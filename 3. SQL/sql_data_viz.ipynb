# %%
# Import Dependencies
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a3f9d068-3c33-4335-a75c-cf19b2e69502" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f30fcac7-eabd-4376-a8cc-12e64a64c880":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"23788a399ed14d3c9e78757d20ffe47d","client_comm_id":"07d28a2b7d1f46f1a98bcac62d33ebdf"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"f30fcac7-eabd-4376-a8cc-12e64a64c880","roots":{"p1002":"a3f9d068-3c33-4335-a75c-cf19b2e69502"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
obs_file = Path("../SQL_Output/results_observation_days.csv")

# %%
obs_data = pd.read_csv(obs_file)

# %%
obs_data.head()
# Out:
#                             locname        lat         lng  \
# 0            Mount Penang Parklands -33.427007  151.296308
# 1  Werakata State Conservation Area -32.884605  151.317346
# 2                     Wicks Reserve -37.856890  145.320790
# 3            Flinders Pde, Brighton -27.302270  153.065257
# 4      Arthur Davis Park (Brighton) -27.312142  153.069133
#
#    Total Days of Observations subnational2code
# 0                          38       AU-NSW-GOS
# 1                          36       AU-NSW-CES
# 2                          34       AU-VIC-KNO
# 3                          30       AU-QLD-BRI
# 4                          22       AU-QLD-BRI

# %%
#%%capture --no-display

# Configure the map plot
obs_map = obs_data.hvplot.points(
    "lng",
    "lat",
    geo = True,
    tiles = "OSM",
    size = "Total Days of Observations",
    frame_width = 800,
    frame_height = 600,
    alpha = 0.9,
    scale = 3.0,
    color = "locname"
)

# Display the map
obs_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [lng,lat]   (locname,Total Days of Observations)

# %%
species_file = Path("../SQL_Output/results_species_diversity.csv")

# %%
species_data = pd.read_csv(species_file)

# %%
species_data.head()
# Out:
#                                         locname        lat         lng  \
# 0  2336, Davis Creek AU-NSW (-32.1680,151.2903) -32.168048  151.290307
# 1                                Ricketts Point -37.994260  145.031540
# 2                          Caulfield Racecourse -37.879342  145.040573
# 3         Mittyack Prange Road Bushland Reserve -35.198657  142.625781
# 4                      Clover Leigh Golf Course -34.121291  148.574980
#
#    Total Number of Species Observed subnational2code
# 0                                 6       AU-NSW-UPH
# 1                                 5       AU-VIC-BAY
# 2                                 5       AU-VIC-GEI
# 3                                 4       AU-VIC-BUL
# 4                                 4       AU-NSW-YOU

# %%
# Configure the map plot
species_map = species_data.hvplot.points(
    "lng",
    "lat",
    geo = True,
    tiles = "OSM",
    size = "Total Number of Species Observed",
    frame_width = 800,
    frame_height = 600,
    alpha = 0.9,
    scale = 4.0,
    color = "locname"
)

# Display the map
species_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [lng,lat]   (locname,Total Number of Species Observed)

# %%
species_data
# Out:
#                                               locname        lat         lng  \
# 0        2336, Davis Creek AU-NSW (-32.1680,151.2903) -32.168048  151.290307
# 1                                      Ricketts Point -37.994260  145.031540
# 2                                Caulfield Racecourse -37.879342  145.040573
# 3               Mittyack Prange Road Bushland Reserve -35.198657  142.625781
# 4                            Clover Leigh Golf Course -34.121291  148.574980
# 5   Keegans Track,  Upper Rouchel, New South Wales... -32.170599  151.293716
# 6   921 Cassels Road,  Mount Royal, New South Wale... -32.174208  151.288543
# 7                   Fishermans Bay Park, Boat Harbour -32.790866  152.109080
# 8                    Lajamanu at -18.33499, 130.63222 -18.334990  130.632220
# 9                                   Spring Mt Reserve -27.737500  152.923610
# 10                      Bunya Mountains National Park -26.879470  151.597600
# 11                                      Newport Lakes -37.839072  144.871216
# 12                                      Yamba pelagic -29.451500  153.821004
# 13                                    Sackville North -33.486497  150.884985
# 14  Leeuwin-Naturaliste National Park--Cape Natura... -33.539120  115.016084
# 15  Daly River, Northern Territory, AU (-13.666, 1... -13.665567  130.648864
# 16           2620, Googong AU-NSW (-35.4043,149.2568) -35.404334  149.256841
# 17              Jerrabomberra Wetlands Nature Reserve -35.314565  149.162235
# 18                             Mount Penang Parklands -33.427007  151.296308
# 19                                Bushy Park Wetlands -37.873041  145.189433
#
#     Total Number of Species Observed subnational2code
# 0                                  6       AU-NSW-UPH
# 1                                  5       AU-VIC-BAY
# 2                                  5       AU-VIC-GEI
# 3                                  4       AU-VIC-BUL
# 4                                  4       AU-NSW-YOU
# 5                                  4       AU-NSW-SIN
# 6                                  4       AU-NSW-UPH
# 7                                  4       AU-NSW-PST
# 8                                  4        AU-NT-CEN
# 9                                  3       AU-QLD-LOG
# 10                                 3       AU-QLD-SOB
# 11                                 3       AU-VIC-HOB
# 12                                 3       AU-NSW-CLA
# 13                                 3       AU-NSW-THE
# 14                                 3        AU-WA-BUS
# 15                                 3        AU-NT-VIC
# 16                                 3       AU-NSW-QUE
# 17                                 3              NaN
# 18                                 3       AU-NSW-GOS
# 19                                 2       AU-VIC-MON

# %%
location_names = species_data['locname'].tolist()
print(location_names)
# Out:
# ['2336, Davis Creek AU-NSW (-32.1680,151.2903)', 'Ricketts Point', 'Caulfield Racecourse', 'Mittyack Prange Road Bushland Reserve', 'Clover Leigh Golf Course', 'Keegans Track,  Upper Rouchel, New South Wales, AU (-32.171, 151.294)', '921 Cassels Road,  Mount Royal, New South Wales, AU (-32.174, 151.289)', 'Fishermans Bay Park, Boat Harbour', 'Lajamanu at -18.33499, 130.63222', 'Spring Mt Reserve', 'Bunya Mountains National Park', 'Newport Lakes', 'Yamba pelagic', 'Sackville North', 'Leeuwin-Naturaliste National Park--Cape Naturaliste', 'Daly River, Northern Territory, AU (-13.666, 130.649)', '2620, Googong AU-NSW (-35.4043,149.2568)', 'Jerrabomberra Wetlands Nature Reserve', 'Mount Penang Parklands', 'Bushy Park Wetlands']

# %%
all_birds = Path("../SQL_Output/eBird_project3.csv")

# %%
all_birds = pd.read_csv(all_birds)

# %%
all_birds.head()
# Out:
#   speciesCode                  comName                 sciName      locId  \
# 0      hudgod         Hudsonian Godwit       Limosa haemastica   L5501457
# 1     gohcis1  Golden-headed Cisticola        Cisticola exilis   L3812472
# 2     gohcis1  Golden-headed Cisticola        Cisticola exilis   L3812472
# 3      compea           Indian Peafowl          Pavo cristatus   L2561059
# 4     aurwar1  Australian Reed Warbler  Acrocephalus australis  L30957325
#
#                                              locName            obsDt  \
# 0                 Flinders Pde at Cliff St, Sandgate  14/6/2024 11:44
# 1                            Kangaroo Swamp (Cattai)  14/6/2024 10:37
# 2                            Kangaroo Swamp (Cattai)  14/6/2024 10:37
# 3                                 Burdekin Falls Dam  14/6/2024 10:02
# 4  543–565 Markwell Rd, Bulahdelah AU-NSW -32.368...   14/6/2024 9:52
#
#    howMany        lat         lng  obsValid  ...   userDisplayName  \
# 0      1.0 -27.320501  153.074731     False  ...  Russell Woodford
# 1      2.0 -33.544471  150.919790     False  ...     Mikaela Tilse
# 2      2.0 -33.544471  150.919790     False  ...        James Hunt
# 3      6.0 -20.642740  147.141260     False  ...     Marleen Acton
# 4      2.0 -32.368145  152.183891     False  ...     Gordon Arthur
#
#            obsId checklistId presenceNoted hasComments firstName  lastName  \
# 0  OBS2242106479     CL29532         False       False   Russell  Woodford
# 1  OBS2241915545     CL29418         False       False   Mikaela     Tilse
# 2  OBS2241915515     CL29418         False       False     James      Hunt
# 3  OBS2242092696     CL29483         False       False   Marleen     Acton
# 4  OBS2242083218     CL29329         False       False    Gordon    Arthur
#
#   hasRichMedia exoticCategory evidence
# 0        False            NaN      NaN
# 1        False            NaN      NaN
# 2        False            NaN      NaN
# 3        False              P      NaN
# 4        False            NaN      NaN
#
# [5 rows x 29 columns]

# %%
#i = species_data['locname']
    #print

#convert locame from species_data into an array 
loop through the array
loop through each row of raw data 
when locname matches the i in array, 
append species list 

species_list = []
for i in location_names:
    if location_names[i] == all_birds['locName']:
        species_list.append(all_birds["comName"][i])

# %%
location_names

# %%
species_list = []
species = all_birds.loc[all_birds["Drug Regimen"] == "Capomulin", :]
capomulin_tumors.append(capomulin["Tumor Volume (mm3)"])
#print(capomulin_tumors)
