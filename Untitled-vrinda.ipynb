# %%
# Import Dependencies
import requests
import json

# Define the API key
api_key = "llhq7n5rh6"

# Import pprint
from pprint import pprint

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import hvplot.pandas

# %%
url = "https://api.ebird.org/v2/data/obs/AU/recent?back=30"
payload={}
headers = {
  'X-eBirdApiToken': api_key
}
response = requests.request("GET", url, headers=headers, data=payload).json()
pprint(response)
# Out:
# [{'comName': 'Australian Ibis',
#   'howMany': 8,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Threskiornis molucca',
#   'speciesCode': 'ausibi1',
#   'subId': 'S181144656'},
#  {'comName': 'Blue-faced Honeyeater',
#   'howMany': 1,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Entomyzon cyanotis',
#   'speciesCode': 'blfhon1',
#   'subId': 'S181144656'},
#  {'comName': 'Superb Fairywren',
#   'howMany': 2,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Malurus cyaneus',
#   'speciesCode': 'supfai1',
#   'subId': 'S181144656'},
#  {'comName': 'Sulphur-crested Cockatoo',
#   'howMany': 2,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cacatua galerita',
#   'speciesCode': 'succoc',
#   'subId': 'S181144656'},
#  {'comName': 'Willie-wagtail',
#   'howMany': 1,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura leucophrys',
#   'speciesCode': 'wilwag1',
#   'subId': 'S181144656'},
#  {'comName': 'Galah',
#   'howMany': 2,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eolophus roseicapilla',
#   'speciesCode': 'galah',
#   'subId': 'S181144656'},
#  {'comName': 'Australian Magpie',
#   'howMany': 2,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gymnorhina tibicen',
#   'speciesCode': 'ausmag2',
#   'subId': 'S181144656'},
#  {'comName': 'Magpie-lark',
#   'howMany': 2,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Grallina cyanoleuca',
#   'speciesCode': 'maglar1',
#   'subId': 'S181144656'},
#  {'comName': 'Rainbow Lorikeet',
#   'howMany': 2,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Trichoglossus moluccanus',
#   'speciesCode': 'railor5',
#   'subId': 'S181144656'},
#  {'comName': 'White-naped Honeyeater',
#   'howMany': 6,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melithreptus lunatus',
#   'speciesCode': 'whnhon2',
#   'subId': 'S181144656'},
#  {'comName': 'Eastern Rosella',
#   'howMany': 4,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platycercus eximius',
#   'speciesCode': 'easros1',
#   'subId': 'S181144656'},
#  {'comName': 'Masked Lapwing',
#   'howMany': 1,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Vanellus miles',
#   'speciesCode': 'maslap1',
#   'subId': 'S181144656'},
#  {'comName': 'Pied Currawong',
#   'howMany': 2,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Strepera graculina',
#   'speciesCode': 'piecur1',
#   'subId': 'S181144656'},
#  {'comName': 'Eurasian Blackbird',
#   'exoticCategory': 'N',
#   'howMany': 1,
#   'lat': -33.838293,
#   'lng': 148.685286,
#   'locId': 'L4004605',
#   'locName': 'Lachlan River at Carob Bean Avenue, Cowra',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 16:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Turdus merula',
#   'speciesCode': 'eurbla',
#   'subId': 'S181144656'},
#  {'comName': 'Australian Pelican',
#   'howMany': 1,
#   'lat': -32.82594,
#   'lng': 151.68651,
#   'locId': 'L2536872',
#   'locName': 'Hexham',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pelecanus conspicillatus',
#   'speciesCode': 'auspel1',
#   'subId': 'S181151948'},
#  {'comName': 'Black-shouldered Kite',
#   'howMany': 1,
#   'lat': -34.197277,
#   'lng': 150.648605,
#   'locId': 'L33272251',
#   'locName': '336–364 Picton Rd, Razorback AU-NSW -34.19728, 150.64860',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Elanus axillaris',
#   'speciesCode': 'auskit1',
#   'subId': 'S181151915'},
#  {'comName': 'Nankeen Kestrel',
#   'howMany': 1,
#   'lat': -34.197277,
#   'lng': 150.648605,
#   'locId': 'L33272251',
#   'locName': '336–364 Picton Rd, Razorback AU-NSW -34.19728, 150.64860',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Falco cenchroides',
#   'speciesCode': 'auskes1',
#   'subId': 'S181151915'},
#  {'comName': 'Long-billed Corella',
#   'exoticCategory': 'N',
#   'howMany': 40,
#   'lat': -34.197277,
#   'lng': 150.648605,
#   'locId': 'L33272251',
#   'locName': '336–364 Picton Rd, Razorback AU-NSW -34.19728, 150.64860',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cacatua tenuirostris',
#   'speciesCode': 'lobcor1',
#   'subId': 'S181151915'},
#  {'comName': 'Crested Pigeon',
#   'howMany': 1,
#   'lat': -32.8141905,
#   'lng': 151.7014126,
#   'locId': 'L33272162',
#   'locName': '15 Kilcoy Drive, Tomago, New South Wales, AU (-32.814, 151.701)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:52',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ocyphaps lophotes',
#   'speciesCode': 'crepig1',
#   'subId': 'S181151525'},
#  {'comName': 'Gray Fantail',
#   'howMany': 2,
#   'lat': -38.3894013,
#   'lng': 145.1286566,
#   'locId': 'L31163714',
#   'locName': 'Balnarring Beach Caravan Park Reserve C',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura albiscapa',
#   'speciesCode': 'gryfan1',
#   'subId': 'S181151613'},
#  {'comName': 'Golden Whistler',
#   'howMany': 1,
#   'lat': -38.3894013,
#   'lng': 145.1286566,
#   'locId': 'L31163714',
#   'locName': 'Balnarring Beach Caravan Park Reserve C',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pachycephala pectoralis',
#   'speciesCode': 'golwhi1',
#   'subId': 'S181151613'},
#  {'comName': 'Welcome Swallow',
#   'howMany': 10,
#   'lat': -38.3894013,
#   'lng': 145.1286566,
#   'locId': 'L31163714',
#   'locName': 'Balnarring Beach Caravan Park Reserve C',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Hirundo neoxena',
#   'speciesCode': 'welswa1',
#   'subId': 'S181151613'},
#  {'comName': 'White-eared Honeyeater',
#   'howMany': 1,
#   'lat': -38.3894013,
#   'lng': 145.1286566,
#   'locId': 'L31163714',
#   'locName': 'Balnarring Beach Caravan Park Reserve C',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Nesoptilotis leucotis',
#   'speciesCode': 'whehon1',
#   'subId': 'S181151613'},
#  {'comName': 'Little Wattlebird',
#   'howMany': 2,
#   'lat': -38.3894013,
#   'lng': 145.1286566,
#   'locId': 'L31163714',
#   'locName': 'Balnarring Beach Caravan Park Reserve C',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anthochaera chrysoptera',
#   'speciesCode': 'bruwat1',
#   'subId': 'S181151613'},
#  {'comName': 'Brown Thornbill',
#   'howMany': 2,
#   'lat': -38.3894013,
#   'lng': 145.1286566,
#   'locId': 'L31163714',
#   'locName': 'Balnarring Beach Caravan Park Reserve C',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acanthiza pusilla',
#   'speciesCode': 'brotho1',
#   'subId': 'S181151613'},
#  {'comName': 'Osprey',
#   'howMany': 2,
#   'lat': -25.18664,
#   'lng': 152.60827,
#   'locId': 'L2533063',
#   'locName': 'Burrum Heads',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:47',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pandion haliaetus',
#   'speciesCode': 'osprey',
#   'subId': 'S181151199'},
#  {'comName': 'Red-browed Firetail',
#   'howMany': 2,
#   'lat': -33.04054,
#   'lng': 150.16897,
#   'locId': 'L2535794',
#   'locName': 'Capertee Valley--Glen Alice Rd',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Neochmia temporalis',
#   'speciesCode': 'rebfir1',
#   'subId': 'S181151701'},
#  {'comName': 'White-plumed Honeyeater',
#   'howMany': 4,
#   'lat': -33.04054,
#   'lng': 150.16897,
#   'locId': 'L2535794',
#   'locName': 'Capertee Valley--Glen Alice Rd',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ptilotula penicillata',
#   'speciesCode': 'whphon1',
#   'subId': 'S181151701'},
#  {'comName': 'Silvereye',
#   'howMany': 1,
#   'lat': -33.04054,
#   'lng': 150.16897,
#   'locId': 'L2535794',
#   'locName': 'Capertee Valley--Glen Alice Rd',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zosterops lateralis',
#   'speciesCode': 'silver3',
#   'subId': 'S181151701'},
#  {'comName': 'Pacific Reef-Heron',
#   'howMany': 1,
#   'lat': -16.7982553,
#   'lng': 145.7100606,
#   'locId': 'L12846077',
#   'locName': 'Trinity Park Foreshore',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:42',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Egretta sacra',
#   'speciesCode': 'pacreh1',
#   'subId': 'S181151481'},
#  {'comName': 'Great Egret',
#   'howMany': 1,
#   'lat': -32.7317177,
#   'lng': 151.7826452,
#   'locId': 'L33272051',
#   'locName': 'Pacific Highway, Ferodale, New South Wales, AU (-32.732, '
#              '151.783)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:40',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardea alba',
#   'speciesCode': 'greegr',
#   'subId': 'S181150810'},
#  {'comName': 'Little Raven',
#   'howMany': 1,
#   'lat': -37.7506954,
#   'lng': 145.6766978,
#   'locId': 'L8169695',
#   'locName': 'Surrey Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus mellori',
#   'speciesCode': 'litrav1',
#   'subId': 'S181151707'},
#  {'comName': 'Australian Raven',
#   'howMany': 1,
#   'lat': -37.7506954,
#   'lng': 145.6766978,
#   'locId': 'L8169695',
#   'locName': 'Surrey Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus coronoides',
#   'speciesCode': 'ausrav1',
#   'subId': 'S181151707'},
#  {'comName': 'Red Wattlebird',
#   'howMany': 2,
#   'lat': -37.7506954,
#   'lng': 145.6766978,
#   'locId': 'L8169695',
#   'locName': 'Surrey Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anthochaera carunculata',
#   'speciesCode': 'redwat1',
#   'subId': 'S181151707'},
#  {'comName': 'Australian King-Parrot',
#   'howMany': 3,
#   'lat': -37.7506954,
#   'lng': 145.6766978,
#   'locId': 'L8169695',
#   'locName': 'Surrey Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Alisterus scapularis',
#   'speciesCode': 'aukpar1',
#   'subId': 'S181151707'},
#  {'comName': 'Crimson Rosella',
#   'howMany': 4,
#   'lat': -37.7506954,
#   'lng': 145.6766978,
#   'locId': 'L8169695',
#   'locName': 'Surrey Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platycercus elegans',
#   'speciesCode': 'criros2',
#   'subId': 'S181151707'},
#  {'comName': 'Common Myna',
#   'exoticCategory': 'N',
#   'howMany': 1,
#   'lat': -37.7506954,
#   'lng': 145.6766978,
#   'locId': 'L8169695',
#   'locName': 'Surrey Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acridotheres tristis',
#   'speciesCode': 'commyn',
#   'subId': 'S181151707'},
#  {'comName': 'Common Bronzewing',
#   'howMany': 2,
#   'lat': -37.7506954,
#   'lng': 145.6766978,
#   'locId': 'L8169695',
#   'locName': 'Surrey Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phaps chalcoptera',
#   'speciesCode': 'combro1',
#   'subId': 'S181151707'},
#  {'comName': 'Pied Stilt',
#   'howMany': 7,
#   'lat': -27.31492,
#   'lng': 153.0704783,
#   'locId': 'L14302017',
#   'locName': '140 Flinders Parade, Sandgate, Queensland, AU (-27.315, 153.07)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:33',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Himantopus leucocephalus',
#   'speciesCode': 'piesti1',
#   'subId': 'S181150805'},
#  {'comName': 'Pied Oystercatcher',
#   'howMany': 7,
#   'lat': -27.31492,
#   'lng': 153.0704783,
#   'locId': 'L14302017',
#   'locName': '140 Flinders Parade, Sandgate, Queensland, AU (-27.315, 153.07)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:33',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Haematopus longirostris',
#   'speciesCode': 'pieoys1',
#   'subId': 'S181150805'},
#  {'comName': 'Silver Gull',
#   'howMany': 7,
#   'lat': -27.31492,
#   'lng': 153.0704783,
#   'locId': 'L14302017',
#   'locName': '140 Flinders Parade, Sandgate, Queensland, AU (-27.315, 153.07)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:33',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chroicocephalus novaehollandiae',
#   'speciesCode': 'silgul2',
#   'subId': 'S181150805'},
#  {'comName': 'Pacific Heron',
#   'howMany': 1,
#   'lat': -32.64206,
#   'lng': 151.8684294,
#   'locId': 'L33271952',
#   'locName': '125 The Bucketts Way, Twelve Mile Creek, New South Wales, AU '
#              '(-32.642, 151.868)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:31',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardea pacifica',
#   'speciesCode': 'pacher1',
#   'subId': 'S181150303'},
#  {'comName': 'Hardhead',
#   'howMany': 60,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Aythya australis',
#   'speciesCode': 'wheduc1',
#   'subId': 'S181151029'},
#  {'comName': 'Chestnut Teal',
#   'howMany': 20,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas castanea',
#   'speciesCode': 'chetea1',
#   'subId': 'S181151029'},
#  {'comName': 'White-faced Heron',
#   'howMany': 5,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Egretta novaehollandiae',
#   'speciesCode': 'whfher1',
#   'subId': 'S181151029'},
#  {'comName': 'Eurasian Coot',
#   'howMany': 20,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Fulica atra',
#   'speciesCode': 'eurcoo',
#   'subId': 'S181151029'},
#  {'comName': 'Australasian Grebe',
#   'howMany': 3,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Tachybaptus novaehollandiae',
#   'speciesCode': 'ausgre1',
#   'subId': 'S181151029'},
#  {'comName': 'Gray Teal',
#   'howMany': 30,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas gracilis',
#   'speciesCode': 'gretea1',
#   'subId': 'S181151029'},
#  {'comName': 'Royal Spoonbill',
#   'howMany': 2,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platalea regia',
#   'speciesCode': 'royspo1',
#   'subId': 'S181151029'},
#  {'comName': 'Hoary-headed Grebe',
#   'howMany': 5,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Poliocephalus poliocephalus',
#   'speciesCode': 'hohgre1',
#   'subId': 'S181151029'},
#  {'comName': 'Black Swan',
#   'howMany': 1,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cygnus atratus',
#   'speciesCode': 'blkswa',
#   'subId': 'S181151029'},
#  {'comName': 'Noisy Miner',
#   'howMany': 2,
#   'lat': -34.127736,
#   'lng': 150.711343,
#   'locId': 'L33272098',
#   'locName': '2568, Menangle AU-NSW (-34.1277,150.7113)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:29',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanocephala',
#   'speciesCode': 'noimin1',
#   'subId': 'S181151029'},
#  {'comName': 'Maned Duck',
#   'howMany': 20,
#   'lat': -37.71356,
#   'lng': 145.11154,
#   'locId': 'L2986722',
#   'locName': 'Willinda Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:28',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chenonetta jubata',
#   'speciesCode': 'manduc1',
#   'subId': 'S181150387'},
#  {'comName': 'Straw-necked Ibis',
#   'howMany': 12,
#   'lat': -37.71356,
#   'lng': 145.11154,
#   'locId': 'L2986722',
#   'locName': 'Willinda Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:28',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Threskiornis spinicollis',
#   'speciesCode': 'stnibi1',
#   'subId': 'S181150387'},
#  {'comName': 'Gray Goshawk',
#   'howMany': 1,
#   'lat': -42.9014728,
#   'lng': 147.2706127,
#   'locId': 'L2709360',
#   'locName': 'Strickland Ave above the brewery',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:27',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Accipiter novaehollandiae',
#   'speciesCode': 'grygos1',
#   'subId': 'S181150170'},
#  {'comName': 'Little Pied Cormorant',
#   'howMany': 3,
#   'lat': -27.451504,
#   'lng': 153.191142,
#   'locId': 'L9126708',
#   'locName': 'Manly Boat Harbour, Manly AU-QLD (-27.4515,153.1911)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:27',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Microcarbo melanoleucos',
#   'speciesCode': 'lipcor1',
#   'subId': 'S181150539'},
#  {'comName': 'Brown Honeyeater',
#   'howMany': 2,
#   'lat': -27.451504,
#   'lng': 153.191142,
#   'locId': 'L9126708',
#   'locName': 'Manly Boat Harbour, Manly AU-QLD (-27.4515,153.1911)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:27',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lichmera indistincta',
#   'speciesCode': 'brohon1',
#   'subId': 'S181150539'},
#  {'comName': 'Musk Lorikeet',
#   'howMany': 2,
#   'lat': -37.79796,
#   'lng': 144.9612,
#   'locId': 'L2551983',
#   'locName': 'University of Melbourne',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:23',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glossopsitta concinna',
#   'speciesCode': 'muslor1',
#   'subId': 'S181149970'},
#  {'comName': 'Lesser Crested Tern',
#   'howMany': 1,
#   'lat': -27.4453725,
#   'lng': 153.1814343,
#   'locId': 'L6291249',
#   'locName': 'Wynnum Esplanade at Penfold Parade',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:21',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Thalasseus bengalensis',
#   'speciesCode': 'lecter2',
#   'subId': 'S181150097'},
#  {'comName': 'Great Crested Tern',
#   'howMany': 1,
#   'lat': -27.4453725,
#   'lng': 153.1814343,
#   'locId': 'L6291249',
#   'locName': 'Wynnum Esplanade at Penfold Parade',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:21',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Thalasseus bergii',
#   'speciesCode': 'grcter1',
#   'subId': 'S181150097'},
#  {'comName': 'Australian Tern',
#   'howMany': 1,
#   'lat': -27.4453725,
#   'lng': 153.1814343,
#   'locId': 'L6291249',
#   'locName': 'Wynnum Esplanade at Penfold Parade',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:21',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gelochelidon macrotarsa',
#   'speciesCode': 'gubter3',
#   'subId': 'S181150097'},
#  {'comName': 'Gibber Chat',
#   'howMany': 2,
#   'lat': -28.895905,
#   'lng': 134.824694,
#   'locId': 'L33272150',
#   'locName': 'Kanku-Breakaways Conservation Park, Coober Pedy AU-SA -28.89590, '
#              '134.82469',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:19',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ashbyia lovensis',
#   'speciesCode': 'descha1',
#   'subId': 'S181151467'},
#  {'comName': 'Laughing Kookaburra',
#   'lat': -36.20557,
#   'lng': 147.2525,
#   'locId': 'L33271796',
#   'locName': '8701 Murray Valley Highway, Tallangatta East AU-VIC -36.20557, '
#              '147.25250',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dacelo novaeguineae',
#   'speciesCode': 'laukoo1',
#   'subId': 'S181149729'},
#  {'comName': 'Australasian Swamphen',
#   'lat': -37.8912608,
#   'lng': 144.7961569,
#   'locId': 'L2531712',
#   'locName': 'Point Cook Coastal Park--Cheetham Wetlands (restricted access)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Porphyrio melanotus',
#   'speciesCode': 'purswa6',
#   'subId': 'S181149934'},
#  {'comName': 'Little Egret',
#   'howMany': 10,
#   'lat': -29.4487956,
#   'lng': 153.2682009,
#   'locId': 'L8070236',
#   'locName': 'Palmers Channel North Bank Rd, Palmers Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Egretta garzetta',
#   'speciesCode': 'litegr',
#   'subId': 'S181150517'},
#  {'comName': 'Wedge-tailed Eagle',
#   'howMany': 4,
#   'lat': -29.4487956,
#   'lng': 153.2682009,
#   'locId': 'L8070236',
#   'locName': 'Palmers Channel North Bank Rd, Palmers Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Aquila audax',
#   'speciesCode': 'weteag1',
#   'subId': 'S181150517'},
#  {'comName': 'White-bellied Sea-Eagle',
#   'howMany': 2,
#   'lat': -29.4487956,
#   'lng': 153.2682009,
#   'locId': 'L8070236',
#   'locName': 'Palmers Channel North Bank Rd, Palmers Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Icthyophaga leucogaster',
#   'speciesCode': 'wbseag1',
#   'subId': 'S181150517'},
#  {'comName': 'Little Black Cormorant',
#   'howMany': 10,
#   'lat': -29.4487956,
#   'lng': 153.2682009,
#   'locId': 'L8070236',
#   'locName': 'Palmers Channel North Bank Rd, Palmers Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phalacrocorax sulcirostris',
#   'speciesCode': 'libcor1',
#   'subId': 'S181150517'},
#  {'comName': 'Pied Butcherbird',
#   'howMany': 2,
#   'lat': -29.4487956,
#   'lng': 153.2682009,
#   'locId': 'L8070236',
#   'locName': 'Palmers Channel North Bank Rd, Palmers Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cracticus nigrogularis',
#   'speciesCode': 'piebut1',
#   'subId': 'S181150517'},
#  {'comName': 'Plumed Whistling-Duck',
#   'howMany': 35,
#   'lat': -29.4487956,
#   'lng': 153.2682009,
#   'locId': 'L8070236',
#   'locName': 'Palmers Channel North Bank Rd, Palmers Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dendrocygna eytoni',
#   'speciesCode': 'plwduc1',
#   'subId': 'S181150517'},
#  {'comName': 'Eastern Whipbird',
#   'howMany': 2,
#   'lat': -29.4487956,
#   'lng': 153.2682009,
#   'locId': 'L8070236',
#   'locName': 'Palmers Channel North Bank Rd, Palmers Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Psophodes olivaceus',
#   'speciesCode': 'easwhi1',
#   'subId': 'S181150517'},
#  {'comName': 'Common Tern',
#   'howMany': 7,
#   'lat': -29.4487956,
#   'lng': 153.2682009,
#   'locId': 'L8070236',
#   'locName': 'Palmers Channel North Bank Rd, Palmers Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sterna hirundo',
#   'speciesCode': 'comter',
#   'subId': 'S181150517'},
#  {'comName': 'European Starling',
#   'exoticCategory': 'N',
#   'lat': -37.8912608,
#   'lng': 144.7961569,
#   'locId': 'L2531712',
#   'locName': 'Point Cook Coastal Park--Cheetham Wetlands (restricted access)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sturnus vulgaris',
#   'speciesCode': 'eursta',
#   'subId': 'S181149934'},
#  {'comName': "Lewin's Honeyeater",
#   'howMany': 1,
#   'lat': -29.4487956,
#   'lng': 153.2682009,
#   'locId': 'L8070236',
#   'locName': 'Palmers Channel North Bank Rd, Palmers Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:16',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Meliphaga lewinii',
#   'speciesCode': 'lewhon1',
#   'subId': 'S181150517'},
#  {'comName': 'Sacred Kingfisher',
#   'howMany': 1,
#   'lat': -27.4488573,
#   'lng': 153.0988491,
#   'locId': 'L3264047',
#   'locName': 'Metroplex Avenue Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Todiramphus sanctus',
#   'speciesCode': 'sackin1',
#   'subId': 'S181150688'},
#  {'comName': 'Striated Pardalote',
#   'howMany': 1,
#   'lat': -27.4488573,
#   'lng': 153.0988491,
#   'locId': 'L3264047',
#   'locName': 'Metroplex Avenue Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pardalotus striatus',
#   'speciesCode': 'strpar1',
#   'subId': 'S181150688'},
#  {'comName': 'Eastern Cattle Egret',
#   'howMany': 20,
#   'lat': -32.4733962,
#   'lng': 151.9595264,
#   'locId': 'L33271779',
#   'locName': '2286 The Bucketts Way, Booral, New South Wales, AU (-32.473, '
#              '151.96)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Bubulcus coromandus',
#   'speciesCode': 'categr2',
#   'subId': 'S181149650'},
#  {'comName': 'Orange-footed Megapode',
#   'howMany': 2,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Megapodius reinwardt',
#   'speciesCode': 'orfscr1',
#   'subId': 'S181151730'},
#  {'comName': 'White-throated Honeyeater',
#   'howMany': 1,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melithreptus albogularis',
#   'speciesCode': 'whthon1',
#   'subId': 'S181151730'},
#  {'comName': 'White-gaped Honeyeater',
#   'howMany': 1,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Stomiopera unicolor',
#   'speciesCode': 'whghon1',
#   'subId': 'S181151730'},
#  {'comName': 'White-breasted Woodswallow',
#   'howMany': 1,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Artamus leucorynchus',
#   'speciesCode': 'whbwoo4',
#   'subId': 'S181151730'},
#  {'comName': 'Red-winged Parrot',
#   'howMany': 1,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Aprosmictus erythropterus',
#   'speciesCode': 'rewpar1',
#   'subId': 'S181151730'},
#  {'comName': 'Red-collared Lorikeet',
#   'howMany': 3,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Trichoglossus rubritorquis',
#   'speciesCode': 'railor7',
#   'subId': 'S181151730'},
#  {'comName': 'Little Friarbird',
#   'howMany': 1,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Philemon citreogularis',
#   'speciesCode': 'litfri1',
#   'subId': 'S181151730'},
#  {'comName': 'Rainbow Bee-eater',
#   'howMany': 2,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Merops ornatus',
#   'speciesCode': 'rabeat1',
#   'subId': 'S181151730'},
#  {'comName': 'Mistletoebird',
#   'howMany': 1,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dicaeum hirundinaceum',
#   'speciesCode': 'mistle1',
#   'subId': 'S181151730'},
#  {'comName': 'Peaceful Dove',
#   'howMany': 2,
#   'lat': -12.399842,
#   'lng': 130.874969,
#   'locId': 'L33272209',
#   'locName': 'Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia placida',
#   'speciesCode': 'peadov1',
#   'subId': 'S181151730'},
#  {'comName': 'Pacific Black Duck',
#   'howMany': 2,
#   'lat': -32.3803121,
#   'lng': 151.9493098,
#   'locId': 'L33271647',
#   'locName': '300 The Bucketts Way, Stroud, New South Wales, AU (-32.38, '
#              '151.949)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 15:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas superciliosa',
#   'speciesCode': 'pabduc1',
#   'subId': 'S181149076'},
#  {'comName': 'House Sparrow',
#   'exoticCategory': 'N',
#   'howMany': 2,
#   'lat': -35.34896,
#   'lng': 149.15554,
#   'locId': 'L2541747',
#   'locName': 'Narrabundah Lane, Symonston',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:04',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Passer domesticus',
#   'speciesCode': 'houspa',
#   'subId': 'S181149356'},
#  {'comName': 'Eastern Spinebill',
#   'howMany': 1,
#   'lat': -35.34896,
#   'lng': 149.15554,
#   'locId': 'L2541747',
#   'locName': 'Narrabundah Lane, Symonston',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:04',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acanthorhynchus tenuirostris',
#   'speciesCode': 'easspi1',
#   'subId': 'S181149356'},
#  {'comName': 'Australasian Shoveler',
#   'howMany': 4,
#   'lat': -34.1272,
#   'lng': 150.702364,
#   'locId': 'L6781562',
#   'locName': 'Elizabeth Macarthur Agricultural Institute',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:01',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Spatula rhynchotis',
#   'speciesCode': 'aussho1',
#   'subId': 'S181149719'},
#  {'comName': 'Musk Duck',
#   'howMany': 1,
#   'lat': -34.1272,
#   'lng': 150.702364,
#   'locId': 'L6781562',
#   'locName': 'Elizabeth Macarthur Agricultural Institute',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 15:01',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Biziura lobata',
#   'speciesCode': 'musduc1',
#   'subId': 'S181149719'},
#  {'comName': 'Bar-shouldered Dove',
#   'howMany': 1,
#   'lat': -16.2607666,
#   'lng': 145.3920638,
#   'locId': 'L2540418',
#   'locName': 'Lower Daintree River Boat Cruise',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:46',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia humeralis',
#   'speciesCode': 'basdov1',
#   'subId': 'S181148657'},
#  {'comName': 'Australasian Figbird',
#   'howMany': 3,
#   'lat': -16.2607666,
#   'lng': 145.3920638,
#   'locId': 'L2540418',
#   'locName': 'Lower Daintree River Boat Cruise',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:46',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sphecotheres vieilloti',
#   'speciesCode': 'ausfig1',
#   'subId': 'S181148657'},
#  {'comName': 'Forest Raven',
#   'howMany': 1,
#   'lat': -40.802685,
#   'lng': 147.944301,
#   'locId': 'L33271671',
#   'locName': '7264, Rushy Lagoon AU-TAS (-40.8027,147.9443)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus tasmanicus',
#   'speciesCode': 'forrav1',
#   'subId': 'S181149174'},
#  {'comName': 'Yellow-tailed Black-Cockatoo',
#   'howMany': 2,
#   'lat': -40.802685,
#   'lng': 147.944301,
#   'locId': 'L33271671',
#   'locName': '7264, Rushy Lagoon AU-TAS (-40.8027,147.9443)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zanda funerea',
#   'speciesCode': 'ytbcoc1',
#   'subId': 'S181149174'},
#  {'comName': 'Fan-tailed Cuckoo',
#   'howMany': 1,
#   'lat': -40.802685,
#   'lng': 147.944301,
#   'locId': 'L33271671',
#   'locName': '7264, Rushy Lagoon AU-TAS (-40.8027,147.9443)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cacomantis flabelliformis',
#   'speciesCode': 'fatcuc1',
#   'subId': 'S181149174'},
#  {'comName': 'Gray Shrikethrush',
#   'howMany': 1,
#   'lat': -40.802685,
#   'lng': 147.944301,
#   'locId': 'L33271671',
#   'locName': '7264, Rushy Lagoon AU-TAS (-40.8027,147.9443)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Colluricincla harmonica',
#   'speciesCode': 'grysht1',
#   'subId': 'S181149174'},
#  {'comName': 'Brown Falcon',
#   'howMany': 1,
#   'lat': -40.802685,
#   'lng': 147.944301,
#   'locId': 'L33271671',
#   'locName': '7264, Rushy Lagoon AU-TAS (-40.8027,147.9443)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Falco berigora',
#   'speciesCode': 'brofal1',
#   'subId': 'S181149174'},
#  {'comName': 'Sooty Oystercatcher',
#   'howMany': 8,
#   'lat': -43.15589,
#   'lng': 147.847228,
#   'locId': 'L33272131',
#   'locName': '160–162 Safety Cove Rd, 亞瑟港 AU-TAS -43.15589, 147.84723',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Haematopus fuliginosus',
#   'speciesCode': 'soooys1',
#   'subId': 'S181151198'},
#  {'comName': 'Black-headed Honeyeater',
#   'howMany': 4,
#   'lat': -43.15589,
#   'lng': 147.847228,
#   'locId': 'L33272131',
#   'locName': '160–162 Safety Cove Rd, 亞瑟港 AU-TAS -43.15589, 147.84723',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melithreptus affinis',
#   'speciesCode': 'blhhon1',
#   'subId': 'S181151198'},
#  {'comName': 'Pacific Gull',
#   'howMany': 3,
#   'lat': -43.15589,
#   'lng': 147.847228,
#   'locId': 'L33272131',
#   'locName': '160–162 Safety Cove Rd, 亞瑟港 AU-TAS -43.15589, 147.84723',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Larus pacificus',
#   'speciesCode': 'pacgul1',
#   'subId': 'S181151198'},
#  {'comName': 'Green Rosella',
#   'howMany': 2,
#   'lat': -43.15589,
#   'lng': 147.847228,
#   'locId': 'L33272131',
#   'locName': '160–162 Safety Cove Rd, 亞瑟港 AU-TAS -43.15589, 147.84723',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platycercus caledonicus',
#   'speciesCode': 'greros2',
#   'subId': 'S181151198'},
#  {'comName': 'Great Cormorant',
#   'howMany': 2,
#   'lat': -43.15589,
#   'lng': 147.847228,
#   'locId': 'L33272131',
#   'locName': '160–162 Safety Cove Rd, 亞瑟港 AU-TAS -43.15589, 147.84723',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phalacrocorax carbo',
#   'speciesCode': 'grecor',
#   'subId': 'S181151198'},
#  {'comName': 'Scarlet Robin',
#   'howMany': 1,
#   'lat': -43.15589,
#   'lng': 147.847228,
#   'locId': 'L33272131',
#   'locName': '160–162 Safety Cove Rd, 亞瑟港 AU-TAS -43.15589, 147.84723',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Petroica boodang',
#   'speciesCode': 'scarob2',
#   'subId': 'S181151198'},
#  {'comName': 'Yellow-throated Honeyeater',
#   'howMany': 1,
#   'lat': -43.15589,
#   'lng': 147.847228,
#   'locId': 'L33272131',
#   'locName': '160–162 Safety Cove Rd, 亞瑟港 AU-TAS -43.15589, 147.84723',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Nesoptilotis flavicollis',
#   'speciesCode': 'yethon1',
#   'subId': 'S181151198'},
#  {'comName': 'Spotted Dove',
#   'exoticCategory': 'N',
#   'howMany': 8,
#   'lat': -32.971115,
#   'lng': 151.688204,
#   'locId': 'L3344306',
#   'locName': 'Gateshead',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Spilopelia chinensis',
#   'speciesCode': 'spodov',
#   'subId': 'S181148065'},
#  {'comName': 'Yellow-faced Honeyeater',
#   'howMany': 2,
#   'lat': -32.971115,
#   'lng': 151.688204,
#   'locId': 'L3344306',
#   'locName': 'Gateshead',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Caligavis chrysops',
#   'speciesCode': 'yefhon1',
#   'subId': 'S181148065'},
#  {'comName': 'Azure Kingfisher',
#   'howMany': 1,
#   'lat': -36.7883982,
#   'lng': 145.1232362,
#   'locId': 'L2551280',
#   'locName': 'Chinamans Bridge, Nagambie',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ceyx azureus',
#   'speciesCode': 'azukin1',
#   'subId': 'S181148597'},
#  {'comName': 'Gray Butcherbird',
#   'howMany': 1,
#   'lat': -32.971115,
#   'lng': 151.688204,
#   'locId': 'L3344306',
#   'locName': 'Gateshead',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cracticus torquatus',
#   'speciesCode': 'grybut1',
#   'subId': 'S181148065'},
#  {'comName': 'Red-rumped Parrot',
#   'howMany': 2,
#   'lat': -36.7883982,
#   'lng': 145.1232362,
#   'locId': 'L2551280',
#   'locName': 'Chinamans Bridge, Nagambie',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Psephotus haematonotus',
#   'speciesCode': 'rerpar1',
#   'subId': 'S181148597'},
#  {'comName': 'Dusky Moorhen',
#   'howMany': 4,
#   'lat': -36.7883982,
#   'lng': 145.1232362,
#   'locId': 'L2551280',
#   'locName': 'Chinamans Bridge, Nagambie',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gallinula tenebrosa',
#   'speciesCode': 'dusmoo1',
#   'subId': 'S181148597'},
#  {'comName': 'Spotted Pardalote',
#   'howMany': 2,
#   'lat': -36.7883982,
#   'lng': 145.1232362,
#   'locId': 'L2551280',
#   'locName': 'Chinamans Bridge, Nagambie',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pardalotus punctatus',
#   'speciesCode': 'spopar1',
#   'subId': 'S181148597'},
#  {'comName': 'Black-faced Cuckooshrike',
#   'howMany': 1,
#   'lat': -32.1091179,
#   'lng': 151.9397224,
#   'locId': 'L33271415',
#   'locName': '3660 The Bucketts Way, Stratford, New South Wales, AU (-32.109, '
#              '151.94)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Coracina novaehollandiae',
#   'speciesCode': 'bkfcus1',
#   'subId': 'S181147822'},
#  {'comName': 'Brown Songlark',
#   'howMany': 1,
#   'lat': -28.6758909,
#   'lng': 149.440504,
#   'locId': 'L33272083',
#   'locName': 'Unnamed Road, Boomi, New South Wales, AU (-28.676, '
#              '149.441)Koramba, Sth Front, Sth Perimiter.',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cincloramphus cruralis',
#   'speciesCode': 'broson1',
#   'subId': 'S181150961'},
#  {'comName': 'Yellow-billed Spoonbill',
#   'howMany': 1,
#   'lat': -34.0664542,
#   'lng': 139.8523092,
#   'locId': 'L1175701',
#   'locName': 'Hogwash Bend',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platalea flavipes',
#   'speciesCode': 'yebspo1',
#   'subId': 'S181149500'},
#  {'comName': 'Australian Ringneck',
#   'howMany': 2,
#   'lat': -34.0664542,
#   'lng': 139.8523092,
#   'locId': 'L1175701',
#   'locName': 'Hogwash Bend',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Barnardius zonarius',
#   'speciesCode': 'polpar1',
#   'subId': 'S181149500'},
#  {'comName': 'Bell Miner',
#   'howMany': 1,
#   'lat': -37.7164516,
#   'lng': 145.0554943,
#   'locId': 'L1922139',
#   'locName': 'La Trobe University Bundoora--Nangak Tamboree Wildlife Sanctuary '
#              '(don’t report Emus)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanophrys',
#   'speciesCode': 'belmin1',
#   'subId': 'S181149425'},
#  {'comName': 'Rock Pigeon',
#   'exoticCategory': 'N',
#   'howMany': 6,
#   'lat': -34.0664542,
#   'lng': 139.8523092,
#   'locId': 'L1175701',
#   'locName': 'Hogwash Bend',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Columba livia',
#   'speciesCode': 'rocpig',
#   'subId': 'S181149500'},
#  {'comName': 'Australian Shelduck',
#   'howMany': 5,
#   'lat': -34.0664542,
#   'lng': 139.8523092,
#   'locId': 'L1175701',
#   'locName': 'Hogwash Bend',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Tadorna tadornoides',
#   'speciesCode': 'ausshe1',
#   'subId': 'S181149500'},
#  {'comName': 'Whistling Kite',
#   'howMany': 3,
#   'lat': -34.0664542,
#   'lng': 139.8523092,
#   'locId': 'L1175701',
#   'locName': 'Hogwash Bend',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Haliastur sphenurus',
#   'speciesCode': 'whikit1',
#   'subId': 'S181149500'},
#  {'comName': 'Torresian Crow',
#   'howMany': 30,
#   'lat': -28.6758909,
#   'lng': 149.440504,
#   'locId': 'L33272083',
#   'locName': 'Unnamed Road, Boomi, New South Wales, AU (-28.676, '
#              '149.441)Koramba, Sth Front, Sth Perimiter.',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus orru',
#   'speciesCode': 'torcro2',
#   'subId': 'S181150961'},
#  {'comName': 'Black Kite',
#   'howMany': 1,
#   'lat': -28.6758909,
#   'lng': 149.440504,
#   'locId': 'L33272083',
#   'locName': 'Unnamed Road, Boomi, New South Wales, AU (-28.676, '
#              '149.441)Koramba, Sth Front, Sth Perimiter.',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Milvus migrans',
#   'speciesCode': 'blakit1',
#   'subId': 'S181150961'},
#  {'comName': 'Zebra Finch',
#   'howMany': 2,
#   'lat': -28.6758909,
#   'lng': 149.440504,
#   'locId': 'L33272083',
#   'locName': 'Unnamed Road, Boomi, New South Wales, AU (-28.676, '
#              '149.441)Koramba, Sth Front, Sth Perimiter.',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Taeniopygia guttata',
#   'speciesCode': 'zebfin2',
#   'subId': 'S181150961'},
#  {'comName': 'Australasian Darter',
#   'howMany': 1,
#   'lat': -34.0664542,
#   'lng': 139.8523092,
#   'locId': 'L1175701',
#   'locName': 'Hogwash Bend',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anhinga novaehollandiae',
#   'speciesCode': 'darter4',
#   'subId': 'S181149500'},
#  {'comName': 'Little Corella',
#   'howMany': 6,
#   'lat': -34.0664542,
#   'lng': 139.8523092,
#   'locId': 'L1175701',
#   'locName': 'Hogwash Bend',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cacatua sanguinea',
#   'speciesCode': 'litcor2',
#   'subId': 'S181149500'},
#  {'comName': 'Regent Parrot',
#   'howMany': 8,
#   'lat': -34.0664542,
#   'lng': 139.8523092,
#   'locId': 'L1175701',
#   'locName': 'Hogwash Bend',
#   'locationPrivate': False,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Polytelis anthopeplus',
#   'speciesCode': 'regpar1',
#   'subId': 'S181149500'},
#  {'comName': 'Australian Pipit',
#   'howMany': 2,
#   'lat': -28.6758909,
#   'lng': 149.440504,
#   'locId': 'L33272083',
#   'locName': 'Unnamed Road, Boomi, New South Wales, AU (-28.676, '
#              '149.441)Koramba, Sth Front, Sth Perimiter.',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anthus australis',
#   'speciesCode': 'auspip2',
#   'subId': 'S181150961'},
#  {'comName': 'Red-capped Plover',
#   'howMany': 2,
#   'lat': -41.434595,
#   'lng': 148.27637,
#   'locId': 'L25941056',
#   'locName': 'Shelly Point',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:34',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anarhynchus ruficapillus',
#   'speciesCode': 'recplo1',
#   'subId': 'S181149771'},
#  {'comName': 'Hooded Plover',
#   'howMany': 5,
#   'lat': -41.434595,
#   'lng': 148.27637,
#   'locId': 'L25941056',
#   'locName': 'Shelly Point',
#   'locationPrivate': True,
#   'obsDt': '2024-06-13 14:34',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Charadrius cucullatus',
#   'speciesCode': 'hooplo2',
#   'subId': 'S181149771'},
#  {'comName': 'White-capped Albatross',
#   'howMany': 1,
#   'lat': -41.434595,
#   'lng': 148.27637,
#   'locId': 'L25941056',
#   'locName': 'Shelly Point',
# ...
#   'locationPrivate': False,
#   'obsDt': '2024-06-04 09:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dendrocygna guttata',
#   'speciesCode': 'spwduc1',
#   'subId': 'S179652896'},
#  {'comName': 'Black-naped Tern',
#   'howMany': 17,
#   'lat': -16.00555,
#   'lng': 145.84144,
#   'locId': 'L2540806',
#   'locName': 'Agincourt Reefs',
#   'locationPrivate': False,
#   'obsDt': '2024-06-04 09:28',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sterna sumatrana',
#   'speciesCode': 'blnter1',
#   'subId': 'S179295909'},
#  {'comName': 'Chestnut-backed Buttonquail',
#   'howMany': 2,
#   'lat': -14.930525,
#   'lng': 131.9624,
#   'locId': 'L32828867',
#   'locName': '0852, Manbulloo AU-NT -14.93053, 131.96240',
#   'locationPrivate': True,
#   'obsDt': '2024-06-04 09:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Turnix castanotus',
#   'speciesCode': 'chbbut2',
#   'subId': 'S179285162'},
#  {'comName': 'Little x Long-billed Corella (hybrid)',
#   'howMany': 2,
#   'lat': -33.82288,
#   'lng': 151.14666,
#   'locId': 'L2555918',
#   'locName': 'Lane Cove National Park--Boronia Park to Buffalo Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-04 08:00',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Cacatua sanguinea x tenuirostris',
#   'speciesCode': 'x00806',
#   'subId': 'S179274639'},
#  {'comName': 'Kimberley Honeyeater',
#   'howMany': 2,
#   'lat': -14.1283333,
#   'lng': 126.3091667,
#   'locId': 'L17211408',
#   'locName': 'Vansittart Bay (C53 wreck)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-03 09:34',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Territornis fordiana',
#   'speciesCode': 'kimhon1',
#   'subId': 'S179072412'},
#  {'comName': 'White-winged Tern',
#   'howMany': 1,
#   'lat': -17.9746307,
#   'lng': 122.2218919,
#   'locId': 'L985449',
#   'locName': 'Broome South Wastewater Treatment Plant',
#   'locationPrivate': False,
#   'obsDt': '2024-06-03 08:41',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chlidonias leucopterus',
#   'speciesCode': 'whwter',
#   'subId': 'S179076967'},
#  {'comName': 'Bridled Tern',
#   'howMany': 1,
#   'lat': -9.347823,
#   'lng': 143.6731,
#   'locId': 'L32722596',
#   'locName': 'Mar del Coral (Australia1)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-02 17:46',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Onychoprion anaethetus',
#   'speciesCode': 'briter1',
#   'subId': 'S178809195'},
#  {'comName': 'Copperback Quail-thrush',
#   'howMany': 3,
#   'lat': -33.1695538,
#   'lng': 137.0407968,
#   'locId': 'L23506153',
#   'locName': 'Middleback Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-02 13:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cinclosoma clarum',
#   'speciesCode': 'copqut1',
#   'subId': 'S178814719'},
#  {'comName': 'Streaked Shearwater',
#   'howMany': 3,
#   'lat': -13.737797,
#   'lng': 127.630206,
#   'locId': 'L32722766',
#   'locName': 'At sea -13.73780, 127.63021',
#   'locationPrivate': True,
#   'obsDt': '2024-06-02 10:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calonectris leucomelas',
#   'speciesCode': 'strshe',
#   'subId': 'S178809875'},
#  {'comName': "Salvin's Albatross",
#   'howMany': 1,
#   'lat': -43.0906763,
#   'lng': 148.3212687,
#   'locId': 'L1163813',
#   'locName': 'Eaglehawk Neck Pelagic Trip',
#   'locationPrivate': False,
#   'obsDt': '2024-06-02 07:28',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Thalassarche salvini',
#   'speciesCode': 'salalb1',
#   'subId': 'S179321107'},
#  {'comName': 'Sooty Tern',
#   'lat': -12.2390223,
#   'lng': 122.9802258,
#   'locId': 'L32572461',
#   'locName': 'Ashmore Reef (-12.239, 122.98)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-01 13:27',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Onychoprion fuscatus',
#   'speciesCode': 'sooter1',
#   'subId': 'S179333397'},
#  {'comName': 'Blue-breasted Quail',
#   'howMany': 1,
#   'lat': -27.1158826,
#   'lng': 152.7533282,
#   'locId': 'L10571892',
#   'locName': "Kye's backyard",
#   'locationPrivate': True,
#   'obsDt': '2024-05-30 23:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Synoicus chinensis',
#   'speciesCode': 'blbqua1',
#   'subId': 'S178175225'},
#  {'comName': 'Pacific Koel',
#   'howMany': 1,
#   'lat': -27.93671,
#   'lng': 153.323638,
#   'locId': 'L32561000',
#   'locName': '1 Pago Tce, Pacific Pines AU-QLD -27.93671, 153.32364',
#   'locationPrivate': True,
#   'obsDt': '2024-05-30 12:33',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eudynamys orientalis',
#   'speciesCode': 'asikoe3',
#   'subId': 'S178116301'},
#  {'comName': 'Chestnut-breasted Cuckoo',
#   'howMany': 1,
#   'lat': -16.56237,
#   'lng': 145.38771,
#   'locId': 'L2539396',
#   'locName': 'Euluma Creek Rd, Julatten at -16.56237, 145.38771 (restricted '
#              'access)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-30 08:05',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Cacomantis castaneiventris',
#   'speciesCode': 'chbcuc3',
#   'subId': 'S178112972'},
#  {'comName': 'Black-eared Miner',
#   'howMany': 2,
#   'lat': -33.7056432,
#   'lng': 140.212664,
#   'locId': 'L2557774',
#   'locName': 'Gluepot Reserve--Josies Hideaway (Grasswren Tank)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-30 07:26',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanotis',
#   'speciesCode': 'blemin1',
#   'subId': 'S179834231'},
#  {'comName': 'Egyptian Goose',
#   'exoticCategory': 'X',
#   'howMany': 1,
#   'lat': -26.5250424,
#   'lng': 152.9674081,
#   'locId': 'L5589433',
#   'locName': 'Fairhill Rd Dams at -26.5250, 152.9674 (North Arm)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-29 10:53',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Alopochen aegyptiaca',
#   'speciesCode': 'egygoo',
#   'subId': 'S178087173'},
#  {'comName': 'Northern Shrike-tit',
#   'howMany': 3,
#   'lat': -15.7026,
#   'lng': 126.3786,
#   'locId': 'L1120589',
#   'locName': 'Drysdale River Station',
#   'locationPrivate': False,
#   'obsDt': '2024-05-29 06:30',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Falcunculus whitei',
#   'speciesCode': 'cresht3',
#   'subId': 'S178566492'},
#  {'comName': 'Yellow-rumped Munia',
#   'howMany': 3,
#   'lat': -15.61389,
#   'lng': 130.4075,
#   'locId': 'L2538504',
#   'locName': 'Bradshaw Bridge at -15.61389, 130.4075',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 17:04',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lonchura flaviprymna',
#   'speciesCode': 'yermun1',
#   'subId': 'S177926578'},
#  {'comName': 'Flesh-footed Shearwater',
#   'howMany': 4,
#   'lat': -23.14288,
#   'lng': 113.7751,
#   'locId': 'L2562064',
#   'locName': 'Coral Bay',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 16:56',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardenna carneipes',
#   'speciesCode': 'flfshe',
#   'subId': 'S177754811'},
#  {'comName': 'Noisy Scrub-bird',
#   'howMany': 3,
#   'lat': -34.8850112,
#   'lng': 118.4162621,
#   'locId': 'L921845',
#   'locName': 'Arpenteur Nature Reserve (incl. encompassing trails)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 06:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Atrichornis clamosus',
#   'speciesCode': 'nosbir1',
#   'subId': 'S180269365'},
#  {'comName': 'Western Bristlebird',
#   'howMany': 3,
#   'lat': -34.8850112,
#   'lng': 118.4162621,
#   'locId': 'L921845',
#   'locName': 'Arpenteur Nature Reserve (incl. encompassing trails)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 06:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dasyornis longirostris',
#   'speciesCode': 'wesbri1',
#   'subId': 'S180269365'},
#  {'comName': 'Blue-faced Parrotfinch',
#   'howMany': 1,
#   'lat': -16.6272015,
#   'lng': 145.3199863,
#   'locId': 'L4803810',
#   'locName': 'Julatten, Jim Weir Road.',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 13:13',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Erythrura trichroa',
#   'speciesCode': 'blfpar3',
#   'subId': 'S177476712'},
#  {'comName': 'Wild Turkey',
#   'exoticCategory': 'P',
#   'howMany': 3,
#   'lat': -35.5929012,
#   'lng': 137.5062561,
#   'locId': 'L1158734',
#   'locName': 'Emu Bay',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 12:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Meleagris gallopavo',
#   'speciesCode': 'wiltur',
#   'subId': 'S177472535'},
#  {'comName': 'Broad-billed Sandpiper',
#   'howMany': 12,
#   'lat': -17.9771,
#   'lng': 122.42084,
#   'locId': 'L989143',
#   'locName': 'Kidney Bean Claypan and Duck Lake',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 12:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calidris falcinellus',
#   'speciesCode': 'brbsan',
#   'subId': 'S177517718'},
#  {'comName': 'Common Ostrich',
#   'exoticCategory': 'X',
#   'howMany': 10,
#   'lat': -33.8371691,
#   'lng': 117.1604712,
#   'locId': 'L3668259',
#   'locName': 'Kojonup',
#   'locationPrivate': False,
#   'obsDt': '2024-05-26 14:22',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Struthio camelus',
#   'speciesCode': 'ostric2',
#   'subId': 'S177178798'},
#  {'comName': 'Dollarbird',
#   'howMany': 1,
#   'lat': -27.13833,
#   'lng': 152.8825,
#   'locId': 'L2558227',
#   'locName': 'Shanley, Morayfield (restricted access)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-26 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eurystomus orientalis',
#   'speciesCode': 'dollar1',
#   'subId': 'S178131237'},
#  {'comName': 'Black-bellied Plover',
#   'howMany': 2,
#   'lat': -22.2948125,
#   'lng': 114.1265234,
#   'locId': 'L32280175',
#   'locName': 'Unnamed Road, Exmouth Gulf, Western Australia, AU (-22.295, '
#              '114.127)Bookings Rest',
#   'locationPrivate': True,
#   'obsDt': '2024-05-25 09:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pluvialis squatarola',
#   'speciesCode': 'bkbplo',
#   'subId': 'S176902114'},
#  {'comName': 'South Polar Skua',
#   'howMany': 1,
#   'lat': -34.8837771,
#   'lng': 118.4046257,
#   'locId': 'L3321508',
#   'locName': 'Cheynes Beach Caravan Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-25 07:00',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Stercorarius maccormicki',
#   'speciesCode': 'sopsku1',
#   'subId': 'S177151736'},
#  {'comName': 'Black Grasswren',
#   'howMany': 3,
#   'lat': -14.8236175,
#   'lng': 125.7051798,
#   'locId': 'L2539862',
#   'locName': 'Mitchell River National Park--general',
#   'locationPrivate': False,
#   'obsDt': '2024-05-25 06:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Amytornis housei',
#   'speciesCode': 'blagra1',
#   'subId': 'S178572008'},
#  {'comName': 'Gray Grasswren',
#   'howMany': 2,
#   'lat': -26.65389,
#   'lng': 139.61667,
#   'locId': 'L32349826',
#   'locName': 'Birdsville track',
#   'locationPrivate': True,
#   'obsDt': '2024-05-23 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Amytornis barbatus',
#   'speciesCode': 'grygra1',
#   'subId': 'S177193033'},
#  {'comName': 'White-faced Robin',
#   'howMany': 2,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eopsaltria leucops',
#   'speciesCode': 'whfrob1',
#   'subId': 'S176095004'},
#  {'comName': 'Tropical Scrubwren',
#   'howMany': 2,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sericornis beccarii',
#   'speciesCode': 'becscr1',
#   'subId': 'S176095004'},
#  {'comName': 'Red-cheeked Parrot',
#   'howMany': 3,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geoffroyus geoffroyi',
#   'speciesCode': 'recpar2',
#   'subId': 'S176095004'},
#  {'comName': 'Satin Flycatcher',
#   'howMany': 1,
#   'lat': -29.5858186,
#   'lng': 152.8418933,
#   'locId': 'L9641752',
#   'locName': 'Whiteman Creek (Private Property)',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 13:16',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Myiagra cyanoleuca',
#   'speciesCode': 'satfly1',
#   'subId': 'S175223653'},
#  {'comName': 'Eastern Yellow Wagtail',
#   'howMany': 1,
#   'lat': -24.8612616,
#   'lng': 113.707006,
#   'locId': 'L31977863',
#   'locName': 'Plantation road verge on highway',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 12:25',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Motacilla tschutschensis',
#   'speciesCode': 'eaywag',
#   'subId': 'S175503341'},
#  {'comName': 'Tahiti Petrel',
#   'howMany': 1,
#   'lat': -27.84132,
#   'lng': 153.93214,
#   'locId': 'L28317038',
#   'locName': 'Auto selected -27.84132, 153.93214',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 11:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pseudobulweria rostrata',
#   'speciesCode': 'tahpet1',
#   'subId': 'S176676068'},
#  {'comName': 'Oriental Plover',
#   'howMany': 1,
#   'lat': -17.9230256,
#   'lng': 122.2651398,
#   'locId': 'L986014',
#   'locName': 'Dampier Creek saltmarsh (The Common)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:07',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Anarhynchus veredus',
#   'speciesCode': 'oriplo1',
#   'subId': 'S175204463'},
#  {'comName': 'Oriental Pratincole',
#   'howMany': 1,
#   'lat': -17.9230256,
#   'lng': 122.2651398,
#   'locId': 'L986014',
#   'locName': 'Dampier Creek saltmarsh (The Common)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glareola maldivarum',
#   'speciesCode': 'oripra',
#   'subId': 'S175204463'},
#  {'comName': 'Green-backed Honeyeater',
#   'howMany': 5,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glycichaera fallax',
#   'speciesCode': 'grbhon1',
#   'subId': 'S176438326'},
#  {'comName': 'Yellow-billed Kingfisher',
#   'howMany': 3,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Syma torotoro',
#   'speciesCode': 'yebkin1',
#   'subId': 'S176438326'},
#  {'comName': 'Northern Scrub-Robin',
#   'howMany': 2,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Drymodes superciliaris',
#   'speciesCode': 'nosrob1',
#   'subId': 'S176438326'},
#  {'comName': 'Scarlet-chested Parrot',
#   'howMany': 2,
#   'lat': -29.474602,
#   'lng': 124.490901,
#   'locId': 'L31875841',
#   'locName': '6431, Plumridge Lakes AU-WA (-29.4746,124.4909)',
#   'locationPrivate': True,
#   'obsDt': '2024-05-17 12:40',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Neophema splendida',
#   'speciesCode': 'sccpar1',
#   'subId': 'S175031406'},
#  {'comName': 'Common Redshank',
#   'howMany': 1,
#   'lat': -17.979327,
#   'lng': 122.336533,
#   'locId': 'L3442562',
#   'locName': 'Wader Spit (Roebuck Bay)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-15 15:24',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Tringa totanus',
#   'speciesCode': 'comred1',
#   'subId': 'S174619127'},
#  {'comName': 'Naretha Bluebonnet',
#   'howMany': 2,
#   'lat': -31.45568,
#   'lng': 129.85827,
#   'locId': 'L2536340',
#   'locName': 'Koonalda Homestead',
#   'locationPrivate': False,
#   'obsDt': '2024-05-15 08:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Northiella narethae',
#   'speciesCode': 'bluebo4',
#   'subId': 'S175606155'}]

# %%
obs_no = (len(response))
print(f"Number of observations in dataset: {obs_no}")
# Out:
# Number of observations in dataset: 697

# %%
#Convert the dataset into a pandas dataframe
birds_df = pd.DataFrame(response)

# %%
#Print the first 10 rows
birds_df.head()
# Out:
#   speciesCode                   comName               sciName     locId  \
# 0     ausibi1           Australian Ibis  Threskiornis molucca  L4004605
# 1     blfhon1     Blue-faced Honeyeater    Entomyzon cyanotis  L4004605
# 2     supfai1          Superb Fairywren       Malurus cyaneus  L4004605
# 3      succoc  Sulphur-crested Cockatoo      Cacatua galerita  L4004605
# 4     wilwag1            Willie-wagtail  Rhipidura leucophrys  L4004605
#
#                                      locName             obsDt  howMany  \
# 0  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      8.0
# 1  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      1.0
# 2  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      2.0
# 3  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      2.0
# 4  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      1.0
#
#          lat         lng  obsValid  obsReviewed  locationPrivate       subId  \
# 0 -33.838293  148.685286      True        False            False  S181144656
# 1 -33.838293  148.685286      True        False            False  S181144656
# 2 -33.838293  148.685286      True        False            False  S181144656
# 3 -33.838293  148.685286      True        False            False  S181144656
# 4 -33.838293  148.685286      True        False            False  S181144656
#
#   exoticCategory
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
#Print column names, data types
column_names = birds_df.columns
print(f"Columns in dataset are: {column_names}")

print(birds_df.describe())
# Out:
# Columns in dataset are: Index(['speciesCode', 'comName', 'sciName', 'locId', 'locName', 'obsDt',
#        'howMany', 'lat', 'lng', 'obsValid', 'obsReviewed', 'locationPrivate',
#        'subId', 'exoticCategory'],
#       dtype='object')
#           howMany         lat         lng
# count  682.000000  697.000000  697.000000
# mean     3.760997  -27.887657  141.786296
# std      6.698460    9.298242   10.900889
# min      1.000000  -43.389269  113.707006
# 25%      1.000000  -34.671939  135.264040
# 50%      2.000000  -29.399942  145.325458
# 75%      3.000000  -17.977100  149.440504
# max     60.000000   -9.347823  159.250560

# %%
#%%capture --no-display

# Configure the map plot
obs_map = birds_df.hvplot.points(
    "lng",
    "lat",
    geo = True,
    tiles = "OSM",
    size = "howMany",
    frame_width = 800,
    frame_height = 600,
    color = "comName",
    alpha = 0.5
)


# Display the map
obs_map = birds_df.hvplot.points(
    "lng",
    "lat",
    geo = True,
    tiles = "OSM",
    size = "howMany",
    frame_width = 800,
    frame_height = 600,
    color = "comName",
    alpha = 0.5
)

# Display the map
obs_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [lng,lat]   (comName,howMany)

# %%
# seperate the bird sighting per state from the map
state_birds = birds_df.groupby("locName").count()["comName"].sort_values(ascending = False)
state_birds.head(10)
# Out:
# locName
# Tasman Sea, Cape Pillar AU-TAS (-43.1992,148.2331)                                               14
# Lachlan River at Carob Bean Avenue, Cowra                                                        14
# Unnamed Road, Boomi, New South Wales, AU (-28.676, 149.441)Koramba, Sth Front, Sth Perimiter.    10
# Charles Eaton Dr, Marrara AU-NT -12.39984, 130.87497                                             10
# 2568, Menangle AU-NSW (-34.1277,150.7113)                                                        10
# Mangroves near Orchard Rd (Coconut Grove)                                                         9
# Lock 9, Murray River                                                                              9
# Palmers Channel North Bank Rd, Palmers Island                                                     9
# Hogwash Bend                                                                                      8
# Surrey Rd                                                                                         7
# Name: comName, dtype: int64

# %%
# total number of observations
birds_df["comName"].nunique()
# Out:
# 697

# %%
birds_df["locName"].nunique()
# Out:
# 396

# %%
location_counts = pd.DataFrame(birds_df["locName"].value_counts()).reset_index()
location_counts
# Out:
#                                                locName  count
# 0    Tasman Sea, Cape Pillar AU-TAS (-43.1992,148.2...     14
# 1            Lachlan River at Carob Bean Avenue, Cowra     14
# 2    Unnamed Road, Boomi, New South Wales, AU (-28....     10
# 3            2568, Menangle AU-NSW (-34.1277,150.7113)     10
# 4    Charles Eaton Dr, Marrara AU-NT -12.39984, 130...     10
# ..                                                 ...    ...
# 391                       LHI25--Balls Pyramid Pelagic      1
# 392  11 Kerr Point Dr, Mission River AU-QLD -12.665...      1
# 393  Warri Park Wetland, Port Douglas Rd, Port Douglas      1
# 394                Eungella National Park--Diggings Rd      1
# 395                 140 Kruckow Rd (Restricted Access)      1
#
# [396 rows x 2 columns]

# %%
#Merge Location Counts df with birds_df to get lat and long for each location
birds_locatoin_df = pd.merge(birds_df, location_counts, how = 'inner', on = "locName")
birds_locatoin_df
# Out:
#     speciesCode                   comName                 sciName      locId  \
# 0       ausibi1           Australian Ibis    Threskiornis molucca   L4004605
# 1       blfhon1     Blue-faced Honeyeater      Entomyzon cyanotis   L4004605
# 2       supfai1          Superb Fairywren         Malurus cyaneus   L4004605
# 3        succoc  Sulphur-crested Cockatoo        Cacatua galerita   L4004605
# 4       wilwag1            Willie-wagtail    Rhipidura leucophrys   L4004605
# ..          ...                       ...                     ...        ...
# 692     grbhon1   Green-backed Honeyeater      Glycichaera fallax   L2038367
# 693     yebkin1  Yellow-billed Kingfisher           Syma torotoro   L2038367
# 694     nosrob1      Northern Scrub-Robin  Drymodes superciliaris   L2038367
# 695     sccpar1    Scarlet-chested Parrot      Neophema splendida  L31875841
# 696     bluebo4        Naretha Bluebonnet     Northiella narethae   L2536340
#
#                                              locName             obsDt  \
# 0          Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22
# 1          Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22
# 2          Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22
# 3          Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22
# 4          Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22
# ..                                               ...               ...
# 692         Kutini-Payamu (Iron Range) National Park  2024-05-18 07:00
# 693         Kutini-Payamu (Iron Range) National Park  2024-05-18 07:00
# 694         Kutini-Payamu (Iron Range) National Park  2024-05-18 07:00
# 695  6431, Plumridge Lakes AU-WA (-29.4746,124.4909)  2024-05-17 12:40
# 696                               Koonalda Homestead  2024-05-15 08:37
#
#      howMany        lat         lng  obsValid  obsReviewed  locationPrivate  \
# 0        8.0 -33.838293  148.685286      True        False            False
# 1        1.0 -33.838293  148.685286      True        False            False
# 2        2.0 -33.838293  148.685286      True        False            False
# 3        2.0 -33.838293  148.685286      True        False            False
# 4        1.0 -33.838293  148.685286      True        False            False
# ..       ...        ...         ...       ...          ...              ...
# 692      5.0 -12.659014  143.347378      True        False            False
# 693      3.0 -12.659014  143.347378      True        False            False
# 694      2.0 -12.659014  143.347378      True        False            False
# 695      2.0 -29.474602  124.490901      True        False             True
# 696      2.0 -31.455680  129.858270      True        False            False
#
#           subId exoticCategory  count
# 0    S181144656            NaN     14
# 1    S181144656            NaN     14
# 2    S181144656            NaN     14
# 3    S181144656            NaN     14
# 4    S181144656            NaN     14
# ..          ...            ...    ...
# 692  S176438326            NaN      3
# 693  S176438326            NaN      3
# 694  S176438326            NaN      3
# 695  S175031406            NaN      1
# 696  S175606155            NaN      1
#
# [697 rows x 15 columns]

# %%
top_ten_locations = birds_locatoin_df.locName.value_counts().nlargest(10)

top_ten_locations_df.hvplot.bar(
    x = "locName",
    y = "count",  # change this to a column that contains numerical data
    title = "Top 10 Bird Observing Locations in Australia",
    xlabel = "Location",
    ylabel = "Number of Observations",
    rot = 90,
    height = 800,
    width = 800
)
# Out:
# :Bars   [locName]   (count)

# %%
# fetch the historical observation data of 2020
url = "https://api.ebird.org/v2/data/obs/AU/recent?back=30"
payload={}
headers = {
  'X-eBirdApiToken': api_key
}
response = requests.request("GET", url, headers=headers, data=payload)
if response.status_code == 200:
    data = response.json()
else:
    print(f"Error: {response.status_code} - {response.text}")
    
  
# Convert the data into a pandas dataframe
birds_df = pd.DataFrame(data)
birds_df.head()
# Out:
#   speciesCode                   comName               sciName     locId  \
# 0     ausibi1           Australian Ibis  Threskiornis molucca  L4004605
# 1     blfhon1     Blue-faced Honeyeater    Entomyzon cyanotis  L4004605
# 2     supfai1          Superb Fairywren       Malurus cyaneus  L4004605
# 3      succoc  Sulphur-crested Cockatoo      Cacatua galerita  L4004605
# 4     wilwag1            Willie-wagtail  Rhipidura leucophrys  L4004605
#
#                                      locName             obsDt  howMany  \
# 0  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      8.0
# 1  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      1.0
# 2  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      2.0
# 3  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      2.0
# 4  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      1.0
#
#          lat         lng  obsValid  obsReviewed  locationPrivate       subId  \
# 0 -33.838293  148.685286      True        False            False  S181144656
# 1 -33.838293  148.685286      True        False            False  S181144656
# 2 -33.838293  148.685286      True        False            False  S181144656
# 3 -33.838293  148.685286      True        False            False  S181144656
# 4 -33.838293  148.685286      True        False            False  S181144656
#
#   exoticCategory
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# scatter plot of last 30 days obseravions for top 10 species by location
top_ten_species = birds_df["comName"].value_counts().nlargest(10).index.tolist()
top_ten_species_df = birds_df[birds_df["comName"].isin(top_ten_species)]
top_ten_species_df.head()
# Out:
#   speciesCode                   comName               sciName     locId  \
# 0     ausibi1           Australian Ibis  Threskiornis molucca  L4004605
# 1     blfhon1     Blue-faced Honeyeater    Entomyzon cyanotis  L4004605
# 2     supfai1          Superb Fairywren       Malurus cyaneus  L4004605
# 3      succoc  Sulphur-crested Cockatoo      Cacatua galerita  L4004605
# 4     wilwag1            Willie-wagtail  Rhipidura leucophrys  L4004605
#
#                                      locName             obsDt  howMany  \
# 0  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      8.0
# 1  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      1.0
# 2  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      2.0
# 3  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      2.0
# 4  Lachlan River at Carob Bean Avenue, Cowra  2024-06-13 16:22      1.0
#
#          lat         lng  obsValid  obsReviewed  locationPrivate       subId  \
# 0 -33.838293  148.685286      True        False            False  S181144656
# 1 -33.838293  148.685286      True        False            False  S181144656
# 2 -33.838293  148.685286      True        False            False  S181144656
# 3 -33.838293  148.685286      True        False            False  S181144656
# 4 -33.838293  148.685286      True        False            False  S181144656
#
#   exoticCategory
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# bar chart of top 10 species by location observed in the last 30 days
top_ten_species_df.hvplot.bar(
    x = "comName",
    y = "howMany",
    title = "Top 10 Bird Species Observed in the Last 30 Days",
    xlabel = "Species",
    ylabel = "Number of Observations",
    rot = 45,
    height = 400,
    width = 800
)
# Out:
# :Bars   [comName]   (howMany)

# %%
# Fetch the list of states in Australia
states_url = 'https://api.ebird.org/v2/ref/region/list/subnational1/AU.json'
states_response = requests.get(states_url, headers=headers)
states = states_response.json()

# For each state, fetch the bird data
for state in states:
    state_code = state['code']
    bird_data_url = f'https://api.ebird.org/v2/data/obs/{state_code}/recent?back=30'
    bird_data_response = requests.get(bird_data_url, headers=headers)
    if bird_data_response.status_code == 200:
        bird_data = bird_data_response.json()
    else:
        print(bird_data_response.status_code)
        print(bird_data_response.text)

# %%
# list of states
states_list = [state['code'] for state in states]
states_list
# Out:
# ['AU-ACT', 'AU-NSW', 'AU-NT', 'AU-QLD', 'AU-SA', 'AU-TAS', 'AU-VIC', 'AU-WA']

# %%
# create a dictionary to store the bird data for each state
birds_data = {}
for state in states:
    state_code = state['code']
    bird_data_url = f'https://api.ebird.org/v2/data/obs/{state_code}/recent?back=30'
    bird_data_response = requests.get(bird_data_url, headers=headers)
    if bird_data_response.status_code == 200:
        bird_data = bird_data_response.json()
        birds_data[state_code] = bird_data
    else:
        print(bird_data_response.status_code)
        print(bird_data_response.text)

# %%
state_counts = {}
for state in birds_data.keys():
    state_counts[state] = len(birds_data[state])
    
state_counts_df = pd.DataFrame.from_dict(state_counts, orient='index', columns=['Observations'])
state_counts_df.reset_index(inplace=True)
state_counts_df.rename(columns={'index': 'State'}, inplace=True)
state_counts_df
# Out:
#     State  Observations
# 0  AU-ACT           162
# 1  AU-NSW           410
# 2   AU-NT           317
# 3  AU-QLD           497
# 4   AU-SA           305
# 5  AU-TAS           186
# 6  AU-VIC           317
# 7   AU-WA           410

# %%
# bar chart of bird observations by state
state_counts_df.hvplot.bar(
    x = "State",
    y = "Observations",
    title = "Bird Observations by State in the Last 30 Days",
    xlabel = "State",
    ylabel = "Number of Observations",
    rot = 45,
    height = 400,
    width = 800,
    color = "red" 
)
# Out:
# :Bars   [State]   (Observations)

# %%
import matplotlib.pyplot as plt

# Assuming state_counts_df is your DataFrame and it has a column 'Observations' with counts of bird observations for each 'State'
data = state_counts_df.set_index('State')['Observations']

plt.figure(figsize=(10,10))
plt.pie(data, labels = data.index, autopct='%1.1f%%')
plt.title('Bird Observations by State')
plt.show()
