# %%
# Import Dependencies
import requests
import json

# Define the API key
api_key = "llhq7n5rh6"

# Import pprint
from pprint import pprint

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import hvplot.pandas

# %%
url = "https://api.ebird.org/v2/data/obs/AU/recent?back=30"
payload={}
headers = {
  'X-eBirdApiToken': api_key
}
response = requests.request("GET", url, headers=headers, data=payload).json()
pprint(response)
# Out:
# [{'comName': 'Great Egret',
#   'howMany': 1,
#   'lat': -27.4440426,
#   'lng': 153.0277249,
#   'locId': 'L5907133',
#   'locName': 'Bowen Bridge Heritage Track',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:46',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardea alba',
#   'speciesCode': 'greegr',
#   'subId': 'S180683658'},
#  {'comName': 'Little Black Cormorant',
#   'howMany': 28,
#   'lat': -27.4440426,
#   'lng': 153.0277249,
#   'locId': 'L5907133',
#   'locName': 'Bowen Bridge Heritage Track',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:46',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phalacrocorax sulcirostris',
#   'speciesCode': 'libcor1',
#   'subId': 'S180683658'},
#  {'comName': 'Crested Pigeon',
#   'howMany': 4,
#   'lat': -35.4075861,
#   'lng': 149.1310302,
#   'locId': 'L9410949',
#   'locName': 'Macarthur ACT yd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ocyphaps lophotes',
#   'speciesCode': 'crepig1',
#   'subId': 'S180685233'},
#  {'comName': 'Crimson Rosella',
#   'howMany': 1,
#   'lat': -35.4075861,
#   'lng': 149.1310302,
#   'locId': 'L9410949',
#   'locName': 'Macarthur ACT yd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platycercus elegans',
#   'speciesCode': 'criros2',
#   'subId': 'S180685233'},
#  {'comName': 'Sulphur-crested Cockatoo',
#   'howMany': 1,
#   'lat': -35.4075861,
#   'lng': 149.1310302,
#   'locId': 'L9410949',
#   'locName': 'Macarthur ACT yd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cacatua galerita',
#   'speciesCode': 'succoc',
#   'subId': 'S180685233'},
#  {'comName': 'Australian Magpie',
#   'howMany': 1,
#   'lat': -35.4075861,
#   'lng': 149.1310302,
#   'locId': 'L9410949',
#   'locName': 'Macarthur ACT yd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gymnorhina tibicen',
#   'speciesCode': 'ausmag2',
#   'subId': 'S180685233'},
#  {'comName': 'Noisy Miner',
#   'howMany': 2,
#   'lat': -35.4075861,
#   'lng': 149.1310302,
#   'locId': 'L9410949',
#   'locName': 'Macarthur ACT yd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanocephala',
#   'speciesCode': 'noimin1',
#   'subId': 'S180685233'},
#  {'comName': 'Silvereye',
#   'howMany': 4,
#   'lat': -35.4075861,
#   'lng': 149.1310302,
#   'locId': 'L9410949',
#   'locName': 'Macarthur ACT yd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zosterops lateralis',
#   'speciesCode': 'silver3',
#   'subId': 'S180685233'},
#  {'comName': 'Powerful Owl',
#   'howMany': 1,
#   'lat': -37.80448,
#   'lng': 144.9715,
#   'locId': 'L2551842',
#   'locName': 'Carlton Gardens',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ninox strenua',
#   'speciesCode': 'powowl1',
#   'subId': 'S180683157'},
#  {'comName': 'Pied Currawong',
#   'howMany': 2,
#   'lat': -35.4075861,
#   'lng': 149.1310302,
#   'locId': 'L9410949',
#   'locName': 'Macarthur ACT yd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Strepera graculina',
#   'speciesCode': 'piecur1',
#   'subId': 'S180685233'},
#  {'comName': 'Australian King-Parrot',
#   'howMany': 1,
#   'lat': -35.4075861,
#   'lng': 149.1310302,
#   'locId': 'L9410949',
#   'locName': 'Macarthur ACT yd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Alisterus scapularis',
#   'speciesCode': 'aukpar1',
#   'subId': 'S180685233'},
#  {'comName': 'Red-tailed Black-Cockatoo',
#   'howMany': 2,
#   'lat': -30.08989,
#   'lng': 145.941,
#   'locId': 'L2535499',
#   'locName': 'Bourke',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calyptorhynchus banksii',
#   'speciesCode': 'rtbcoc1',
#   'subId': 'S180682638'},
#  {'comName': 'Rainbow Lorikeet',
#   'howMany': 1,
#   'lat': -37.8314539,
#   'lng': 145.0698263,
#   'locId': 'L25678047',
#   'locName': 'Riversdale station',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Trichoglossus moluccanus',
#   'speciesCode': 'railor5',
#   'subId': 'S180682739'},
#  {'comName': 'House Sparrow',
#   'exoticCategory': 'N',
#   'howMany': 16,
#   'lat': -42.885308,
#   'lng': 147.319761,
#   'locId': 'L33155023',
#   'locName': 'Bathurst Street, Hobart',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Passer domesticus',
#   'speciesCode': 'houspa',
#   'subId': 'S180684676'},
#  {'comName': 'Gray Fantail',
#   'howMany': 1,
#   'lat': -42.885308,
#   'lng': 147.319761,
#   'locId': 'L33155023',
#   'locName': 'Bathurst Street, Hobart',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura albiscapa',
#   'speciesCode': 'gryfan1',
#   'subId': 'S180684676'},
#  {'comName': 'Forest Raven',
#   'howMany': 3,
#   'lat': -42.885308,
#   'lng': 147.319761,
#   'locId': 'L33155023',
#   'locName': 'Bathurst Street, Hobart',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus tasmanicus',
#   'speciesCode': 'forrav1',
#   'subId': 'S180684676'},
#  {'comName': 'Spotted Dove',
#   'exoticCategory': 'N',
#   'howMany': 2,
#   'lat': -42.885308,
#   'lng': 147.319761,
#   'locId': 'L33155023',
#   'locName': 'Bathurst Street, Hobart',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Spilopelia chinensis',
#   'speciesCode': 'spodov',
#   'subId': 'S180684676'},
#  {'comName': 'European Starling',
#   'exoticCategory': 'N',
#   'howMany': 9,
#   'lat': -42.885308,
#   'lng': 147.319761,
#   'locId': 'L33155023',
#   'locName': 'Bathurst Street, Hobart',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sturnus vulgaris',
#   'speciesCode': 'eursta',
#   'subId': 'S180684676'},
#  {'comName': 'Kelp Gull',
#   'howMany': 4,
#   'lat': -42.885308,
#   'lng': 147.319761,
#   'locId': 'L33155023',
#   'locName': 'Bathurst Street, Hobart',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Larus dominicanus',
#   'speciesCode': 'kelgul',
#   'subId': 'S180684676'},
#  {'comName': 'Eurasian Blackbird',
#   'exoticCategory': 'N',
#   'howMany': 4,
#   'lat': -42.885308,
#   'lng': 147.319761,
#   'locId': 'L33155023',
#   'locName': 'Bathurst Street, Hobart',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Turdus merula',
#   'speciesCode': 'eurbla',
#   'subId': 'S180684676'},
#  {'comName': 'Brown Thornbill',
#   'howMany': 13,
#   'lat': -42.885308,
#   'lng': 147.319761,
#   'locId': 'L33155023',
#   'locName': 'Bathurst Street, Hobart',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acanthiza pusilla',
#   'speciesCode': 'brotho1',
#   'subId': 'S180684676'},
#  {'comName': 'Yellow-tailed Black-Cockatoo',
#   'howMany': 2,
#   'lat': -30.63839,
#   'lng': 151.502342,
#   'locId': 'L33154224',
#   'locName': '55 King St, Uralla AU-NSW -30.63839, 151.50234',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:31',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zanda funerea',
#   'speciesCode': 'ytbcoc1',
#   'subId': 'S180680971'},
#  {'comName': 'European Goldfinch',
#   'exoticCategory': 'N',
#   'howMany': 3,
#   'lat': -42.8977863,
#   'lng': 147.3266441,
#   'locId': 'L5218606',
#   'locName': 'Yard List, Sandy Bay',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:18',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Carduelis carduelis',
#   'speciesCode': 'eurgol',
#   'subId': 'S180681733'},
#  {'comName': 'Yellow Wattlebird',
#   'howMany': 1,
#   'lat': -42.8977863,
#   'lng': 147.3266441,
#   'locId': 'L5218606',
#   'locName': 'Yard List, Sandy Bay',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:18',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anthochaera paradoxa',
#   'speciesCode': 'yelwat1',
#   'subId': 'S180681733'},
#  {'comName': 'Royal Spoonbill',
#   'howMany': 7,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platalea regia',
#   'speciesCode': 'royspo1',
#   'subId': 'S180681090'},
#  {'comName': 'White-faced Heron',
#   'howMany': 3,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Egretta novaehollandiae',
#   'speciesCode': 'whfher1',
#   'subId': 'S180681090'},
#  {'comName': 'Caspian Tern',
#   'howMany': 4,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Hydroprogne caspia',
#   'speciesCode': 'caster1',
#   'subId': 'S180681090'},
#  {'comName': 'Pied Stilt',
#   'howMany': 10,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Himantopus leucocephalus',
#   'speciesCode': 'piesti1',
#   'subId': 'S180681090'},
#  {'comName': 'Black Swan',
#   'howMany': 2,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cygnus atratus',
#   'speciesCode': 'blkswa',
#   'subId': 'S180681090'},
#  {'comName': 'Welcome Swallow',
#   'howMany': 5,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Hirundo neoxena',
#   'speciesCode': 'welswa1',
#   'subId': 'S180681090'},
#  {'comName': 'Little Egret',
#   'howMany': 2,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Egretta garzetta',
#   'speciesCode': 'litegr',
#   'subId': 'S180681090'},
#  {'comName': 'Brahminy Kite',
#   'howMany': 1,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Haliastur indus',
#   'speciesCode': 'brakit1',
#   'subId': 'S180681090'},
#  {'comName': 'Australian Pelican',
#   'howMany': 18,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pelecanus conspicillatus',
#   'speciesCode': 'auspel1',
#   'subId': 'S180681090'},
#  {'comName': 'Australian Ibis',
#   'howMany': 6,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Threskiornis molucca',
#   'speciesCode': 'ausibi1',
#   'subId': 'S180681090'},
#  {'comName': 'Silver Gull',
#   'howMany': 40,
#   'lat': -26.841073,
#   'lng': 153.113133,
#   'locId': 'L33154245',
#   'locName': 'Keith Hill Park, Golden Beach AU-QLD -26.84107, 153.11313',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chroicocephalus novaehollandiae',
#   'speciesCode': 'silgul2',
#   'subId': 'S180681090'},
#  {'comName': 'Australasian Grebe',
#   'howMany': 3,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Tachybaptus novaehollandiae',
#   'speciesCode': 'ausgre1',
#   'subId': 'S180684488'},
#  {'comName': 'Eastern Spinebill',
#   'howMany': 1,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acanthorhynchus tenuirostris',
#   'speciesCode': 'easspi1',
#   'subId': 'S180684488'},
#  {'comName': 'Red Wattlebird',
#   'howMany': 4,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anthochaera carunculata',
#   'speciesCode': 'redwat1',
#   'subId': 'S180684488'},
#  {'comName': 'Gray Butcherbird',
#   'howMany': 1,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cracticus torquatus',
#   'speciesCode': 'grybut1',
#   'subId': 'S180684488'},
#  {'comName': 'Galah',
#   'howMany': 30,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eolophus roseicapilla',
#   'speciesCode': 'galah',
#   'subId': 'S180684488'},
#  {'comName': 'Eurasian Coot',
#   'howMany': 8,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Fulica atra',
#   'speciesCode': 'eurcoo',
#   'subId': 'S180684488'},
#  {'comName': 'Australasian Swamphen',
#   'howMany': 2,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Porphyrio melanotus',
#   'speciesCode': 'purswa6',
#   'subId': 'S180684488'},
#  {'comName': 'Common Myna',
#   'exoticCategory': 'N',
#   'howMany': 5,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acridotheres tristis',
#   'speciesCode': 'commyn',
#   'subId': 'S180684488'},
#  {'comName': 'Bell Miner',
#   'howMany': 10,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanophrys',
#   'speciesCode': 'belmin1',
#   'subId': 'S180684488'},
#  {'comName': 'Golden Whistler',
#   'howMany': 1,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pachycephala pectoralis',
#   'speciesCode': 'golwhi1',
#   'subId': 'S180684488'},
#  {'comName': 'Spotted Pardalote',
#   'howMany': 3,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pardalotus punctatus',
#   'speciesCode': 'spopar1',
#   'subId': 'S180684488'},
#  {'comName': 'Pacific Heron',
#   'howMany': 1,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardea pacifica',
#   'speciesCode': 'pacher1',
#   'subId': 'S180684488'},
#  {'comName': 'Little Wattlebird',
#   'howMany': 1,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anthochaera chrysoptera',
#   'speciesCode': 'bruwat1',
#   'subId': 'S180684488'},
#  {'comName': 'Pacific Black Duck',
#   'howMany': 6,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas superciliosa',
#   'speciesCode': 'pabduc1',
#   'subId': 'S180684488'},
#  {'comName': 'Little Raven',
#   'howMany': 3,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus mellori',
#   'speciesCode': 'litrav1',
#   'subId': 'S180684488'},
#  {'comName': 'Tawny Frogmouth',
#   'howMany': 1,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Podargus strigoides',
#   'speciesCode': 'tawfro1',
#   'subId': 'S180684488'},
#  {'comName': 'New Holland Honeyeater',
#   'howMany': 3,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phylidonyris novaehollandiae',
#   'speciesCode': 'nehhon2',
#   'subId': 'S180684488'},
#  {'comName': 'Dusky Moorhen',
#   'howMany': 1,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gallinula tenebrosa',
#   'speciesCode': 'dusmoo1',
#   'subId': 'S180684488'},
#  {'comName': 'Musk Lorikeet',
#   'howMany': 6,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glossopsitta concinna',
#   'speciesCode': 'muslor1',
#   'subId': 'S180684488'},
#  {'comName': 'Mistletoebird',
#   'howMany': 1,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dicaeum hirundinaceum',
#   'speciesCode': 'mistle1',
#   'subId': 'S180684488'},
#  {'comName': 'Masked Lapwing',
#   'howMany': 2,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Vanellus miles',
#   'speciesCode': 'maslap1',
#   'subId': 'S180684488'},
#  {'comName': 'Superb Fairywren',
#   'howMany': 2,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Malurus cyaneus',
#   'speciesCode': 'supfai1',
#   'subId': 'S180684488'},
#  {'comName': 'Magpie-lark',
#   'howMany': 6,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Grallina cyanoleuca',
#   'speciesCode': 'maglar1',
#   'subId': 'S180684488'},
#  {'comName': 'Gray Teal',
#   'howMany': 2,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas gracilis',
#   'speciesCode': 'gretea1',
#   'subId': 'S180684488'},
#  {'comName': 'White-plumed Honeyeater',
#   'howMany': 2,
#   'lat': -37.7892413,
#   'lng': 144.9508023,
#   'locId': 'L2552179',
#   'locName': 'Royal Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ptilotula penicillata',
#   'speciesCode': 'whphon1',
#   'subId': 'S180684488'},
#  {'comName': 'White-bellied Sea-Eagle',
#   'howMany': 2,
#   'lat': -16.8684645,
#   'lng': 145.6806187,
#   'locId': 'L30652421',
#   'locName': '27 Impey Street, Caravonica, Queensland, AU (-16.868, 145.681)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:14',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Icthyophaga leucogaster',
#   'speciesCode': 'wbseag1',
#   'subId': 'S180678242'},
#  {'comName': 'Red-whiskered Bulbul',
#   'exoticCategory': 'N',
#   'howMany': 3,
#   'lat': -33.33109,
#   'lng': 151.37391,
#   'locId': 'L2537242',
#   'locName': 'Palmdale',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pycnonotus jocosus',
#   'speciesCode': 'rewbul',
#   'subId': 'S180677333'},
#  {'comName': 'Peaceful Dove',
#   'howMany': 1,
#   'lat': -17.3527083,
#   'lng': 145.5946827,
#   'locId': 'L3044538',
#   'locName': 'Malanda',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia placida',
#   'speciesCode': 'peadov1',
#   'subId': 'S180677683'},
#  {'comName': 'Bush Thick-knee',
#   'howMany': 4,
#   'lat': -17.3527083,
#   'lng': 145.5946827,
#   'locId': 'L3044538',
#   'locName': 'Malanda',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 09:06',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Burhinus grallarius',
#   'speciesCode': 'butkne1',
#   'subId': 'S180677683'},
#  {'comName': 'Rock Pigeon',
#   'exoticCategory': 'N',
#   'lat': -33.472497,
#   'lng': 151.321151,
#   'locId': 'L33153207',
#   'locName': '31 Johns Rd, Koolewong AU-NSW -33.47250, 151.32115',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 09:03',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Columba livia',
#   'speciesCode': 'rocpig',
#   'subId': 'S180676275'},
#  {'comName': 'Little Grassbird',
#   'howMany': 5,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Poodytes gramineus',
#   'speciesCode': 'litgra1',
#   'subId': 'S180682694'},
#  {'comName': 'Pied Butcherbird',
#   'howMany': 1,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cracticus nigrogularis',
#   'speciesCode': 'piebut1',
#   'subId': 'S180682694'},
#  {'comName': 'Brown Honeyeater',
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lichmera indistincta',
#   'speciesCode': 'brohon1',
#   'subId': 'S180682694'},
#  {'comName': 'Brown Goshawk',
#   'howMany': 1,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Accipiter fasciatus',
#   'speciesCode': 'brogos1',
#   'subId': 'S180682694'},
#  {'comName': 'Australian Pipit',
#   'howMany': 1,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anthus australis',
#   'speciesCode': 'auspip2',
#   'subId': 'S180682694'},
#  {'comName': 'Red-backed Fairywren',
#   'howMany': 12,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Malurus melanocephalus',
#   'speciesCode': 'rebfai1',
#   'subId': 'S180682694'},
#  {'comName': 'Black-fronted Dotterel',
#   'howMany': 1,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Charadrius melanops',
#   'speciesCode': 'blfdot1',
#   'subId': 'S180682694'},
#  {'comName': 'Buff-banded Rail',
#   'howMany': 1,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gallirallus philippensis',
#   'speciesCode': 'bubrai1',
#   'subId': 'S180682694'},
#  {'comName': 'Striated Pardalote',
#   'howMany': 1,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pardalotus striatus',
#   'speciesCode': 'strpar1',
#   'subId': 'S180682694'},
#  {'comName': 'Double-barred Finch',
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Stizoptera bichenovii',
#   'speciesCode': 'dobfin1',
#   'subId': 'S180682694'},
#  {'comName': 'Willie-wagtail',
#   'howMany': 1,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura leucophrys',
#   'speciesCode': 'wilwag1',
#   'subId': 'S180682694'},
#  {'comName': 'Australasian Darter',
#   'howMany': 1,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anhinga novaehollandiae',
#   'speciesCode': 'darter4',
#   'subId': 'S180682694'},
#  {'comName': 'Brown Quail',
#   'howMany': 1,
#   'lat': -23.67528,
#   'lng': 150.75333,
#   'locId': 'L3019838',
#   'locName': 'Twelve Mile Creek Fishing Reserve (Marmor)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Synoicus ypsilophorus',
#   'speciesCode': 'broqua1',
#   'subId': 'S180682694'},
#  {'comName': 'Inland Thornbill',
#   'howMany': 2,
#   'lat': -23.699539,
#   'lng': 133.827881,
#   'locId': 'L2782364',
#   'locName': 'Alice Springs Desert Park Entrance',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acanthiza apicalis',
#   'speciesCode': 'inltho1',
#   'subId': 'S180682442'},
#  {'comName': 'Rufous Whistler',
#   'howMany': 2,
#   'lat': -23.699539,
#   'lng': 133.827881,
#   'locId': 'L2782364',
#   'locName': 'Alice Springs Desert Park Entrance',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pachycephala rufiventris',
#   'speciesCode': 'rufwhi1',
#   'subId': 'S180682442'},
#  {'comName': 'Black Kite',
#   'howMany': 1,
#   'lat': -23.699539,
#   'lng': 133.827881,
#   'locId': 'L2782364',
#   'locName': 'Alice Springs Desert Park Entrance',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Milvus migrans',
#   'speciesCode': 'blakit1',
#   'subId': 'S180682442'},
#  {'comName': 'Gray Honeyeater',
#   'howMany': 2,
#   'lat': -23.699539,
#   'lng': 133.827881,
#   'locId': 'L2782364',
#   'locName': 'Alice Springs Desert Park Entrance',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Conopophila whitei',
#   'speciesCode': 'gryhon1',
#   'subId': 'S180682442'},
#  {'comName': 'Collared Sparrowhawk',
#   'howMany': 1,
#   'lat': -23.699539,
#   'lng': 133.827881,
#   'locId': 'L2782364',
#   'locName': 'Alice Springs Desert Park Entrance',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Accipiter cirrocephalus',
#   'speciesCode': 'colspa1',
#   'subId': 'S180682442'},
#  {'comName': 'Spiny-cheeked Honeyeater',
#   'howMany': 2,
#   'lat': -23.699539,
#   'lng': 133.827881,
#   'locId': 'L2782364',
#   'locName': 'Alice Springs Desert Park Entrance',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acanthagenys rufogularis',
#   'speciesCode': 'spchon1',
#   'subId': 'S180682442'},
#  {'comName': 'Australian Raven',
#   'howMany': 1,
#   'lat': -33.497646,
#   'lng': 151.30405,
#   'locId': 'L33153021',
#   'locName': '165–179 Railway St, Woy Woy AU-NSW -33.49765, 151.30405',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus coronoides',
#   'speciesCode': 'ausrav1',
#   'subId': 'S180675445'},
#  {'comName': 'Maned Duck',
#   'howMany': 2,
#   'lat': -26.15048,
#   'lng': 152.6293,
#   'locId': 'L2532401',
#   'locName': 'Chatsworth Rest Area',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chenonetta jubata',
#   'speciesCode': 'manduc1',
#   'subId': 'S180676622'},
#  {'comName': 'Australian Ringneck',
#   'howMany': 2,
#   'lat': -23.699539,
#   'lng': 133.827881,
#   'locId': 'L2782364',
#   'locName': 'Alice Springs Desert Park Entrance',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Barnardius zonarius',
#   'speciesCode': 'polpar1',
#   'subId': 'S180682442'},
#  {'comName': 'Little Pied Cormorant',
#   'howMany': 1,
#   'lat': -26.15048,
#   'lng': 152.6293,
#   'locId': 'L2532401',
#   'locName': 'Chatsworth Rest Area',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Microcarbo melanoleucos',
#   'speciesCode': 'lipcor1',
#   'subId': 'S180676622'},
#  {'comName': 'Singing Honeyeater',
#   'howMany': 4,
#   'lat': -23.699539,
#   'lng': 133.827881,
#   'locId': 'L2782364',
#   'locName': 'Alice Springs Desert Park Entrance',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gavicalis virescens',
#   'speciesCode': 'sinhon1',
#   'subId': 'S180682442'},
#  {'comName': 'Cotton Pygmy-Goose',
#   'howMany': 2,
#   'lat': -26.15048,
#   'lng': 152.6293,
#   'locId': 'L2532401',
#   'locName': 'Chatsworth Rest Area',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Nettapus coromandelianus',
#   'speciesCode': 'copgoo1',
#   'subId': 'S180676622'},
#  {'comName': 'Splendid Fairywren',
#   'howMany': 4,
#   'lat': -23.699539,
#   'lng': 133.827881,
#   'locId': 'L2782364',
#   'locName': 'Alice Springs Desert Park Entrance',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Malurus splendens',
#   'speciesCode': 'splfai1',
#   'subId': 'S180682442'},
#  {'comName': 'Whistling Kite',
#   'howMany': 2,
#   'lat': -26.4434705,
#   'lng': 147.538132,
#   'locId': 'L33152829',
#   'locName': '4379 Warrego Highway, Mungallala, Queensland, AU (-26.443, '
#              '147.538)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:52',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Haliastur sphenurus',
#   'speciesCode': 'whikit1',
#   'subId': 'S180674524'},
#  {'comName': 'Brown Falcon',
#   'howMany': 1,
#   'lat': -30.502868,
#   'lng': 151.646765,
#   'locId': 'L33152833',
#   'locName': 'Martin St, Armidale AU-NSW -30.50287, 151.64676',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:52',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Falco berigora',
#   'speciesCode': 'brofal1',
#   'subId': 'S180674539'},
#  {'comName': 'Gang-gang Cockatoo',
#   'howMany': 5,
#   'lat': -33.3283333,
#   'lng': 151.3516667,
#   'locId': 'L11290606',
#   'locName': 'Upper Palmdale',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:50',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Callocephalon fimbriatum',
#   'speciesCode': 'gagcoc1',
#   'subId': 'S180675209'},
#  {'comName': 'Little Corella',
#   'howMany': 2,
#   'lat': -33.3283333,
#   'lng': 151.3516667,
#   'locId': 'L11290606',
#   'locName': 'Upper Palmdale',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:50',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cacatua sanguinea',
#   'speciesCode': 'litcor2',
#   'subId': 'S180675209'},
#  {'comName': 'Long-billed Corella',
#   'exoticCategory': 'N',
#   'howMany': 6,
#   'lat': -33.3283333,
#   'lng': 151.3516667,
#   'locId': 'L11290606',
#   'locName': 'Upper Palmdale',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:50',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cacatua tenuirostris',
#   'speciesCode': 'lobcor1',
#   'subId': 'S180675209'},
#  {'comName': 'Eastern Rosella',
#   'howMany': 2,
#   'lat': -33.3283333,
#   'lng': 151.3516667,
#   'locId': 'L11290606',
#   'locName': 'Upper Palmdale',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:50',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platycercus eximius',
#   'speciesCode': 'easros1',
#   'subId': 'S180675209'},
#  {'comName': 'Topknot Pigeon',
#   'howMany': 190,
#   'lat': -28.004135,
#   'lng': 153.32543,
#   'locId': 'L33152682',
#   'locName': '2 Ewan Ct, Nerang AU-QLD -28.00414, 153.32543',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lopholaimus antarcticus',
#   'speciesCode': 'toppig1',
#   'subId': 'S180673897'},
#  {'comName': 'Scarlet Myzomela',
#   'howMany': 1,
#   'lat': -30.4586368,
#   'lng': 152.8957857,
#   'locId': 'L3861220',
#   'locName': 'Koompartoo Retreat, Bellingen',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:47',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Myzomela sanguinolenta',
#   'speciesCode': 'scamyz1',
#   'subId': 'S180673636'},
#  {'comName': 'Chestnut Teal',
#   'howMany': 10,
#   'lat': -38.06444,
#   'lng': 145.19722,
#   'locId': 'L2547653',
#   'locName': 'Bunurong Memorial Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:42',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas castanea',
#   'speciesCode': 'chetea1',
#   'subId': 'S180681467'},
#  {'comName': 'Red-rumped Parrot',
#   'howMany': 14,
#   'lat': -38.06444,
#   'lng': 145.19722,
#   'locId': 'L2547653',
#   'locName': 'Bunurong Memorial Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:42',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Psephotus haematonotus',
#   'speciesCode': 'rerpar1',
#   'subId': 'S180681467'},
#  {'comName': 'Hoary-headed Grebe',
#   'howMany': 1,
#   'lat': -38.06444,
#   'lng': 145.19722,
#   'locId': 'L2547653',
#   'locName': 'Bunurong Memorial Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:42',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Poliocephalus poliocephalus',
#   'speciesCode': 'hohgre1',
#   'subId': 'S180681467'},
#  {'comName': 'Straw-necked Ibis',
#   'howMany': 7,
#   'lat': -38.06444,
#   'lng': 145.19722,
#   'locId': 'L2547653',
#   'locName': 'Bunurong Memorial Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:42',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Threskiornis spinicollis',
#   'speciesCode': 'stnibi1',
#   'subId': 'S180681467'},
#  {'comName': 'Blue-billed Duck',
#   'howMany': 1,
#   'lat': -38.06444,
#   'lng': 145.19722,
#   'locId': 'L2547653',
#   'locName': 'Bunurong Memorial Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:42',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Oxyura australis',
#   'speciesCode': 'blbduc1',
#   'subId': 'S180681467'},
#  {'comName': 'Pacific Baza',
#   'howMany': 1,
#   'lat': -33.75717,
#   'lng': 150.61594,
#   'locId': 'L2556940',
#   'locName': 'Glenbrook Lagoon',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:41',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Aviceda subcristata',
#   'speciesCode': 'pacbaz1',
#   'subId': 'S180676435'},
#  {'comName': 'Australasian Figbird',
#   'howMany': 2,
#   'lat': -16.9669129,
#   'lng': 145.7381861,
#   'locId': 'L33152288',
#   'locName': '82 Anderson Road, Woree, Queensland, AU (-16.967, 145.738)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sphecotheres vieilloti',
#   'speciesCode': 'ausfig1',
#   'subId': 'S180671942'},
#  {'comName': 'Brolga',
#   'howMany': 2,
#   'lat': -26.4876555,
#   'lng': 147.7997836,
#   'locId': 'L33152787',
#   'locName': 'Warrego Highway, Womalilla, Queensland, AU (-26.488, 147.8)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Antigone rubicunda',
#   'speciesCode': 'brolga1',
#   'subId': 'S180674296'},
#  {'comName': 'Pied Cormorant',
#   'howMany': 5,
#   'lat': -34.181259,
#   'lng': 142.209716,
#   'locId': 'L4758732',
#   'locName': 'River Gardens Tourist Park (Gol Gol)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phalacrocorax varius',
#   'speciesCode': 'piecor1',
#   'subId': 'S180673650'},
#  {'comName': 'Great Cormorant',
#   'howMany': 35,
#   'lat': -34.181259,
#   'lng': 142.209716,
#   'locId': 'L4758732',
#   'locName': 'River Gardens Tourist Park (Gol Gol)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:35',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phalacrocorax carbo',
#   'speciesCode': 'grecor',
#   'subId': 'S180673650'},
#  {'comName': 'Square-tailed Kite',
#   'howMany': 1,
#   'lat': -17.09702,
#   'lng': 145.77473,
#   'locId': 'L33151820',
#   'locName': '71017–71035 Bruce Highway, Gordonvale AU-QLD -17.09702, '
#              '145.77473',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lophoictinia isura',
#   'speciesCode': 'sqtkit1',
#   'subId': 'S180669671'},
#  {'comName': 'Hardhead',
#   'howMany': 2,
#   'lat': -33.8977058,
#   'lng': 151.2341452,
#   'locId': 'L945869',
#   'locName': 'Centennial Park (Sydney)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:18',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Aythya australis',
#   'speciesCode': 'wheduc1',
#   'subId': 'S180676703'},
#  {'comName': 'Laughing Kookaburra',
#   'howMany': 7,
#   'lat': -33.8977058,
#   'lng': 151.2341452,
#   'locId': 'L945869',
#   'locName': 'Centennial Park (Sydney)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:18',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dacelo novaeguineae',
#   'speciesCode': 'laukoo1',
#   'subId': 'S180676703'},
#  {'comName': 'Sahul Sunbird',
#   'howMany': 2,
#   'lat': -19.2731,
#   'lng': 146.74506,
#   'locId': 'L2561111',
#   'locName': 'Mt Louisa',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cinnyris frenatus',
#   'speciesCode': 'olbsun2',
#   'subId': 'S180672370'},
#  {'comName': 'White-gaped Honeyeater',
#   'howMany': 2,
#   'lat': -19.2731,
#   'lng': 146.74506,
#   'locId': 'L2561111',
#   'locName': 'Mt Louisa',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Stomiopera unicolor',
#   'speciesCode': 'whghon1',
#   'subId': 'S180672370'},
#  {'comName': 'Rainbow Bee-eater',
#   'howMany': 2,
#   'lat': -19.2731,
#   'lng': 146.74506,
#   'locId': 'L2561111',
#   'locName': 'Mt Louisa',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Merops ornatus',
#   'speciesCode': 'rabeat1',
#   'subId': 'S180672370'},
#  {'comName': 'Great Bowerbird',
#   'howMany': 2,
#   'lat': -19.2731,
#   'lng': 146.74506,
#   'locId': 'L2561111',
#   'locName': 'Mt Louisa',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:17',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chlamydera nuchalis',
#   'speciesCode': 'grebow1',
#   'subId': 'S180672370'},
#  {'comName': 'Bar-shouldered Dove',
#   'howMany': 2,
#   'lat': -26.368243,
#   'lng': 152.926965,
#   'locId': 'L8573504',
#   'locName': '(-26.3682,152.9270)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia humeralis',
#   'speciesCode': 'basdov1',
#   'subId': 'S180671608'},
#  {'comName': 'Blue-faced Honeyeater',
#   'howMany': 3,
#   'lat': -26.368243,
#   'lng': 152.926965,
#   'locId': 'L8573504',
#   'locName': '(-26.3682,152.9270)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Entomyzon cyanotis',
#   'speciesCode': 'blfhon1',
#   'subId': 'S180671608'},
#  {'comName': "Lewin's Honeyeater",
#   'howMany': 1,
#   'lat': -26.368243,
#   'lng': 152.926965,
#   'locId': 'L8573504',
#   'locName': '(-26.3682,152.9270)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Meliphaga lewinii',
#   'speciesCode': 'lewhon1',
#   'subId': 'S180671608'},
#  {'comName': 'Wonga Pigeon',
#   'howMany': 2,
#   'lat': -26.368243,
#   'lng': 152.926965,
#   'locId': 'L8573504',
#   'locName': '(-26.3682,152.9270)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Leucosarcia melanoleuca',
#   'speciesCode': 'wonpig1',
#   'subId': 'S180671608'},
#  {'comName': 'Torresian Crow',
#   'howMany': 1,
#   'lat': -26.368243,
#   'lng': 152.926965,
#   'locId': 'L8573504',
#   'locName': '(-26.3682,152.9270)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 08:15',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus orru',
#   'speciesCode': 'torcro2',
#   'subId': 'S180671608'},
#  {'comName': 'Yellow Thornbill',
#   'howMany': 1,
#   'lat': -34.6484256,
#   'lng': 150.776968,
#   'locId': 'L1103631',
#   'locName': 'Jamberoo',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:13',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acanthiza nana',
#   'speciesCode': 'yeltho1',
#   'subId': 'S180673671'},
#  {'comName': 'Yellow-faced Honeyeater',
#   'howMany': 1,
#   'lat': -34.6484256,
#   'lng': 150.776968,
#   'locId': 'L1103631',
#   'locName': 'Jamberoo',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:13',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Caligavis chrysops',
#   'speciesCode': 'yefhon1',
#   'subId': 'S180673671'},
#  {'comName': 'Plumed Whistling-Duck',
#   'howMany': 14,
#   'lat': -16.8575359,
#   'lng': 145.693517,
#   'locId': 'L28675084',
#   'locName': 'Botanica Environs',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dendrocygna eytoni',
#   'speciesCode': 'plwduc1',
#   'subId': 'S180668333'},
#  {'comName': 'Plumed Egret',
#   'howMany': 18,
#   'lat': -16.8575359,
#   'lng': 145.693517,
#   'locId': 'L28675084',
#   'locName': 'Botanica Environs',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardea plumifera',
#   'speciesCode': 'integr2',
#   'subId': 'S180668333'},
#  {'comName': 'White-fronted Tern',
#   'howMany': 2,
#   'lat': -31.5464297,
#   'lng': 152.8567931,
#   'locId': 'L5631676',
#   'locName': 'Cathie Creek Estuary',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sterna striata',
#   'speciesCode': 'whfter1',
#   'subId': 'S180667187'},
#  {'comName': 'Great Crested Tern',
#   'howMany': 122,
#   'lat': -31.5464297,
#   'lng': 152.8567931,
#   'locId': 'L5631676',
#   'locName': 'Cathie Creek Estuary',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 08:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Thalasseus bergii',
#   'speciesCode': 'grcter1',
#   'subId': 'S180667187'},
#  {'comName': 'Whimbrel',
#   'howMany': 1,
#   'lat': -16.2623207,
#   'lng': 123.501247,
#   'locId': 'L32477331',
#   'locName': 'Western Australia, AU (-16.262, 123.501)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 07:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Numenius phaeopus',
#   'speciesCode': 'whimbr',
#   'subId': 'S180684189'},
#  {'comName': 'Striated Heron',
#   'howMany': 2,
#   'lat': -16.2623207,
#   'lng': 123.501247,
#   'locId': 'L32477331',
#   'locName': 'Western Australia, AU (-16.262, 123.501)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 07:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Butorides striata',
#   'speciesCode': 'strher',
#   'subId': 'S180684189'},
#  {'comName': 'Pacific Reef-Heron',
#   'howMany': 2,
#   'lat': -16.2623207,
#   'lng': 123.501247,
#   'locId': 'L32477331',
#   'locName': 'Western Australia, AU (-16.262, 123.501)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 07:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Egretta sacra',
#   'speciesCode': 'pacreh1',
#   'subId': 'S180684189'},
#  {'comName': 'Peregrine Falcon',
#   'howMany': 1,
#   'lat': -37.8123,
#   'lng': 144.9623,
#   'locId': 'L1121752',
#   'locName': 'Melbourne CBD',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 07:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Falco peregrinus',
#   'speciesCode': 'perfal',
#   'subId': 'S180666958'},
#  {'comName': 'Great-billed Heron',
#   'howMany': 1,
#   'lat': -16.2623207,
#   'lng': 123.501247,
#   'locId': 'L32477331',
#   'locName': 'Western Australia, AU (-16.262, 123.501)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-11 07:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardea sumatrana',
#   'speciesCode': 'grbher2',
#   'subId': 'S180684189'},
#  {'comName': 'Australian Tern',
#   'howMany': 4,
#   'lat': -16.9182596,
#   'lng': 145.7762807,
#   'locId': 'L3812503',
#   'locName': 'Cairns Esplanade--Southern End',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 07:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gelochelidon macrotarsa',
#   'speciesCode': 'gubter3',
#   'subId': 'S180663329'},
#  {'comName': 'Bar-tailed Godwit',
#   'howMany': 1,
#   'lat': -16.9182596,
#   'lng': 145.7762807,
#   'locId': 'L3812503',
#   'locName': 'Cairns Esplanade--Southern End',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 07:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Limosa lapponica',
#   'speciesCode': 'batgod',
#   'subId': 'S180663329'},
#  {'comName': 'Chestnut-breasted Munia',
#   'howMany': 4,
#   'lat': -16.8642509,
#   'lng': 145.686543,
#   'locId': 'L4780219',
#   'locName': 'Caravonica',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 07:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lonchura castaneothorax',
#   'speciesCode': 'chbmun1',
#   'subId': 'S180679262'},
#  {'comName': 'Helmeted Guineafowl',
#   'exoticCategory': 'X',
#   'howMany': 1,
#   'lat': -16.8642509,
#   'lng': 145.686543,
#   'locId': 'L4780219',
#   'locName': 'Caravonica',
#   'locationPrivate': False,
#   'obsDt': '2024-06-11 07:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Numida meleagris',
#   'speciesCode': 'helgui',
#   'subId': 'S180679262'},
#  {'comName': 'Far Eastern Curlew',
#   'howMany': 10,
#   'lat': -16.9182596,
#   'lng': 145.7762807,
# ...
#   'obsDt': '2024-06-01 09:01',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Psophodes nigrogularis',
#   'speciesCode': 'weswhi1',
#   'subId': 'S178494230'},
#  {'comName': 'Blue-breasted Quail',
#   'howMany': 1,
#   'lat': -27.1158826,
#   'lng': 152.7533282,
#   'locId': 'L10571892',
#   'locName': "Kye's backyard",
#   'locationPrivate': True,
#   'obsDt': '2024-05-30 23:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Synoicus chinensis',
#   'speciesCode': 'blbqua1',
#   'subId': 'S178175225'},
#  {'comName': 'Pacific Koel',
#   'howMany': 1,
#   'lat': -27.93671,
#   'lng': 153.323638,
#   'locId': 'L32561000',
#   'locName': '1 Pago Tce, Pacific Pines AU-QLD -27.93671, 153.32364',
#   'locationPrivate': True,
#   'obsDt': '2024-05-30 12:33',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eudynamys orientalis',
#   'speciesCode': 'asikoe3',
#   'subId': 'S178116301'},
#  {'comName': 'Chestnut-breasted Quail-thrush',
#   'howMany': 1,
#   'lat': -23.476799,
#   'lng': 141.561034,
#   'locId': 'L10064981',
#   'locName': 'Pullen Pullen Reserve (restricted access)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-30 08:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cinclosoma castaneothorax',
#   'speciesCode': 'cbqthr1',
#   'subId': 'S178113965'},
#  {'comName': 'Chestnut-breasted Cuckoo',
#   'howMany': 1,
#   'lat': -16.56237,
#   'lng': 145.38771,
#   'locId': 'L2539396',
#   'locName': 'Euluma Creek Rd, Julatten at -16.56237, 145.38771 (restricted '
#              'access)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-30 08:05',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Cacomantis castaneiventris',
#   'speciesCode': 'chbcuc3',
#   'subId': 'S178112972'},
#  {'comName': 'Black-eared Miner',
#   'howMany': 2,
#   'lat': -33.7056432,
#   'lng': 140.212664,
#   'locId': 'L2557774',
#   'locName': 'Gluepot Reserve--Josies Hideaway (Grasswren Tank)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-30 07:26',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanotis',
#   'speciesCode': 'blemin1',
#   'subId': 'S179834231'},
#  {'comName': 'Egyptian Goose',
#   'exoticCategory': 'X',
#   'howMany': 1,
#   'lat': -26.5250424,
#   'lng': 152.9674081,
#   'locId': 'L5589433',
#   'locName': 'Fairhill Rd Dams at -26.5250, 152.9674 (North Arm)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-29 10:53',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Alopochen aegyptiaca',
#   'speciesCode': 'egygoo',
#   'subId': 'S178087173'},
#  {'comName': 'Fernwren',
#   'howMany': 2,
#   'lat': -17.0367171,
#   'lng': 145.613369,
#   'locId': 'L4879621',
#   'locName': 'Davies Creek National Park--Kahlpahlim Rock Trail carpark',
#   'locationPrivate': False,
#   'obsDt': '2024-05-29 09:41',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Oreoscopus gutturalis',
#   'speciesCode': 'fernwr1',
#   'subId': 'S177913881'},
#  {'comName': 'Northern Shrike-tit',
#   'howMany': 3,
#   'lat': -15.7026,
#   'lng': 126.3786,
#   'locId': 'L1120589',
#   'locName': 'Drysdale River Station',
#   'locationPrivate': False,
#   'obsDt': '2024-05-29 06:30',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Falcunculus whitei',
#   'speciesCode': 'cresht3',
#   'subId': 'S178566492'},
#  {'comName': 'Yellow-rumped Munia',
#   'howMany': 3,
#   'lat': -15.61389,
#   'lng': 130.4075,
#   'locId': 'L2538504',
#   'locName': 'Bradshaw Bridge at -15.61389, 130.4075',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 17:04',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lonchura flaviprymna',
#   'speciesCode': 'yermun1',
#   'subId': 'S177926578'},
#  {'comName': 'Flesh-footed Shearwater',
#   'howMany': 4,
#   'lat': -23.14288,
#   'lng': 113.7751,
#   'locId': 'L2562064',
#   'locName': 'Coral Bay',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 16:56',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardenna carneipes',
#   'speciesCode': 'flfshe',
#   'subId': 'S177754811'},
#  {'comName': 'Common Sandpiper',
#   'howMany': 1,
#   'lat': -20.6296869,
#   'lng': 117.1775308,
#   'locId': 'L7797010',
#   'locName': 'Johns Creek at Point Samson-Roebourne Rd',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 09:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Actitis hypoleucos',
#   'speciesCode': 'comsan',
#   'subId': 'S177721242'},
#  {'comName': 'Western Bristlebird',
#   'howMany': 3,
#   'lat': -34.8850112,
#   'lng': 118.4162621,
#   'locId': 'L921845',
#   'locName': 'Arpenteur Nature Reserve (incl. encompassing trails)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 06:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dasyornis longirostris',
#   'speciesCode': 'wesbri1',
#   'subId': 'S180269365'},
#  {'comName': 'Noisy Scrub-bird',
#   'howMany': 3,
#   'lat': -34.8850112,
#   'lng': 118.4162621,
#   'locId': 'L921845',
#   'locName': 'Arpenteur Nature Reserve (incl. encompassing trails)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 06:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Atrichornis clamosus',
#   'speciesCode': 'nosbir1',
#   'subId': 'S180269365'},
#  {'comName': 'Blue-faced Parrotfinch',
#   'howMany': 1,
#   'lat': -16.6272015,
#   'lng': 145.3199863,
#   'locId': 'L4803810',
#   'locName': 'Julatten, Jim Weir Road.',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 13:13',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Erythrura trichroa',
#   'speciesCode': 'blfpar3',
#   'subId': 'S177476712'},
#  {'comName': 'Wild Turkey',
#   'exoticCategory': 'P',
#   'howMany': 3,
#   'lat': -35.5929012,
#   'lng': 137.5062561,
#   'locId': 'L1158734',
#   'locName': 'Emu Bay',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 12:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Meleagris gallopavo',
#   'speciesCode': 'wiltur',
#   'subId': 'S177472535'},
#  {'comName': 'Broad-billed Sandpiper',
#   'howMany': 12,
#   'lat': -17.9771,
#   'lng': 122.42084,
#   'locId': 'L989143',
#   'locName': 'Kidney Bean Claypan and Duck Lake',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 12:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calidris falcinellus',
#   'speciesCode': 'brbsan',
#   'subId': 'S177517718'},
#  {'comName': 'Common Ostrich',
#   'exoticCategory': 'X',
#   'howMany': 10,
#   'lat': -33.8371691,
#   'lng': 117.1604712,
#   'locId': 'L3668259',
#   'locName': 'Kojonup',
#   'locationPrivate': False,
#   'obsDt': '2024-05-26 14:22',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Struthio camelus',
#   'speciesCode': 'ostric2',
#   'subId': 'S177178798'},
#  {'comName': 'Ashy-bellied White-eye',
#   'howMany': 2,
#   'lat': -9.751633,
#   'lng': 143.40131,
#   'locId': 'L32337768',
#   'locName': 'Auto selected -9.75163, 143.40131',
#   'locationPrivate': True,
#   'obsDt': '2024-05-26 09:31',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zosterops citrinella',
#   'speciesCode': 'asbwhe1',
#   'subId': 'S177142818'},
#  {'comName': 'Dollarbird',
#   'howMany': 1,
#   'lat': -27.13833,
#   'lng': 152.8825,
#   'locId': 'L2558227',
#   'locName': 'Shanley, Morayfield (restricted access)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-26 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eurystomus orientalis',
#   'speciesCode': 'dollar1',
#   'subId': 'S178131237'},
#  {'comName': 'Black-bellied Plover',
#   'howMany': 2,
#   'lat': -22.2948125,
#   'lng': 114.1265234,
#   'locId': 'L32280175',
#   'locName': 'Unnamed Road, Exmouth Gulf, Western Australia, AU (-22.295, '
#              '114.127)Bookings Rest',
#   'locationPrivate': True,
#   'obsDt': '2024-05-25 09:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pluvialis squatarola',
#   'speciesCode': 'bkbplo',
#   'subId': 'S176902114'},
#  {'comName': 'South Polar Skua',
#   'howMany': 1,
#   'lat': -34.8837771,
#   'lng': 118.4046257,
#   'locId': 'L3321508',
#   'locName': 'Cheynes Beach Caravan Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-25 07:00',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Stercorarius maccormicki',
#   'speciesCode': 'sopsku1',
#   'subId': 'S177151736'},
#  {'comName': 'Black Grasswren',
#   'howMany': 3,
#   'lat': -14.8236175,
#   'lng': 125.7051798,
#   'locId': 'L2539862',
#   'locName': 'Mitchell River National Park--general',
#   'locationPrivate': False,
#   'obsDt': '2024-05-25 06:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Amytornis housei',
#   'speciesCode': 'blagra1',
#   'subId': 'S178572008'},
#  {'comName': 'Wandering Tattler',
#   'howMany': 1,
#   'lat': -28.53676,
#   'lng': 153.555828,
#   'locId': 'L31634384',
#   'locName': 'North Head Beach Tk, New Brighton AU-NSW -28.53676, 153.55583',
#   'locationPrivate': True,
#   'obsDt': '2024-05-23 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Tringa incana',
#   'speciesCode': 'wantat1',
#   'subId': 'S176484436'},
#  {'comName': "Hall's Babbler",
#   'howMany': 2,
#   'lat': -25.97666,
#   'lng': 145.02861,
#   'locId': 'L2532502',
#   'locName': 'Mariala National Park at -25.97666, 145.02861',
#   'locationPrivate': False,
#   'obsDt': '2024-05-23 13:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pomatostomus halli',
#   'speciesCode': 'halbab1',
#   'subId': 'S176841184'},
#  {'comName': 'Gray Grasswren',
#   'howMany': 2,
#   'lat': -26.65389,
#   'lng': 139.61667,
#   'locId': 'L32349826',
#   'locName': 'Birdsville track',
#   'locationPrivate': True,
#   'obsDt': '2024-05-23 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Amytornis barbatus',
#   'speciesCode': 'grygra1',
#   'subId': 'S177193033'},
#  {'comName': 'White-streaked Honeyeater',
#   'howMany': 2,
#   'lat': -12.654361,
#   'lng': 143.380291,
#   'locId': 'L32103198',
#   'locName': 'Portland Roads Rd, Iron Range AU-QLD (-12.6544,143.3803)',
#   'locationPrivate': True,
#   'obsDt': '2024-05-21 17:14',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Trichodere cockerelli',
#   'speciesCode': 'whshon1',
#   'subId': 'S176095366'},
#  {'comName': 'Tropical Scrubwren',
#   'howMany': 2,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sericornis beccarii',
#   'speciesCode': 'becscr1',
#   'subId': 'S176095004'},
#  {'comName': 'White-faced Robin',
#   'howMany': 2,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eopsaltria leucops',
#   'speciesCode': 'whfrob1',
#   'subId': 'S176095004'},
#  {'comName': 'Red-cheeked Parrot',
#   'howMany': 3,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geoffroyus geoffroyi',
#   'speciesCode': 'recpar2',
#   'subId': 'S176095004'},
#  {'comName': 'Satin Flycatcher',
#   'howMany': 1,
#   'lat': -29.5858186,
#   'lng': 152.8418933,
#   'locId': 'L9641752',
#   'locName': 'Whiteman Creek (Private Property)',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 13:16',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Myiagra cyanoleuca',
#   'speciesCode': 'satfly1',
#   'subId': 'S175223653'},
#  {'comName': 'Eastern Yellow Wagtail',
#   'howMany': 1,
#   'lat': -24.8612616,
#   'lng': 113.707006,
#   'locId': 'L31977863',
#   'locName': 'Plantation road verge on highway',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 12:25',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Motacilla tschutschensis',
#   'speciesCode': 'eaywag',
#   'subId': 'S175503341'},
#  {'comName': 'Tahiti Petrel',
#   'howMany': 1,
#   'lat': -27.84132,
#   'lng': 153.93214,
#   'locId': 'L28317038',
#   'locName': 'Auto selected -27.84132, 153.93214',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 11:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pseudobulweria rostrata',
#   'speciesCode': 'tahpet1',
#   'subId': 'S176676068'},
#  {'comName': 'Oriental Plover',
#   'howMany': 1,
#   'lat': -17.9230256,
#   'lng': 122.2651398,
#   'locId': 'L986014',
#   'locName': 'Dampier Creek saltmarsh (The Common)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:07',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Anarhynchus veredus',
#   'speciesCode': 'oriplo1',
#   'subId': 'S175204463'},
#  {'comName': 'Oriental Pratincole',
#   'howMany': 1,
#   'lat': -17.9230256,
#   'lng': 122.2651398,
#   'locId': 'L986014',
#   'locName': 'Dampier Creek saltmarsh (The Common)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glareola maldivarum',
#   'speciesCode': 'oripra',
#   'subId': 'S175204463'},
#  {'comName': 'Yellow-billed Kingfisher',
#   'howMany': 3,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Syma torotoro',
#   'speciesCode': 'yebkin1',
#   'subId': 'S176438326'},
#  {'comName': 'Green-backed Honeyeater',
#   'howMany': 5,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glycichaera fallax',
#   'speciesCode': 'grbhon1',
#   'subId': 'S176438326'},
#  {'comName': 'Northern Scrub-Robin',
#   'howMany': 2,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Drymodes superciliaris',
#   'speciesCode': 'nosrob1',
#   'subId': 'S176438326'},
#  {'comName': 'Scarlet-chested Parrot',
#   'howMany': 2,
#   'lat': -29.474602,
#   'lng': 124.490901,
#   'locId': 'L31875841',
#   'locName': '6431, Plumridge Lakes AU-WA (-29.4746,124.4909)',
#   'locationPrivate': True,
#   'obsDt': '2024-05-17 12:40',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Neophema splendida',
#   'speciesCode': 'sccpar1',
#   'subId': 'S175031406'},
#  {'comName': 'Red Goshawk',
#   'howMany': 2,
#   'lat': -14.72832,
#   'lng': 143.63337,
#   'locId': 'L31873853',
#   'locName': 'Lakefield Road',
#   'locationPrivate': True,
#   'obsDt': '2024-05-16 14:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Erythrotriorchis radiatus',
#   'speciesCode': 'redgos1',
#   'subId': 'S175020984'},
#  {'comName': 'Common Redshank',
#   'howMany': 1,
#   'lat': -17.979327,
#   'lng': 122.336533,
#   'locId': 'L3442562',
#   'locName': 'Wader Spit (Roebuck Bay)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-15 15:24',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Tringa totanus',
#   'speciesCode': 'comred1',
#   'subId': 'S174619127'},
#  {'comName': 'Naretha Bluebonnet',
#   'howMany': 2,
#   'lat': -31.45568,
#   'lng': 129.85827,
#   'locId': 'L2536340',
#   'locName': 'Koonalda Homestead',
#   'locationPrivate': False,
#   'obsDt': '2024-05-15 08:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Northiella narethae',
#   'speciesCode': 'bluebo4',
#   'subId': 'S175606155'},
#  {'comName': 'Nullarbor Quail-thrush',
#   'howMany': 1,
#   'lat': -31.4486551,
#   'lng': 130.8969069,
#   'locId': 'L921815',
#   'locName': 'Nullarbor Roadhouse',
#   'locationPrivate': False,
#   'obsDt': '2024-05-13 07:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cinclosoma alisteri',
#   'speciesCode': 'nulqut1',
#   'subId': 'S174121240'},
#  {'comName': 'House Swift',
#   'howMany': 1,
#   'lat': -12.71818,
#   'lng': 130.34869,
#   'locId': 'L2539294',
#   'locName': 'Dundee Beach',
#   'locationPrivate': False,
#   'obsDt': '2024-05-12 17:18',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Apus nipalensis',
#   'speciesCode': 'houswi1',
#   'subId': 'S174810490'}]

# %%
obs_no = (len(response))
print(f"Number of observations in dataset: {obs_no}")
# Out:
# Number of observations in dataset: 698

# %%
#Convert the dataset into a pandas dataframe
birds_df = pd.DataFrame(response)

# %%
#Print the first 10 rows
birds_df.head()
# Out:
#   speciesCode                   comName                     sciName     locId  \
# 0      greegr               Great Egret                  Ardea alba  L5907133
# 1     libcor1    Little Black Cormorant  Phalacrocorax sulcirostris  L5907133
# 2     crepig1            Crested Pigeon           Ocyphaps lophotes  L9410949
# 3     criros2           Crimson Rosella         Platycercus elegans  L9410949
# 4      succoc  Sulphur-crested Cockatoo            Cacatua galerita  L9410949
#
#                        locName             obsDt  howMany        lat  \
# 0  Bowen Bridge Heritage Track  2024-06-11 09:46      1.0 -27.444043
# 1  Bowen Bridge Heritage Track  2024-06-11 09:46     28.0 -27.444043
# 2             Macarthur ACT yd  2024-06-11 09:44      4.0 -35.407586
# 3             Macarthur ACT yd  2024-06-11 09:44      1.0 -35.407586
# 4             Macarthur ACT yd  2024-06-11 09:44      1.0 -35.407586
#
#           lng  obsValid  obsReviewed  locationPrivate       subId  \
# 0  153.027725      True        False            False  S180683658
# 1  153.027725      True        False            False  S180683658
# 2  149.131030      True        False             True  S180685233
# 3  149.131030      True        False             True  S180685233
# 4  149.131030      True        False             True  S180685233
#
#   exoticCategory
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
#Print column names, data types
column_names = birds_df.columns
print(f"Columns in dataset are: {column_names}")

print(birds_df.describe())
# Out:
# Columns in dataset are: Index(['speciesCode', 'comName', 'sciName', 'locId', 'locName', 'obsDt',
#        'howMany', 'lat', 'lng', 'obsValid', 'obsReviewed', 'locationPrivate',
#        'subId', 'exoticCategory'],
#       dtype='object')
#            howMany         lat         lng
# count   690.000000  698.000000  698.000000
# mean      9.120290  -26.645454  140.781722
# std      67.752377    9.381769   11.184043
# min       1.000000  -43.389269  113.707006
# 25%       1.000000  -34.435774  132.313234
# 50%       2.000000  -26.841073  145.127335
# 75%       4.000000  -17.228951  148.233093
# max    1500.000000   -9.347823  159.250560

# %%
#%%capture --no-display

# Configure the map plot
obs_map = birds_df.hvplot.points(
    "lng",
    "lat",
    geo = True,
    tiles = "OSM",
    size = "howMany",
    frame_width = 800,
    frame_height = 600,
    color = "comName",
    alpha = 0.5
)


# Display the map
obs_map = birds_df.hvplot.points(
    "lng",
    "lat",
    geo = True,
    tiles = "OSM",
    size = "howMany",
    frame_width = 800,
    frame_height = 600,
    color = "comName",
    alpha = 0.5
)

# Display the map
obs_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [lng,lat]   (comName,howMany)

# %%
birds_df["comName"].nunique()
# Out:
# 698

# %%
birds_df["locName"].nunique()
# Out:
# 370

# %%
location_counts = pd.DataFrame(birds_df["locName"].value_counts()).reset_index()
location_counts
# Out:
#                                                locName  count
# 0                                           Royal Park     25
# 1                      Rosewood Drive (private access)     19
# 2    Tasman Sea, Cape Pillar AU-TAS (-43.1992,148.2...     16
# 3           Twelve Mile Creek Fishing Reserve (Marmor)     13
# 4                  George Brown Darwin Botanic Gardens     11
# ..                                                 ...    ...
# 365            Broome South Wastewater Treatment Plant      1
# 366                                    King River Road      1
# 367                         Mar del Coral (Australia1)      1
# 368                                      Middleback Rd      1
# 369                        At sea -13.73780, 127.63021      1
#
# [370 rows x 2 columns]

# %%
#Merge Location Counts df with birds_df to get lat and long for each location
birds_locatoin_df = pd.merge(birds_df, location_counts, how = 'inner', on = "locName")
birds_locatoin_df
# Out:
#     speciesCode                   comName                     sciName  \
# 0        greegr               Great Egret                  Ardea alba
# 1       libcor1    Little Black Cormorant  Phalacrocorax sulcirostris
# 2       crepig1            Crested Pigeon           Ocyphaps lophotes
# 3       criros2           Crimson Rosella         Platycercus elegans
# 4        succoc  Sulphur-crested Cockatoo            Cacatua galerita
# ..          ...                       ...                         ...
# 693     redgos1               Red Goshawk   Erythrotriorchis radiatus
# 694     comred1           Common Redshank              Tringa totanus
# 695     bluebo4        Naretha Bluebonnet         Northiella narethae
# 696     nulqut1    Nullarbor Quail-thrush         Cinclosoma alisteri
# 697     houswi1               House Swift             Apus nipalensis
#
#          locId                      locName             obsDt  howMany  \
# 0     L5907133  Bowen Bridge Heritage Track  2024-06-11 09:46      1.0
# 1     L5907133  Bowen Bridge Heritage Track  2024-06-11 09:46     28.0
# 2     L9410949             Macarthur ACT yd  2024-06-11 09:44      4.0
# 3     L9410949             Macarthur ACT yd  2024-06-11 09:44      1.0
# 4     L9410949             Macarthur ACT yd  2024-06-11 09:44      1.0
# ..         ...                          ...               ...      ...
# 693  L31873853               Lakefield Road  2024-05-16 14:00      2.0
# 694   L3442562     Wader Spit (Roebuck Bay)  2024-05-15 15:24      1.0
# 695   L2536340           Koonalda Homestead  2024-05-15 08:37      2.0
# 696    L921815          Nullarbor Roadhouse  2024-05-13 07:59      1.0
# 697   L2539294                 Dundee Beach  2024-05-12 17:18      1.0
#
#            lat         lng  obsValid  obsReviewed  locationPrivate  \
# 0   -27.444043  153.027725      True        False            False
# 1   -27.444043  153.027725      True        False            False
# 2   -35.407586  149.131030      True        False             True
# 3   -35.407586  149.131030      True        False             True
# 4   -35.407586  149.131030      True        False             True
# ..         ...         ...       ...          ...              ...
# 693 -14.728320  143.633370      True        False             True
# 694 -17.979327  122.336533      True        False            False
# 695 -31.455680  129.858270      True        False            False
# 696 -31.448655  130.896907      True        False            False
# 697 -12.718180  130.348690      True         True            False
#
#           subId exoticCategory  count
# 0    S180683658            NaN      2
# 1    S180683658            NaN      2
# 2    S180685233            NaN      8
# 3    S180685233            NaN      8
# 4    S180685233            NaN      8
# ..          ...            ...    ...
# 693  S175020984            NaN      1
# 694  S174619127            NaN      1
# 695  S175606155            NaN      1
# 696  S174121240            NaN      1
# 697  S174810490            NaN      1
#
# [698 rows x 15 columns]

# %%
top_ten_locations_df = location_counts.nlargest(10, 'count')

# bar chart
top_ten_locations_df.hvplot.bar(
    x = "locName",
    y = "count",  # change this to a column that contains numerical data
    title = "Top 10 Bird Observing Locations in Australia",
    xlabel = "Location",
    ylabel = "Number of Observations",
    rot = 45,
    height = 800,
    width = 800
)
# Out:
# :Bars   [locName]   (count)

# %%
# fetch the historical observation data of 2020
url = "https://api.ebird.org/v2/data/obs/AU/recent?back=30"
payload={}
headers = {
  'X-eBirdApiToken': api_key
}
response = requests.request("GET", url, headers=headers, data=payload)
if response.status_code == 200:
    data = response.json()
else:
    print(f"Error: {response.status_code} - {response.text}")
    
  
# Convert the data into a pandas dataframe
birds_df = pd.DataFrame(data)
birds_df.head()
# Out:
#   speciesCode                   comName                     sciName     locId  \
# 0      greegr               Great Egret                  Ardea alba  L5907133
# 1     libcor1    Little Black Cormorant  Phalacrocorax sulcirostris  L5907133
# 2     crepig1            Crested Pigeon           Ocyphaps lophotes  L9410949
# 3     criros2           Crimson Rosella         Platycercus elegans  L9410949
# 4      succoc  Sulphur-crested Cockatoo            Cacatua galerita  L9410949
#
#                        locName             obsDt  howMany        lat  \
# 0  Bowen Bridge Heritage Track  2024-06-11 09:46      1.0 -27.444043
# 1  Bowen Bridge Heritage Track  2024-06-11 09:46     28.0 -27.444043
# 2             Macarthur ACT yd  2024-06-11 09:44      4.0 -35.407586
# 3             Macarthur ACT yd  2024-06-11 09:44      1.0 -35.407586
# 4             Macarthur ACT yd  2024-06-11 09:44      1.0 -35.407586
#
#           lng  obsValid  obsReviewed  locationPrivate       subId  \
# 0  153.027725      True        False            False  S180683658
# 1  153.027725      True        False            False  S180683658
# 2  149.131030      True        False             True  S180685233
# 3  149.131030      True        False             True  S180685233
# 4  149.131030      True        False             True  S180685233
#
#   exoticCategory
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# scatter plot
birds_df.hvplot.scatter(
    x = "obsDt",
    y = "howMany",
    title = "Bird Observations in Australia",
    xlabel = "Date",
    ylabel = "Number of Birds",
    height = 400,
    width = 800
)
# Out:
# :Scatter   [obsDt]   (howMany)

# %%
# scatter plot of last 30 days obseravions for top 10 species by location
top_ten_species = birds_df["comName"].value_counts().nlargest(10).index.tolist()
top_ten_species_df = birds_df[birds_df["comName"].isin(top_ten_species)]
top_ten_species_df.head()
# Out:
#   speciesCode                   comName                     sciName     locId  \
# 0      greegr               Great Egret                  Ardea alba  L5907133
# 1     libcor1    Little Black Cormorant  Phalacrocorax sulcirostris  L5907133
# 2     crepig1            Crested Pigeon           Ocyphaps lophotes  L9410949
# 3     criros2           Crimson Rosella         Platycercus elegans  L9410949
# 4      succoc  Sulphur-crested Cockatoo            Cacatua galerita  L9410949
#
#                        locName             obsDt  howMany        lat  \
# 0  Bowen Bridge Heritage Track  2024-06-11 09:46      1.0 -27.444043
# 1  Bowen Bridge Heritage Track  2024-06-11 09:46     28.0 -27.444043
# 2             Macarthur ACT yd  2024-06-11 09:44      4.0 -35.407586
# 3             Macarthur ACT yd  2024-06-11 09:44      1.0 -35.407586
# 4             Macarthur ACT yd  2024-06-11 09:44      1.0 -35.407586
#
#           lng  obsValid  obsReviewed  locationPrivate       subId  \
# 0  153.027725      True        False            False  S180683658
# 1  153.027725      True        False            False  S180683658
# 2  149.131030      True        False             True  S180685233
# 3  149.131030      True        False             True  S180685233
# 4  149.131030      True        False             True  S180685233
#
#   exoticCategory
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# bar chart of top 10 species by location observed in the last 30 days
top_ten_species_df.hvplot.bar(
    x = "comName",
    y = "howMany",
    title = "Top 10 Bird Species Observed in the Last 30 Days",
    xlabel = "Species",
    ylabel = "Number of Observations",
    rot = 45,
    height = 400,
    width = 800
)
# Out:
# :Bars   [comName]   (howMany)

# %%
#
