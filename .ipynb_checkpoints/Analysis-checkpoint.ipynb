# %%
# Import Dependencies
import requests
import json

# Define the API key
api_key = "llhq7n5rh6"

# Import pprint
from pprint import pprint

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import hvplot.pandas

# %%
# fetch data from eBird_observation_data.csv
file_path = "/Users/vrindapatel/Documents/GitHub/eBird-Data-Visualisation/Resources/eBird_observations_data.csv"
eBird_data = pd.read_csv(file_path)
eBird_data.tail()
# Out:
#     speciesCode                  comName                 sciName      locId  \
# 691     grbhon1  Green-backed Honeyeater      Glycichaera fallax   L2038367
# 692     nosrob1     Northern Scrub-Robin  Drymodes superciliaris   L2038367
# 693     sccpar1   Scarlet-chested Parrot      Neophema splendida  L31875841
# 694     comred1          Common Redshank          Tringa totanus   L3442562
# 695     bluebo4       Naretha Bluebonnet     Northiella narethae   L2536340
#
#                                              locName             obsDt  \
# 691         Kutini-Payamu (Iron Range) National Park  2024-05-18 07:00
# 692         Kutini-Payamu (Iron Range) National Park  2024-05-18 07:00
# 693  6431, Plumridge Lakes AU-WA (-29.4746,124.4909)  2024-05-17 12:40
# 694                         Wader Spit (Roebuck Bay)  2024-05-15 15:24
# 695                               Koonalda Homestead  2024-05-15 08:37
#
#      howMany        lat         lng  obsValid  obsReviewed  locationPrivate  \
# ...

# %%
# get total number of observations
total_observations = eBird_data["comName"].count()
total_observations
# Out:
# 696

# %%
#Print column names, data types
column_names = eBird_data.columns
column_names
# Out:
# Index(['speciesCode', 'comName', 'sciName', 'locId', 'locName', 'obsDt',
#        'howMany', 'lat', 'lng', 'obsValid', 'obsReviewed', 'locationPrivate',
#        'subId', 'formatted_address', 'exoticCategory'],
#       dtype='object')

# %%
#%%capture --no-display

# Configure the map plot
obs_map = eBird_data.hvplot.points(
    "lng",
    "lat",
    geo = True,
    tiles = "OSM",
    size = "howMany",
    frame_width = 800,
    frame_height = 600,
    color = "comName",
    alpha = 0.5
)


# Display the map
obs_map = eBird_data.hvplot.points(
    "lng",
    "lat",
    geo = True,
    tiles = "OSM",
    size = "howMany",
    frame_width = 800,
    frame_height = 600,
    color = "comName",
    alpha = 0.5
)

# Display the map
obs_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [lng,lat]   (comName,howMany)

# %%
location_count = eBird_data["locName"].value_counts()
location_count.head(20)
# Out:
# locName
# Mangroves near Orchard Rd (Coconut Grove)                        36
# Paddock between Kalkarindji and Dagaragu                         18
# Gallet Rd                                                        16
# Tasman Sea, Cape Pillar AU-TAS (-43.1992,148.2331)               14
# 154 Walker Street, Karumba, Queensland, AU (-17.485, 140.841)    13
# Lake Alford Park (Gympie)                                        13
# The Strand                                                       11
# Tarneit Lakes                                                    10
# Lincoln National Park                                             7
# Great Northern Hwy, Mount Magnet AU-WA -28.16138, 117.86651       7
# Central Arnhem Rd at Roper Creek                                  6
# Fogg Dam Conservation Reserve                                     6
# 122 Dan Street, Karalee, Queensland, AU (-27.565, 152.805)        6
# Mount Painter Nature Reserve                                      6
# ...

# %%
# create a bar chart of Top 10 Bird Observing Locations in Australia
location_count.head(10).hvplot.bar(
    x = "locName",
    y = "count",
    title = "Top 20 Locations by Bird Count",
    xlabel = "Location",
    ylabel = "Total Bird Observations",
    rot = 45,
    height = 400,
    width = 800
)
# Out:
# :Bars   [locName]   (count)
