# %%
# Import Dependencies
import requests
import json
import pandas as pd

# Import the API key
from config import eBird_api_key
from config import Google_maps_api_key

#Import pprint
from pprint import pprint

# %%
#call on the eBird API 
url = "https://api.ebird.org/v2/data/obs/AU/recent?back=30"
payload={}
headers = {
  'X-eBirdApiToken': eBird_api_key
}
response = requests.request("GET", url, headers=headers, data=payload).json()

# %%
pprint(response)
# Out:
# [{'comName': 'Tawny Frogmouth',
#   'howMany': 1,
#   'lat': -27.4498303,
#   'lng': 152.9771613,
#   'locId': 'L28355910',
#   'locName': 'Yard List, Ashgrove',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 20:18',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Podargus strigoides',
#   'speciesCode': 'tawfro1',
#   'subId': 'S180932085'},
#  {'comName': 'Large-tailed Nightjar',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Caprimulgus macrurus',
#   'speciesCode': 'latnig2',
#   'subId': 'S180927762'},
#  {'comName': 'Rainbow Bee-eater',
#   'howMany': 3,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Merops ornatus',
#   'speciesCode': 'rabeat1',
#   'subId': 'S180926578'},
#  {'comName': 'Australian Yellow White-eye',
#   'howMany': 3,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zosterops luteus',
#   'speciesCode': 'ayweye3',
#   'subId': 'S180926578'},
#  {'comName': 'Northern Fantail',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura rufiventris',
#   'speciesCode': 'norfan1',
#   'subId': 'S180926578'},
#  {'comName': 'Australasian Figbird',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sphecotheres vieilloti',
#   'speciesCode': 'ausfig1',
#   'subId': 'S180926578'},
#  {'comName': 'Red-winged Parrot',
#   'howMany': 8,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Aprosmictus erythropterus',
#   'speciesCode': 'rewpar1',
#   'subId': 'S180926287'},
#  {'comName': 'Peregrine Falcon',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Falco peregrinus',
#   'speciesCode': 'perfal',
#   'subId': 'S180926287'},
#  {'comName': 'Broad-billed Flycatcher',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Myiagra ruficollis',
#   'speciesCode': 'brbfly1',
#   'subId': 'S180926578'},
#  {'comName': 'Dusky Myzomela',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Myzomela obscura',
#   'speciesCode': 'dusmyz1',
#   'subId': 'S180926578'},
#  {'comName': 'Peaceful Dove',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia placida',
#   'speciesCode': 'peadov1',
#   'subId': 'S180926578'},
#  {'comName': 'Rufous-banded Honeyeater',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Conopophila albogularis',
#   'speciesCode': 'rubhon2',
#   'subId': 'S180926578'},
#  {'comName': 'White-breasted Woodswallow',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Artamus leucorynchus',
#   'speciesCode': 'whbwoo4',
#   'subId': 'S180926578'},
#  {'comName': 'Helmeted Friarbird',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Philemon buceroides',
#   'speciesCode': 'helfri1',
#   'subId': 'S180926578'},
#  {'comName': 'Little Bronze-Cuckoo',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chrysococcyx minutillus',
#   'speciesCode': 'libcuc1',
#   'subId': 'S180926578'},
#  {'comName': 'Orange-footed Megapode',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Megapodius reinwardt',
#   'speciesCode': 'orfscr1',
#   'subId': 'S180926287'},
#  {'comName': 'Black Butcherbird',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melloria quoyi',
#   'speciesCode': 'blabut1',
#   'subId': 'S180926578'},
#  {'comName': 'Arafura Fantail',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura dryas',
#   'speciesCode': 'arafan1',
#   'subId': 'S180926578'},
#  {'comName': 'Shining Flycatcher',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Myiagra alecto',
#   'speciesCode': 'shifly1',
#   'subId': 'S180926578'},
#  {'comName': 'Spangled Drongo',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dicrurus bracteatus',
#   'speciesCode': 'spadro1',
#   'subId': 'S180926578'},
#  {'comName': 'Bar-shouldered Dove',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia humeralis',
#   'speciesCode': 'basdov1',
#   'subId': 'S180926578'},
#  {'comName': 'Little Friarbird',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Philemon citreogularis',
#   'speciesCode': 'litfri1',
#   'subId': 'S180926287'},
#  {'comName': 'Red-headed Myzomela',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Myzomela erythrocephala',
#   'speciesCode': 'rehmyz1',
#   'subId': 'S180926578'},
#  {'comName': 'White-gaped Honeyeater',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Stomiopera unicolor',
#   'speciesCode': 'whghon1',
#   'subId': 'S180926578'},
#  {'comName': 'Red-collared Lorikeet',
#   'howMany': 40,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Trichoglossus rubritorquis',
#   'speciesCode': 'railor7',
#   'subId': 'S180926287'},
#  {'comName': 'Crimson Finch',
#   'howMany': 3,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Neochmia phaeton',
#   'speciesCode': 'crifin1',
#   'subId': 'S180926578'},
#  {'comName': 'Rose-crowned Fruit-Dove',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ptilinopus regina',
#   'speciesCode': 'rcfdov1',
#   'subId': 'S180926578'},
#  {'comName': 'Varied Triller',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lalage leucomela',
#   'speciesCode': 'vartri1',
#   'subId': 'S180926578'},
#  {'comName': 'Brown Honeyeater',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lichmera indistincta',
#   'speciesCode': 'brohon1',
#   'subId': 'S180926287'},
#  {'comName': 'Double-barred Finch',
#   'howMany': 6,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Stizoptera bichenovii',
#   'speciesCode': 'dobfin1',
#   'subId': 'S180926578'},
#  {'comName': 'Plumed Whistling-Duck',
#   'howMany': 1,
#   'lat': -27.5649253,
#   'lng': 152.8051878,
#   'locId': 'L33206976',
#   'locName': '122 Dan Street, Karalee, Queensland, AU (-27.565, 152.805)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 18:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dendrocygna eytoni',
#   'speciesCode': 'plwduc1',
#   'subId': 'S180924258'},
#  {'comName': 'Masked Lapwing',
#   'howMany': 2,
#   'lat': -27.5649253,
#   'lng': 152.8051878,
#   'locId': 'L33206976',
#   'locName': '122 Dan Street, Karalee, Queensland, AU (-27.565, 152.805)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 18:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Vanellus miles',
#   'speciesCode': 'maslap1',
#   'subId': 'S180924258'},
#  {'comName': 'Apostlebird',
#   'howMany': 8,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Struthidea cinerea',
#   'speciesCode': 'apostl1',
#   'subId': 'S180927345'},
#  {'comName': 'Silver-crowned Friarbird',
#   'howMany': 2,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Philemon argenticeps',
#   'speciesCode': 'sicfri1',
#   'subId': 'S180927345'},
#  {'comName': 'Galah',
#   'howMany': 4,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eolophus roseicapilla',
#   'speciesCode': 'galah',
#   'subId': 'S180927345'},
#  {'comName': 'Whistling Kite',
#   'howMany': 1,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Haliastur sphenurus',
#   'speciesCode': 'whikit1',
#   'subId': 'S180927345'},
#  {'comName': 'Nankeen Night Heron',
#   'howMany': 1,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Nycticorax caledonicus',
#   'speciesCode': 'runher1',
#   'subId': 'S180927345'},
#  {'comName': 'Black-faced Cuckooshrike',
#   'howMany': 1,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Coracina novaehollandiae',
#   'speciesCode': 'bkfcus1',
#   'subId': 'S180927345'},
#  {'comName': 'Bush Thick-knee',
#   'howMany': 1,
#   'lat': -27.5649253,
#   'lng': 152.8051878,
#   'locId': 'L33206976',
#   'locName': '122 Dan Street, Karalee, Queensland, AU (-27.565, 152.805)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Burhinus grallarius',
#   'speciesCode': 'butkne1',
#   'subId': 'S180922481'},
#  {'comName': 'Lemon-bellied Flyrobin',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Microeca flavigaster',
#   'speciesCode': 'lebfly3',
#   'subId': 'S180927900'},
#  {'comName': 'Beach Thick-knee',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Esacus magnirostris',
#   'speciesCode': 'beathk1',
#   'subId': 'S180927900'},
#  {'comName': 'Australian Hobby',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Falco longipennis',
#   'speciesCode': 'aushob1',
#   'subId': 'S180927900'},
#  {'comName': 'Sacred Kingfisher',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Todiramphus sanctus',
#   'speciesCode': 'sackin1',
#   'subId': 'S180927900'},
#  {'comName': 'Mangrove Gerygone',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gerygone levigaster',
#   'speciesCode': 'manger1',
#   'subId': 'S180927900'},
#  {'comName': 'Australian Raven',
#   'howMany': 2,
#   'lat': -32.094158,
#   'lng': 115.785864,
#   'locId': 'L10831355',
#   'locName': 'Phoenix Road, Spearwood',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:33',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus coronoides',
#   'speciesCode': 'ausrav1',
#   'subId': 'S180932566'},
#  {'comName': 'Indian Peafowl',
#   'exoticCategory': 'X',
#   'howMany': 1,
#   'lat': -17.1184442,
#   'lng': 145.7052997,
#   'locId': 'L6240566',
#   'locName': 'Gallet Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:31',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pavo cristatus',
#   'speciesCode': 'compea',
#   'subId': 'S180925896'},
#  {'comName': 'Weebill',
#   'howMany': 2,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Smicrornis brevirostris',
#   'speciesCode': 'weebil1',
#   'subId': 'S180942357'},
#  {'comName': 'Singing Bushlark',
#   'howMany': 2,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Mirafra javanica',
#   'speciesCode': 'sinbus6',
#   'subId': 'S180942357'},
#  {'comName': 'Yellow-tinted Honeyeater',
#   'howMany': 4,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ptilotula flavescens',
#   'speciesCode': 'yethon2',
#   'subId': 'S180942357'},
#  {'comName': 'Golden-headed Cisticola',
#   'howMany': 7,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cisticola exilis',
#   'speciesCode': 'gohcis1',
#   'subId': 'S180942357'},
#  {'comName': 'Spinifex Pigeon',
#   'howMany': 24,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geophaps plumifera',
#   'speciesCode': 'spipig2',
#   'subId': 'S180942357'},
#  {'comName': 'Black Kite',
#   'howMany': 7,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Milvus migrans',
#   'speciesCode': 'blakit1',
#   'subId': 'S180942357'},
#  {'comName': 'Black-chinned Honeyeater',
#   'howMany': 2,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melithreptus gularis',
#   'speciesCode': 'blchon2',
#   'subId': 'S180942357'},
#  {'comName': 'Rufous Songlark',
#   'howMany': 1,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cincloramphus mathewsi',
#   'speciesCode': 'rufson1',
#   'subId': 'S180942357'},
#  {'comName': 'Fairy Martin',
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Petrochelidon ariel',
#   'speciesCode': 'faimar2',
#   'subId': 'S180942357'},
#  {'comName': 'Black-faced Woodswallow',
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Artamus cinereus',
#   'speciesCode': 'blfwoo1',
#   'subId': 'S180942357'},
#  {'comName': 'Red-tailed Black-Cockatoo',
#   'howMany': 9,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calyptorhynchus banksii',
#   'speciesCode': 'rtbcoc1',
#   'subId': 'S180942357'},
#  {'comName': 'Willie-wagtail',
#   'howMany': 6,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura leucophrys',
#   'speciesCode': 'wilwag1',
#   'subId': 'S180942357'},
#  {'comName': 'White-winged Triller',
#   'howMany': 8,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lalage tricolor',
#   'speciesCode': 'whwtri1',
#   'subId': 'S180942357'},
#  {'comName': 'Diamond Dove',
#   'howMany': 5,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia cuneata',
#   'speciesCode': 'diadov1',
#   'subId': 'S180942357'},
#  {'comName': 'Brown Quail',
#   'howMany': 9,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Synoicus ypsilophorus',
#   'speciesCode': 'broqua1',
#   'subId': 'S180942357'},
#  {'comName': 'Zebra Finch',
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Taeniopygia guttata',
#   'speciesCode': 'zebfin2',
#   'subId': 'S180942357'},
#  {'comName': 'Crested Pigeon',
#   'howMany': 7,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ocyphaps lophotes',
#   'speciesCode': 'crepig1',
#   'subId': 'S180942357'},
#  {'comName': 'Budgerigar',
#   'howMany': 45,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melopsittacus undulatus',
#   'speciesCode': 'budger',
#   'subId': 'S180942357'},
#  {'comName': 'Rainbow Lorikeet',
#   'howMany': 17,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Trichoglossus moluccanus',
#   'speciesCode': 'railor5',
#   'subId': 'S180923425'},
#  {'comName': 'Blue-faced Honeyeater',
#   'howMany': 12,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Entomyzon cyanotis',
#   'speciesCode': 'blfhon1',
#   'subId': 'S180923425'},
#  {'comName': 'Australian Ibis',
#   'howMany': 11,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Threskiornis molucca',
#   'speciesCode': 'ausibi1',
#   'subId': 'S180923425'},
#  {'comName': 'Australian Magpie',
#   'howMany': 1,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gymnorhina tibicen',
#   'speciesCode': 'ausmag2',
#   'subId': 'S180923425'},
#  {'comName': 'Welcome Swallow',
#   'howMany': 50,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Hirundo neoxena',
#   'speciesCode': 'welswa1',
#   'subId': 'S180923425'},
#  {'comName': 'House Sparrow',
#   'exoticCategory': 'N',
#   'howMany': 2,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Passer domesticus',
#   'speciesCode': 'houspa',
#   'subId': 'S180923425'},
#  {'comName': 'Great Crested Tern',
#   'howMany': 1,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Thalasseus bergii',
#   'speciesCode': 'grcter1',
#   'subId': 'S180923425'},
#  {'comName': 'Silver Gull',
#   'howMany': 42,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chroicocephalus novaehollandiae',
#   'speciesCode': 'silgul2',
#   'subId': 'S180923425'},
#  {'comName': 'Common Myna',
#   'exoticCategory': 'N',
#   'howMany': 3,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acridotheres tristis',
#   'speciesCode': 'commyn',
#   'subId': 'S180923425'},
#  {'comName': 'Great Bowerbird',
#   'howMany': 1,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chlamydera nuchalis',
#   'speciesCode': 'grebow1',
#   'subId': 'S180923425'},
#  {'comName': 'Yellow Honeyeater',
#   'howMany': 2,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Stomiopera flava',
#   'speciesCode': 'yelhon1',
#   'subId': 'S180923425'},
#  {'comName': 'Emu',
#   'howMany': 2,
#   'lat': -34.77021,
#   'lng': 135.93847,
#   'locId': 'L2557479',
#   'locName': 'Lincoln National Park--Stamford Hill',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dromaius novaehollandiae',
#   'speciesCode': 'emu1',
#   'subId': 'S180923490'},
#  {'comName': 'Noisy Miner',
#   'howMany': 4,
#   'lat': -28.070211,
#   'lng': 145.681353,
#   'locId': 'L33210726',
#   'locName': '9 Louise St, Cunnamulla AU-QLD -28.07021, 145.68135',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanocephala',
#   'speciesCode': 'noimin1',
#   'subId': 'S180931970'},
#  {'comName': 'Pied Oystercatcher',
#   'howMany': 2,
#   'lat': -34.77021,
#   'lng': 135.93847,
#   'locId': 'L2557479',
#   'locName': 'Lincoln National Park--Stamford Hill',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Haematopus longirostris',
#   'speciesCode': 'pieoys1',
#   'subId': 'S180923490'},
#  {'comName': 'Osprey',
#   'howMany': 1,
#   'lat': -34.77021,
#   'lng': 135.93847,
#   'locId': 'L2557479',
#   'locName': 'Lincoln National Park--Stamford Hill',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pandion haliaetus',
#   'speciesCode': 'osprey',
#   'subId': 'S180923490'},
#  {'comName': 'Red-rumped Parrot',
#   'howMany': 3,
#   'lat': -28.070211,
#   'lng': 145.681353,
#   'locId': 'L33210726',
#   'locName': '9 Louise St, Cunnamulla AU-QLD -28.07021, 145.68135',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Psephotus haematonotus',
#   'speciesCode': 'rerpar1',
#   'subId': 'S180931970'},
#  {'comName': 'Collared Sparrowhawk',
#   'howMany': 1,
#   'lat': -28.070211,
#   'lng': 145.681353,
#   'locId': 'L33210726',
#   'locName': '9 Louise St, Cunnamulla AU-QLD -28.07021, 145.68135',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Accipiter cirrocephalus',
#   'speciesCode': 'colspa1',
#   'subId': 'S180931970'},
#  {'comName': 'Mangrove Robin',
#   'howMany': 1,
#   'lat': -12.4434808,
#   'lng': 130.877037,
#   'locId': 'L1143268',
#   'locName': 'Charles Darwin National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melanodryas pulverulenta',
#   'speciesCode': 'manrob1',
#   'subId': 'S180925203'},
#  {'comName': 'White-bellied Cuckooshrike',
#   'howMany': 2,
#   'lat': -12.4434808,
#   'lng': 130.877037,
#   'locId': 'L1143268',
#   'locName': 'Charles Darwin National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Coracina papuensis',
#   'speciesCode': 'whbcus1',
#   'subId': 'S180925203'},
#  {'comName': 'Sulphur-crested Cockatoo',
#   'howMany': 2,
#   'lat': -12.4434808,
#   'lng': 130.877037,
#   'locId': 'L1143268',
#   'locName': 'Charles Darwin National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cacatua galerita',
#   'speciesCode': 'succoc',
#   'subId': 'S180925203'},
#  {'comName': 'White-throated Honeyeater',
#   'howMany': 8,
#   'lat': -12.4434808,
#   'lng': 130.877037,
#   'locId': 'L1143268',
#   'locName': 'Charles Darwin National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melithreptus albogularis',
#   'speciesCode': 'whthon1',
#   'subId': 'S180925203'},
#  {'comName': 'Rufous Fieldwren',
#   'howMany': 1,
#   'lat': -31.3799544,
#   'lng': 136.9232799,
#   'locId': 'L33208104',
#   'locName': 'Stuart Highway, Arcoona, South Australia, AU (-31.38, 136.923)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:13',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calamanthus campestris',
#   'speciesCode': 'ruffie2',
#   'subId': 'S180921444'},
#  {'comName': 'Pacific Black Duck',
#   'howMany': 7,
#   'lat': -37.8794669,
#   'lng': 145.1897656,
#   'locId': 'L7817345',
#   'locName': 'Napier Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:12',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas superciliosa',
#   'speciesCode': 'pabduc1',
#   'subId': 'S180922300'},
#  {'comName': 'Rufous-throated Honeyeater',
#   'howMany': 1,
#   'lat': -14.6025,
#   'lng': 132.71172,
#   'locId': 'L2540255',
#   'locName': 'Central Arnhem Rd at -14.60250, 132.71172',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:11',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Conopophila rufogularis',
#   'speciesCode': 'ruthon1',
#   'subId': 'S180927433'},
#  {'comName': 'Pheasant Coucal',
#   'howMany': 1,
#   'lat': -14.6025,
#   'lng': 132.71172,
#   'locId': 'L2540255',
#   'locName': 'Central Arnhem Rd at -14.60250, 132.71172',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:11',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Centropus phasianinus',
#   'speciesCode': 'phecou2',
#   'subId': 'S180927433'},
#  {'comName': 'Magpie-lark',
#   'howMany': 4,
#   'lat': -25.41833,
#   'lng': 142.67361,
#   'locId': 'L2532139',
#   'locName': 'Windorah Nature Trail',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Grallina cyanoleuca',
#   'speciesCode': 'maglar1',
#   'subId': 'S180932748'},
#  {'comName': 'Spotted Harrier',
#   'howMany': 1,
#   'lat': -34.5888418,
#   'lng': 138.5268296,
#   'locId': 'L27222309',
#   'locName': 'Seacomb Road',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Circus assimilis',
#   'speciesCode': 'spohar1',
#   'subId': 'S180922048'},
#  {'comName': 'Jacky-winter',
#   'howMany': 1,
#   'lat': -25.41833,
#   'lng': 142.67361,
#   'locId': 'L2532139',
#   'locName': 'Windorah Nature Trail',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Microeca fascinans',
#   'speciesCode': 'jacwin1',
#   'subId': 'S180932748'},
#  {'comName': 'Pied Butcherbird',
#   'howMany': 2,
#   'lat': -25.41833,
#   'lng': 142.67361,
#   'locId': 'L2532139',
#   'locName': 'Windorah Nature Trail',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cracticus nigrogularis',
#   'speciesCode': 'piebut1',
#   'subId': 'S180932748'},
#  {'comName': 'Australian Pelican',
#   'howMany': 1,
#   'lat': -25.41833,
#   'lng': 142.67361,
#   'locId': 'L2532139',
#   'locName': 'Windorah Nature Trail',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pelecanus conspicillatus',
#   'speciesCode': 'auspel1',
#   'subId': 'S180932748'},
#  {'comName': 'Black Swan',
#   'howMany': 12,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cygnus atratus',
#   'speciesCode': 'blkswa',
#   'subId': 'S180929803'},
#  {'comName': 'Eastern Cattle Egret',
#   'howMany': 6,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Bubulcus coromandus',
#   'speciesCode': 'categr2',
#   'subId': 'S180929803'},
#  {'comName': 'Muscovy Duck',
#   'exoticCategory': 'X',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cairina moschata',
#   'speciesCode': 'musduc',
#   'subId': 'S180929803'},
#  {'comName': 'Magpie Goose',
#   'howMany': 15,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anseranas semipalmata',
#   'speciesCode': 'maggoo1',
#   'subId': 'S180929803'},
#  {'comName': 'Torresian Crow',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus orru',
#   'speciesCode': 'torcro2',
#   'subId': 'S180929803'},
#  {'comName': 'Hardhead',
#   'howMany': 1,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Aythya australis',
#   'speciesCode': 'wheduc1',
#   'subId': 'S180929803'},
#  {'comName': 'Little Black Cormorant',
#   'howMany': 15,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phalacrocorax sulcirostris',
#   'speciesCode': 'libcor1',
#   'subId': 'S180929803'},
#  {'comName': 'Little Pied Cormorant',
#   'howMany': 5,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Microcarbo melanoleucos',
#   'speciesCode': 'lipcor1',
#   'subId': 'S180929803'},
#  {'comName': 'Maned Duck',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chenonetta jubata',
#   'speciesCode': 'manduc1',
#   'subId': 'S180929803'},
#  {'comName': 'Dusky Moorhen',
#   'howMany': 75,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gallinula tenebrosa',
#   'speciesCode': 'dusmoo1',
#   'subId': 'S180929803'},
#  {'comName': 'Mallard',
#   'exoticCategory': 'X',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas platyrhynchos',
#   'speciesCode': 'mallar3',
#   'subId': 'S180929803'},
#  {'comName': 'Australasian Darter',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anhinga novaehollandiae',
#   'speciesCode': 'darter4',
#   'subId': 'S180929803'},
#  {'comName': 'Large-billed Gerygone',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gerygone magnirostris',
#   'speciesCode': 'labger1',
#   'subId': 'S180925002'},
#  {'comName': 'Laughing Kookaburra',
#   'howMany': 1,
#   'lat': -16.4827421,
#   'lng': 145.4641479,
#   'locId': 'L1486336',
#   'locName': 'Port Douglas',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dacelo novaeguineae',
#   'speciesCode': 'laukoo1',
#   'subId': 'S180920393'},
#  {'comName': 'Eastern Rosella',
#   'howMany': 2,
#   'lat': -33.481278,
#   'lng': 150.699726,
#   'locId': 'L25178807',
#   'locName': '285 Cedar Ridge Road Kurrajong (Private Property)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platycercus eximius',
#   'speciesCode': 'easros1',
#   'subId': 'S180919236'},
#  {'comName': 'Rufous Whistler',
#   'howMany': 1,
#   'lat': -18.8947259,
#   'lng': 145.5658865,
#   'locId': 'L4976757',
#   'locName': 'Valley of Lagoons',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pachycephala rufiventris',
#   'speciesCode': 'rufwhi1',
#   'subId': 'S180922850'},
#  {'comName': 'Gray Fantail',
#   'howMany': 5,
#   'lat': -18.8947259,
#   'lng': 145.5658865,
#   'locId': 'L4976757',
#   'locName': 'Valley of Lagoons',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura albiscapa',
#   'speciesCode': 'gryfan1',
#   'subId': 'S180922850'},
#  {'comName': 'Common Bronzewing',
#   'howMany': 5,
#   'lat': -18.8947259,
#   'lng': 145.5658865,
#   'locId': 'L4976757',
#   'locName': 'Valley of Lagoons',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phaps chalcoptera',
#   'speciesCode': 'combro1',
#   'subId': 'S180922850'},
#  {'comName': 'Black-fronted Dotterel',
#   'howMany': 1,
#   'lat': -18.8947259,
#   'lng': 145.5658865,
#   'locId': 'L4976757',
#   'locName': 'Valley of Lagoons',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Charadrius melanops',
#   'speciesCode': 'blfdot1',
#   'subId': 'S180922850'},
#  {'comName': 'Pied Currawong',
#   'howMany': 1,
#   'lat': -18.8947259,
#   'lng': 145.5658865,
#   'locId': 'L4976757',
#   'locName': 'Valley of Lagoons',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Strepera graculina',
#   'speciesCode': 'piecur1',
#   'subId': 'S180922850'},
#  {'comName': 'White-plumed Honeyeater',
#   'howMany': 4,
#   'lat': -23.410878,
#   'lng': 144.2296314,
#   'locId': 'L3131209',
#   'locName': 'Apex Riverside Park Campground, Longreach',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:04',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ptilotula penicillata',
#   'speciesCode': 'whphon1',
#   'subId': 'S180922387'},
#  {'comName': 'Red Junglefowl',
#   'exoticCategory': 'X',
#   'howMany': 14,
#   'lat': -23.410878,
#   'lng': 144.2296314,
#   'locId': 'L3131209',
#   'locName': 'Apex Riverside Park Campground, Longreach',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:04',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Gallus gallus',
#   'speciesCode': 'redjun',
#   'subId': 'S180922387'},
#  {'comName': 'Yellow-tailed Black-Cockatoo',
#   'howMany': 18,
#   'lat': -38.155141,
#   'lng': 144.574799,
#   'locId': 'L10941485',
#   'locName': '65 Dundundra Drive, Clifton Springs AU-VIC (-38.1551,144.5748)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:03',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zanda funerea',
#   'speciesCode': 'ytbcoc1',
#   'subId': 'S180918854'},
#  {'comName': 'Eurasian Coot',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Fulica atra',
#   'speciesCode': 'eurcoo',
#   'subId': 'S180929412'},
#  {'comName': 'Pacific Reef-Heron',
#   'howMany': 1,
#   'lat': -9.5974706,
#   'lng': 143.7603682,
#   'locId': 'L3249529',
#   'locName': 'Darnley Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Egretta sacra',
#   'speciesCode': 'pacreh1',
#   'subId': 'S180921930'},
#  {'comName': 'Eurasian Tree Sparrow',
#   'exoticCategory': 'P',
#   'howMany': 7,
#   'lat': -9.5974706,
#   'lng': 143.7603682,
#   'locId': 'L3249529',
#   'locName': 'Darnley Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Passer montanus',
#   'speciesCode': 'eutspa',
#   'subId': 'S180921930'},
#  {'comName': 'Ashy-bellied White-eye',
#   'howMany': 5,
#   'lat': -9.5974706,
#   'lng': 143.7603682,
#   'locId': 'L3249529',
#   'locName': 'Darnley Island',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zosterops citrinella',
#   'speciesCode': 'asbwhe1',
#   'subId': 'S180921930'},
#  {'comName': 'Superb Fairywren',
#   'howMany': 2,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Malurus cyaneus',
#   'speciesCode': 'supfai1',
#   'subId': 'S180921000'},
#  {'comName': 'Little Raven',
#   'howMany': 14,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus mellori',
#   'speciesCode': 'litrav1',
#   'subId': 'S180921000'},
#  {'comName': 'Red Wattlebird',
#   'howMany': 2,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anthochaera carunculata',
#   'speciesCode': 'redwat1',
#   'subId': 'S180921000'},
#  {'comName': 'Eurasian Blackbird',
#   'exoticCategory': 'N',
#   'howMany': 1,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Turdus merula',
#   'speciesCode': 'eurbla',
#   'subId': 'S180921000'},
#  {'comName': 'Black-shouldered Kite',
#   'howMany': 2,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Elanus axillaris',
#   'speciesCode': 'auskit1',
#   'subId': 'S180921000'},
#  {'comName': 'Rock Pigeon',
#   'exoticCategory': 'N',
#   'howMany': 2,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Columba livia',
#   'speciesCode': 'rocpig',
#   'subId': 'S180921000'},
#  {'comName': 'White-faced Heron',
#   'howMany': 1,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Egretta novaehollandiae',
#   'speciesCode': 'whfher1',
#   'subId': 'S180921000'},
#  {'comName': 'Australasian Swamphen',
#   'howMany': 13,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Porphyrio melanotus',
#   'speciesCode': 'purswa6',
#   'subId': 'S180921000'},
#  {'comName': 'Chestnut Teal',
#   'howMany': 3,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas castanea',
#   'speciesCode': 'chetea1',
#   'subId': 'S180921000'},
#  {'comName': 'White-winged Chough',
#   'howMany': 2,
#   'lat': -29.061182,
#   'lng': 152.017447,
#   'locId': 'L33208015',
#   'locName': '106 Rouse St, Tenterfield AU-NSW -29.06118, 152.01745',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corcorax melanorhamphos',
#   'speciesCode': 'whwcho1',
#   'subId': 'S180921085'},
#  {'comName': 'New Holland Honeyeater',
#   'howMany': 2,
#   'lat': -37.845772,
#   'lng': 144.6865954,
#   'locId': 'L20957691',
#   'locName': 'Tarneit Lakes',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phylidonyris novaehollandiae',
#   'speciesCode': 'nehhon2',
#   'subId': 'S180921000'},
#  {'comName': 'White-browed Scrubwren',
#   'howMany': 1,
#   'lat': -35.3524671,
#   'lng': 138.6203639,
#   'locId': 'L1206398',
#   'locName': 'Mount Compass Wetlands',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 16:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sericornis frontalis',
#   'speciesCode': 'whbscr1',
#   'subId': 'S180941166'},
#  {'comName': 'European Starling',
#   'exoticCategory': 'N',
#   'howMany': 4,
#   'lat': -35.3524671,
#   'lng': 138.6203639,
#   'locId': 'L1206398',
#   'locName': 'Mount Compass Wetlands',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 16:59',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sturnus vulgaris',
#   'speciesCode': 'eursta',
#   'subId': 'S180941166'},
#  {'comName': 'Crimson Rosella',
#   'howMany': 2,
#   'lat': -35.3524671,
#   'lng': 138.6203639,
#   'locId': 'L1206398',
# ...
#   'obsDt': '2024-06-04 09:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Turnix castanotus',
#   'speciesCode': 'chbbut2',
#   'subId': 'S179285162'},
#  {'comName': 'Little x Long-billed Corella (hybrid)',
#   'howMany': 2,
#   'lat': -33.82288,
#   'lng': 151.14666,
#   'locId': 'L2555918',
#   'locName': 'Lane Cove National Park--Boronia Park to Buffalo Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-04 08:00',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Cacatua sanguinea x tenuirostris',
#   'speciesCode': 'x00806',
#   'subId': 'S179274639'},
#  {'comName': 'Kimberley Honeyeater',
#   'howMany': 2,
#   'lat': -14.1283333,
#   'lng': 126.3091667,
#   'locId': 'L17211408',
#   'locName': 'Vansittart Bay (C53 wreck)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-03 09:34',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Territornis fordiana',
#   'speciesCode': 'kimhon1',
#   'subId': 'S179072412'},
#  {'comName': 'White-winged Tern',
#   'howMany': 1,
#   'lat': -17.9746307,
#   'lng': 122.2218919,
#   'locId': 'L985449',
#   'locName': 'Broome South Wastewater Treatment Plant',
#   'locationPrivate': False,
#   'obsDt': '2024-06-03 08:41',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chlidonias leucopterus',
#   'speciesCode': 'whwter',
#   'subId': 'S179076967'},
#  {'comName': 'Bridled Tern',
#   'howMany': 1,
#   'lat': -9.347823,
#   'lng': 143.6731,
#   'locId': 'L32722596',
#   'locName': 'Mar del Coral (Australia1)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-02 17:46',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Onychoprion anaethetus',
#   'speciesCode': 'briter1',
#   'subId': 'S178809195'},
#  {'comName': 'Copperback Quail-thrush',
#   'howMany': 3,
#   'lat': -33.1695538,
#   'lng': 137.0407968,
#   'locId': 'L23506153',
#   'locName': 'Middleback Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-02 13:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cinclosoma clarum',
#   'speciesCode': 'copqut1',
#   'subId': 'S178814719'},
#  {'comName': 'Streaked Shearwater',
#   'howMany': 3,
#   'lat': -13.737797,
#   'lng': 127.630206,
#   'locId': 'L32722766',
#   'locName': 'At sea -13.73780, 127.63021',
#   'locationPrivate': True,
#   'obsDt': '2024-06-02 10:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calonectris leucomelas',
#   'speciesCode': 'strshe',
#   'subId': 'S178809875'},
#  {'comName': "Salvin's Albatross",
#   'howMany': 1,
#   'lat': -43.0906763,
#   'lng': 148.3212687,
#   'locId': 'L1163813',
#   'locName': 'Eaglehawk Neck Pelagic Trip',
#   'locationPrivate': False,
#   'obsDt': '2024-06-02 07:28',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Thalassarche salvini',
#   'speciesCode': 'salalb1',
#   'subId': 'S179321107'},
#  {'comName': 'Sooty Tern',
#   'lat': -12.2390223,
#   'lng': 122.9802258,
#   'locId': 'L32572461',
#   'locName': 'Ashmore Reef (-12.239, 122.98)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-01 13:27',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Onychoprion fuscatus',
#   'speciesCode': 'sooter1',
#   'subId': 'S179333397'},
#  {'comName': 'Western Whipbird',
#   'howMany': 1,
#   'lat': -34.826937,
#   'lng': 135.847265,
#   'locId': 'L32647962',
#   'locName': '956 Wanna Rd, Lincoln National Park AU-SA -34.82694, 135.84727',
#   'locationPrivate': True,
#   'obsDt': '2024-06-01 09:01',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Psophodes nigrogularis',
#   'speciesCode': 'weswhi1',
#   'subId': 'S178494230'},
#  {'comName': 'Blue-breasted Quail',
#   'howMany': 1,
#   'lat': -27.1158826,
#   'lng': 152.7533282,
#   'locId': 'L10571892',
#   'locName': "Kye's backyard",
#   'locationPrivate': True,
#   'obsDt': '2024-05-30 23:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Synoicus chinensis',
#   'speciesCode': 'blbqua1',
#   'subId': 'S178175225'},
#  {'comName': 'Pacific Koel',
#   'howMany': 1,
#   'lat': -27.93671,
#   'lng': 153.323638,
#   'locId': 'L32561000',
#   'locName': '1 Pago Tce, Pacific Pines AU-QLD -27.93671, 153.32364',
#   'locationPrivate': True,
#   'obsDt': '2024-05-30 12:33',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eudynamys orientalis',
#   'speciesCode': 'asikoe3',
#   'subId': 'S178116301'},
#  {'comName': 'Chestnut-breasted Cuckoo',
#   'howMany': 1,
#   'lat': -16.56237,
#   'lng': 145.38771,
#   'locId': 'L2539396',
#   'locName': 'Euluma Creek Rd, Julatten at -16.56237, 145.38771 (restricted '
#              'access)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-30 08:05',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Cacomantis castaneiventris',
#   'speciesCode': 'chbcuc3',
#   'subId': 'S178112972'},
#  {'comName': 'Black-eared Miner',
#   'howMany': 2,
#   'lat': -33.7056432,
#   'lng': 140.212664,
#   'locId': 'L2557774',
#   'locName': 'Gluepot Reserve--Josies Hideaway (Grasswren Tank)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-30 07:26',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanotis',
#   'speciesCode': 'blemin1',
#   'subId': 'S179834231'},
#  {'comName': 'Egyptian Goose',
#   'exoticCategory': 'X',
#   'howMany': 1,
#   'lat': -26.5250424,
#   'lng': 152.9674081,
#   'locId': 'L5589433',
#   'locName': 'Fairhill Rd Dams at -26.5250, 152.9674 (North Arm)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-29 10:53',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Alopochen aegyptiaca',
#   'speciesCode': 'egygoo',
#   'subId': 'S178087173'},
#  {'comName': 'Northern Shrike-tit',
#   'howMany': 3,
#   'lat': -15.7026,
#   'lng': 126.3786,
#   'locId': 'L1120589',
#   'locName': 'Drysdale River Station',
#   'locationPrivate': False,
#   'obsDt': '2024-05-29 06:30',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Falcunculus whitei',
#   'speciesCode': 'cresht3',
#   'subId': 'S178566492'},
#  {'comName': 'Yellow-rumped Munia',
#   'howMany': 3,
#   'lat': -15.61389,
#   'lng': 130.4075,
#   'locId': 'L2538504',
#   'locName': 'Bradshaw Bridge at -15.61389, 130.4075',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 17:04',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lonchura flaviprymna',
#   'speciesCode': 'yermun1',
#   'subId': 'S177926578'},
#  {'comName': 'Flesh-footed Shearwater',
#   'howMany': 4,
#   'lat': -23.14288,
#   'lng': 113.7751,
#   'locId': 'L2562064',
#   'locName': 'Coral Bay',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 16:56',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardenna carneipes',
#   'speciesCode': 'flfshe',
#   'subId': 'S177754811'},
#  {'comName': 'Common Sandpiper',
#   'howMany': 1,
#   'lat': -20.6296869,
#   'lng': 117.1775308,
#   'locId': 'L7797010',
#   'locName': 'Johns Creek at Point Samson-Roebourne Rd',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 09:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Actitis hypoleucos',
#   'speciesCode': 'comsan',
#   'subId': 'S177721242'},
#  {'comName': 'Western Bristlebird',
#   'howMany': 3,
#   'lat': -34.8850112,
#   'lng': 118.4162621,
#   'locId': 'L921845',
#   'locName': 'Arpenteur Nature Reserve (incl. encompassing trails)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 06:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dasyornis longirostris',
#   'speciesCode': 'wesbri1',
#   'subId': 'S180269365'},
#  {'comName': 'Noisy Scrub-bird',
#   'howMany': 3,
#   'lat': -34.8850112,
#   'lng': 118.4162621,
#   'locId': 'L921845',
#   'locName': 'Arpenteur Nature Reserve (incl. encompassing trails)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 06:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Atrichornis clamosus',
#   'speciesCode': 'nosbir1',
#   'subId': 'S180269365'},
#  {'comName': 'Blue-faced Parrotfinch',
#   'howMany': 1,
#   'lat': -16.6272015,
#   'lng': 145.3199863,
#   'locId': 'L4803810',
#   'locName': 'Julatten, Jim Weir Road.',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 13:13',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Erythrura trichroa',
#   'speciesCode': 'blfpar3',
#   'subId': 'S177476712'},
#  {'comName': 'Wild Turkey',
#   'exoticCategory': 'P',
#   'howMany': 3,
#   'lat': -35.5929012,
#   'lng': 137.5062561,
#   'locId': 'L1158734',
#   'locName': 'Emu Bay',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 12:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Meleagris gallopavo',
#   'speciesCode': 'wiltur',
#   'subId': 'S177472535'},
#  {'comName': 'Broad-billed Sandpiper',
#   'howMany': 12,
#   'lat': -17.9771,
#   'lng': 122.42084,
#   'locId': 'L989143',
#   'locName': 'Kidney Bean Claypan and Duck Lake',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 12:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calidris falcinellus',
#   'speciesCode': 'brbsan',
#   'subId': 'S177517718'},
#  {'comName': 'Common Ostrich',
#   'exoticCategory': 'X',
#   'howMany': 10,
#   'lat': -33.8371691,
#   'lng': 117.1604712,
#   'locId': 'L3668259',
#   'locName': 'Kojonup',
#   'locationPrivate': False,
#   'obsDt': '2024-05-26 14:22',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Struthio camelus',
#   'speciesCode': 'ostric2',
#   'subId': 'S177178798'},
#  {'comName': 'Dollarbird',
#   'howMany': 1,
#   'lat': -27.13833,
#   'lng': 152.8825,
#   'locId': 'L2558227',
#   'locName': 'Shanley, Morayfield (restricted access)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-26 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eurystomus orientalis',
#   'speciesCode': 'dollar1',
#   'subId': 'S178131237'},
#  {'comName': 'Black-bellied Plover',
#   'howMany': 2,
#   'lat': -22.2948125,
#   'lng': 114.1265234,
#   'locId': 'L32280175',
#   'locName': 'Unnamed Road, Exmouth Gulf, Western Australia, AU (-22.295, '
#              '114.127)Bookings Rest',
#   'locationPrivate': True,
#   'obsDt': '2024-05-25 09:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pluvialis squatarola',
#   'speciesCode': 'bkbplo',
#   'subId': 'S176902114'},
#  {'comName': 'South Polar Skua',
#   'howMany': 1,
#   'lat': -34.8837771,
#   'lng': 118.4046257,
#   'locId': 'L3321508',
#   'locName': 'Cheynes Beach Caravan Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-25 07:00',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Stercorarius maccormicki',
#   'speciesCode': 'sopsku1',
#   'subId': 'S177151736'},
#  {'comName': 'Black Grasswren',
#   'howMany': 3,
#   'lat': -14.8236175,
#   'lng': 125.7051798,
#   'locId': 'L2539862',
#   'locName': 'Mitchell River National Park--general',
#   'locationPrivate': False,
#   'obsDt': '2024-05-25 06:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Amytornis housei',
#   'speciesCode': 'blagra1',
#   'subId': 'S178572008'},
#  {'comName': 'Gray Grasswren',
#   'howMany': 2,
#   'lat': -26.65389,
#   'lng': 139.61667,
#   'locId': 'L32349826',
#   'locName': 'Birdsville track',
#   'locationPrivate': True,
#   'obsDt': '2024-05-23 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Amytornis barbatus',
#   'speciesCode': 'grygra1',
#   'subId': 'S177193033'},
#  {'comName': 'White-faced Robin',
#   'howMany': 2,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eopsaltria leucops',
#   'speciesCode': 'whfrob1',
#   'subId': 'S176095004'},
#  {'comName': 'Red-cheeked Parrot',
#   'howMany': 3,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geoffroyus geoffroyi',
#   'speciesCode': 'recpar2',
#   'subId': 'S176095004'},
#  {'comName': 'Tropical Scrubwren',
#   'howMany': 2,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sericornis beccarii',
#   'speciesCode': 'becscr1',
#   'subId': 'S176095004'},
#  {'comName': 'Satin Flycatcher',
#   'howMany': 1,
#   'lat': -29.5858186,
#   'lng': 152.8418933,
#   'locId': 'L9641752',
#   'locName': 'Whiteman Creek (Private Property)',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 13:16',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Myiagra cyanoleuca',
#   'speciesCode': 'satfly1',
#   'subId': 'S175223653'},
#  {'comName': 'Eastern Yellow Wagtail',
#   'howMany': 1,
#   'lat': -24.8612616,
#   'lng': 113.707006,
#   'locId': 'L31977863',
#   'locName': 'Plantation road verge on highway',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 12:25',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Motacilla tschutschensis',
#   'speciesCode': 'eaywag',
#   'subId': 'S175503341'},
#  {'comName': 'Tahiti Petrel',
#   'howMany': 1,
#   'lat': -27.84132,
#   'lng': 153.93214,
#   'locId': 'L28317038',
#   'locName': 'Auto selected -27.84132, 153.93214',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 11:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pseudobulweria rostrata',
#   'speciesCode': 'tahpet1',
#   'subId': 'S176676068'},
#  {'comName': 'Oriental Pratincole',
#   'howMany': 1,
#   'lat': -17.9230256,
#   'lng': 122.2651398,
#   'locId': 'L986014',
#   'locName': 'Dampier Creek saltmarsh (The Common)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glareola maldivarum',
#   'speciesCode': 'oripra',
#   'subId': 'S175204463'},
#  {'comName': 'Oriental Plover',
#   'howMany': 1,
#   'lat': -17.9230256,
#   'lng': 122.2651398,
#   'locId': 'L986014',
#   'locName': 'Dampier Creek saltmarsh (The Common)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:07',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Anarhynchus veredus',
#   'speciesCode': 'oriplo1',
#   'subId': 'S175204463'},
#  {'comName': 'Yellow-billed Kingfisher',
#   'howMany': 3,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Syma torotoro',
#   'speciesCode': 'yebkin1',
#   'subId': 'S176438326'},
#  {'comName': 'Green-backed Honeyeater',
#   'howMany': 5,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glycichaera fallax',
#   'speciesCode': 'grbhon1',
#   'subId': 'S176438326'},
#  {'comName': 'Northern Scrub-Robin',
#   'howMany': 2,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Drymodes superciliaris',
#   'speciesCode': 'nosrob1',
#   'subId': 'S176438326'},
#  {'comName': 'Scarlet-chested Parrot',
#   'howMany': 2,
#   'lat': -29.474602,
#   'lng': 124.490901,
#   'locId': 'L31875841',
#   'locName': '6431, Plumridge Lakes AU-WA (-29.4746,124.4909)',
#   'locationPrivate': True,
#   'obsDt': '2024-05-17 12:40',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Neophema splendida',
#   'speciesCode': 'sccpar1',
#   'subId': 'S175031406'},
#  {'comName': 'Common Redshank',
#   'howMany': 1,
#   'lat': -17.979327,
#   'lng': 122.336533,
#   'locId': 'L3442562',
#   'locName': 'Wader Spit (Roebuck Bay)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-15 15:24',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Tringa totanus',
#   'speciesCode': 'comred1',
#   'subId': 'S174619127'},
#  {'comName': 'Naretha Bluebonnet',
#   'howMany': 2,
#   'lat': -31.45568,
#   'lng': 129.85827,
#   'locId': 'L2536340',
#   'locName': 'Koonalda Homestead',
#   'locationPrivate': False,
#   'obsDt': '2024-05-15 08:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Northiella narethae',
#   'speciesCode': 'bluebo4',
#   'subId': 'S175606155'}]

# %%
obs_no = (len(response))
print(f"Number of observations in dataset: {obs_no}")
# Out:
# Number of observations in dataset: 696

# %%
# Create an empty list to store merged data
merged_data = []

# Iterate through each observation in the eBird API response
for observation in response:
    lat = observation['lat']
    lng = observation['lng']

    # Construct the URL for the reverse geocoding request
    url = f'https://maps.googleapis.com/maps/api/geocode/json?latlng={lat},{lng}&key={Google_maps_api_key}'

    # Make a GET request to the Google Maps Geocoding API
    geocoding_response = requests.get(url).json()

    # Extract the formatted address from the response
    if 'results' in geocoding_response and len(geocoding_response['results']) > 0:
        formatted_address = geocoding_response['results'][0]['formatted_address']

        # Create a new dictionary combining eBird observation data and formatted address
        merged_observation = observation.copy()  # Copy all original observation data
        merged_observation['formatted_address'] = formatted_address  # Add the formatted address

        # Append the merged observation to the list
        merged_data.append(merged_observation)

# Pretty print the merged data for inspection
pprint(merged_data)
# Out:
# [{'comName': 'Tawny Frogmouth',
#   'formatted_address': '220B Coopers Camp Rd, Ashgrove QLD 4060, Australia',
#   'howMany': 1,
#   'lat': -27.4498303,
#   'lng': 152.9771613,
#   'locId': 'L28355910',
#   'locName': 'Yard List, Ashgrove',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 20:18',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Podargus strigoides',
#   'speciesCode': 'tawfro1',
#   'subId': 'S180932085'},
#  {'comName': 'Large-tailed Nightjar',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:58',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Caprimulgus macrurus',
#   'speciesCode': 'latnig2',
#   'subId': 'S180927762'},
#  {'comName': 'Rainbow Bee-eater',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 3,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Merops ornatus',
#   'speciesCode': 'rabeat1',
#   'subId': 'S180926578'},
#  {'comName': 'Australian Yellow White-eye',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 3,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zosterops luteus',
#   'speciesCode': 'ayweye3',
#   'subId': 'S180926578'},
#  {'comName': 'Northern Fantail',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura rufiventris',
#   'speciesCode': 'norfan1',
#   'subId': 'S180926578'},
#  {'comName': 'Australasian Figbird',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sphecotheres vieilloti',
#   'speciesCode': 'ausfig1',
#   'subId': 'S180926578'},
#  {'comName': 'Red-winged Parrot',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 8,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Aprosmictus erythropterus',
#   'speciesCode': 'rewpar1',
#   'subId': 'S180926287'},
#  {'comName': 'Peregrine Falcon',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Falco peregrinus',
#   'speciesCode': 'perfal',
#   'subId': 'S180926287'},
#  {'comName': 'Broad-billed Flycatcher',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Myiagra ruficollis',
#   'speciesCode': 'brbfly1',
#   'subId': 'S180926578'},
#  {'comName': 'Dusky Myzomela',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Myzomela obscura',
#   'speciesCode': 'dusmyz1',
#   'subId': 'S180926578'},
#  {'comName': 'Peaceful Dove',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia placida',
#   'speciesCode': 'peadov1',
#   'subId': 'S180926578'},
#  {'comName': 'Rufous-banded Honeyeater',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Conopophila albogularis',
#   'speciesCode': 'rubhon2',
#   'subId': 'S180926578'},
#  {'comName': 'White-breasted Woodswallow',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Artamus leucorynchus',
#   'speciesCode': 'whbwoo4',
#   'subId': 'S180926578'},
#  {'comName': 'Helmeted Friarbird',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Philemon buceroides',
#   'speciesCode': 'helfri1',
#   'subId': 'S180926578'},
#  {'comName': 'Little Bronze-Cuckoo',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chrysococcyx minutillus',
#   'speciesCode': 'libcuc1',
#   'subId': 'S180926578'},
#  {'comName': 'Orange-footed Megapode',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Megapodius reinwardt',
#   'speciesCode': 'orfscr1',
#   'subId': 'S180926287'},
#  {'comName': 'Black Butcherbird',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melloria quoyi',
#   'speciesCode': 'blabut1',
#   'subId': 'S180926578'},
#  {'comName': 'Arafura Fantail',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura dryas',
#   'speciesCode': 'arafan1',
#   'subId': 'S180926578'},
#  {'comName': 'Shining Flycatcher',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Myiagra alecto',
#   'speciesCode': 'shifly1',
#   'subId': 'S180926578'},
#  {'comName': 'Spangled Drongo',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dicrurus bracteatus',
#   'speciesCode': 'spadro1',
#   'subId': 'S180926578'},
#  {'comName': 'Bar-shouldered Dove',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia humeralis',
#   'speciesCode': 'basdov1',
#   'subId': 'S180926578'},
#  {'comName': 'Little Friarbird',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Philemon citreogularis',
#   'speciesCode': 'litfri1',
#   'subId': 'S180926287'},
#  {'comName': 'Red-headed Myzomela',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Myzomela erythrocephala',
#   'speciesCode': 'rehmyz1',
#   'subId': 'S180926578'},
#  {'comName': 'White-gaped Honeyeater',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Stomiopera unicolor',
#   'speciesCode': 'whghon1',
#   'subId': 'S180926578'},
#  {'comName': 'Red-collared Lorikeet',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 40,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Trichoglossus rubritorquis',
#   'speciesCode': 'railor7',
#   'subId': 'S180926287'},
#  {'comName': 'Crimson Finch',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 3,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Neochmia phaeton',
#   'speciesCode': 'crifin1',
#   'subId': 'S180926578'},
#  {'comName': 'Rose-crowned Fruit-Dove',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ptilinopus regina',
#   'speciesCode': 'rcfdov1',
#   'subId': 'S180926578'},
#  {'comName': 'Varied Triller',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lalage leucomela',
#   'speciesCode': 'vartri1',
#   'subId': 'S180926578'},
#  {'comName': 'Brown Honeyeater',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lichmera indistincta',
#   'speciesCode': 'brohon1',
#   'subId': 'S180926287'},
#  {'comName': 'Double-barred Finch',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 6,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 18:36',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Stizoptera bichenovii',
#   'speciesCode': 'dobfin1',
#   'subId': 'S180926578'},
#  {'comName': 'Plumed Whistling-Duck',
#   'formatted_address': '122 Dan St, Karalee QLD 4306, Australia',
#   'howMany': 1,
#   'lat': -27.5649253,
#   'lng': 152.8051878,
#   'locId': 'L33206976',
#   'locName': '122 Dan Street, Karalee, Queensland, AU (-27.565, 152.805)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 18:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dendrocygna eytoni',
#   'speciesCode': 'plwduc1',
#   'subId': 'S180924258'},
#  {'comName': 'Masked Lapwing',
#   'formatted_address': '122 Dan St, Karalee QLD 4306, Australia',
#   'howMany': 2,
#   'lat': -27.5649253,
#   'lng': 152.8051878,
#   'locId': 'L33206976',
#   'locName': '122 Dan Street, Karalee, Queensland, AU (-27.565, 152.805)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 18:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Vanellus miles',
#   'speciesCode': 'maslap1',
#   'subId': 'S180924258'},
#  {'comName': 'Apostlebird',
#   'formatted_address': 'State Route 24, Beswick Creek NT 0852, Australia',
#   'howMany': 8,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Struthidea cinerea',
#   'speciesCode': 'apostl1',
#   'subId': 'S180927345'},
#  {'comName': 'Silver-crowned Friarbird',
#   'formatted_address': 'State Route 24, Beswick Creek NT 0852, Australia',
#   'howMany': 2,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Philemon argenticeps',
#   'speciesCode': 'sicfri1',
#   'subId': 'S180927345'},
#  {'comName': 'Galah',
#   'formatted_address': 'State Route 24, Beswick Creek NT 0852, Australia',
#   'howMany': 4,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eolophus roseicapilla',
#   'speciesCode': 'galah',
#   'subId': 'S180927345'},
#  {'comName': 'Whistling Kite',
#   'formatted_address': 'State Route 24, Beswick Creek NT 0852, Australia',
#   'howMany': 1,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Haliastur sphenurus',
#   'speciesCode': 'whikit1',
#   'subId': 'S180927345'},
#  {'comName': 'Nankeen Night Heron',
#   'formatted_address': 'State Route 24, Beswick Creek NT 0852, Australia',
#   'howMany': 1,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Nycticorax caledonicus',
#   'speciesCode': 'runher1',
#   'subId': 'S180927345'},
#  {'comName': 'Black-faced Cuckooshrike',
#   'formatted_address': 'State Route 24, Beswick Creek NT 0852, Australia',
#   'howMany': 1,
#   'lat': -14.63673,
#   'lng': 132.68574,
#   'locId': 'L2540242',
#   'locName': 'Central Arnhem Rd at Roper Creek',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:48',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Coracina novaehollandiae',
#   'speciesCode': 'bkfcus1',
#   'subId': 'S180927345'},
#  {'comName': 'Bush Thick-knee',
#   'formatted_address': '122 Dan St, Karalee QLD 4306, Australia',
#   'howMany': 1,
#   'lat': -27.5649253,
#   'lng': 152.8051878,
#   'locId': 'L33206976',
#   'locName': '122 Dan Street, Karalee, Queensland, AU (-27.565, 152.805)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:45',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Burhinus grallarius',
#   'speciesCode': 'butkne1',
#   'subId': 'S180922481'},
#  {'comName': 'Lemon-bellied Flyrobin',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 4,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Microeca flavigaster',
#   'speciesCode': 'lebfly3',
#   'subId': 'S180927900'},
#  {'comName': 'Beach Thick-knee',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Esacus magnirostris',
#   'speciesCode': 'beathk1',
#   'subId': 'S180927900'},
#  {'comName': 'Australian Hobby',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Falco longipennis',
#   'speciesCode': 'aushob1',
#   'subId': 'S180927900'},
#  {'comName': 'Sacred Kingfisher',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Todiramphus sanctus',
#   'speciesCode': 'sackin1',
#   'subId': 'S180927900'},
#  {'comName': 'Mangrove Gerygone',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 1,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:44',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gerygone levigaster',
#   'speciesCode': 'manger1',
#   'subId': 'S180927900'},
#  {'comName': 'Australian Raven',
#   'formatted_address': '25 Glendower Way, Spearwood WA 6163, Australia',
#   'howMany': 2,
#   'lat': -32.094158,
#   'lng': 115.785864,
#   'locId': 'L10831355',
#   'locName': 'Phoenix Road, Spearwood',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:33',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus coronoides',
#   'speciesCode': 'ausrav1',
#   'subId': 'S180932566'},
#  {'comName': 'Indian Peafowl',
#   'exoticCategory': 'X',
#   'formatted_address': '66 Gallett Rd, Little Mulgrave QLD 4865, Australia',
#   'howMany': 1,
#   'lat': -17.1184442,
#   'lng': 145.7052997,
#   'locId': 'L6240566',
#   'locName': 'Gallet Rd',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:31',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pavo cristatus',
#   'speciesCode': 'compea',
#   'subId': 'S180925896'},
#  {'comName': 'Weebill',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 2,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Smicrornis brevirostris',
#   'speciesCode': 'weebil1',
#   'subId': 'S180942357'},
#  {'comName': 'Singing Bushlark',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 2,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Mirafra javanica',
#   'speciesCode': 'sinbus6',
#   'subId': 'S180942357'},
#  {'comName': 'Yellow-tinted Honeyeater',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 4,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ptilotula flavescens',
#   'speciesCode': 'yethon2',
#   'subId': 'S180942357'},
#  {'comName': 'Golden-headed Cisticola',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 7,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cisticola exilis',
#   'speciesCode': 'gohcis1',
#   'subId': 'S180942357'},
#  {'comName': 'Spinifex Pigeon',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 24,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geophaps plumifera',
#   'speciesCode': 'spipig2',
#   'subId': 'S180942357'},
#  {'comName': 'Black Kite',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 7,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Milvus migrans',
#   'speciesCode': 'blakit1',
#   'subId': 'S180942357'},
#  {'comName': 'Black-chinned Honeyeater',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 2,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melithreptus gularis',
#   'speciesCode': 'blchon2',
#   'subId': 'S180942357'},
#  {'comName': 'Rufous Songlark',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 1,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cincloramphus mathewsi',
#   'speciesCode': 'rufson1',
#   'subId': 'S180942357'},
#  {'comName': 'Fairy Martin',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Petrochelidon ariel',
#   'speciesCode': 'faimar2',
#   'subId': 'S180942357'},
#  {'comName': 'Black-faced Woodswallow',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Artamus cinereus',
#   'speciesCode': 'blfwoo1',
#   'subId': 'S180942357'},
#  {'comName': 'Red-tailed Black-Cockatoo',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 9,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calyptorhynchus banksii',
#   'speciesCode': 'rtbcoc1',
#   'subId': 'S180942357'},
#  {'comName': 'Willie-wagtail',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 6,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura leucophrys',
#   'speciesCode': 'wilwag1',
#   'subId': 'S180942357'},
#  {'comName': 'White-winged Triller',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 8,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lalage tricolor',
#   'speciesCode': 'whwtri1',
#   'subId': 'S180942357'},
#  {'comName': 'Diamond Dove',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 5,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geopelia cuneata',
#   'speciesCode': 'diadov1',
#   'subId': 'S180942357'},
#  {'comName': 'Brown Quail',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 9,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Synoicus ypsilophorus',
#   'speciesCode': 'broqua1',
#   'subId': 'S180942357'},
#  {'comName': 'Zebra Finch',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Taeniopygia guttata',
#   'speciesCode': 'zebfin2',
#   'subId': 'S180942357'},
#  {'comName': 'Crested Pigeon',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 7,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ocyphaps lophotes',
#   'speciesCode': 'crepig1',
#   'subId': 'S180942357'},
#  {'comName': 'Budgerigar',
#   'formatted_address': 'HR9H+F7 Kalkarindji NT, Australia',
#   'howMany': 45,
#   'lat': -17.4313577,
#   'lng': 130.8282356,
#   'locId': 'L33212831',
#   'locName': 'Paddock between Kalkarindji and Dagaragu',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melopsittacus undulatus',
#   'speciesCode': 'budger',
#   'subId': 'S180942357'},
#  {'comName': 'Rainbow Lorikeet',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 17,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Trichoglossus moluccanus',
#   'speciesCode': 'railor5',
#   'subId': 'S180923425'},
#  {'comName': 'Blue-faced Honeyeater',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 12,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Entomyzon cyanotis',
#   'speciesCode': 'blfhon1',
#   'subId': 'S180923425'},
#  {'comName': 'Australian Ibis',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 11,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Threskiornis molucca',
#   'speciesCode': 'ausibi1',
#   'subId': 'S180923425'},
#  {'comName': 'Australian Magpie',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 1,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gymnorhina tibicen',
#   'speciesCode': 'ausmag2',
#   'subId': 'S180923425'},
#  {'comName': 'Welcome Swallow',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 50,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Hirundo neoxena',
#   'speciesCode': 'welswa1',
#   'subId': 'S180923425'},
#  {'comName': 'House Sparrow',
#   'exoticCategory': 'N',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 2,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Passer domesticus',
#   'speciesCode': 'houspa',
#   'subId': 'S180923425'},
#  {'comName': 'Great Crested Tern',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 1,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Thalasseus bergii',
#   'speciesCode': 'grcter1',
#   'subId': 'S180923425'},
#  {'comName': 'Silver Gull',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 42,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chroicocephalus novaehollandiae',
#   'speciesCode': 'silgul2',
#   'subId': 'S180923425'},
#  {'comName': 'Common Myna',
#   'exoticCategory': 'N',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 3,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Acridotheres tristis',
#   'speciesCode': 'commyn',
#   'subId': 'S180923425'},
#  {'comName': 'Great Bowerbird',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 1,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chlamydera nuchalis',
#   'speciesCode': 'grebow1',
#   'subId': 'S180923425'},
#  {'comName': 'Yellow Honeyeater',
#   'formatted_address': '79 The Strand, North Ward QLD 4810, Australia',
#   'howMany': 2,
#   'lat': -19.24705,
#   'lng': 146.81229,
#   'locId': 'L2561299',
#   'locName': 'The Strand',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:25',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Stomiopera flava',
#   'speciesCode': 'yelhon1',
#   'subId': 'S180923425'},
#  {'comName': 'Emu',
#   'formatted_address': '6WHQ+W9 Lincoln National Park SA, Australia',
#   'howMany': 2,
#   'lat': -34.77021,
#   'lng': 135.93847,
#   'locId': 'L2557479',
#   'locName': 'Lincoln National Park--Stamford Hill',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dromaius novaehollandiae',
#   'speciesCode': 'emu1',
#   'subId': 'S180923490'},
#  {'comName': 'Noisy Miner',
#   'formatted_address': '10 Garden St, Cunnamulla QLD 4490, Australia',
#   'howMany': 4,
#   'lat': -28.070211,
#   'lng': 145.681353,
#   'locId': 'L33210726',
#   'locName': '9 Louise St, Cunnamulla AU-QLD -28.07021, 145.68135',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanocephala',
#   'speciesCode': 'noimin1',
#   'subId': 'S180931970'},
#  {'comName': 'Pied Oystercatcher',
#   'formatted_address': '6WHQ+W9 Lincoln National Park SA, Australia',
#   'howMany': 2,
#   'lat': -34.77021,
#   'lng': 135.93847,
#   'locId': 'L2557479',
#   'locName': 'Lincoln National Park--Stamford Hill',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Haematopus longirostris',
#   'speciesCode': 'pieoys1',
#   'subId': 'S180923490'},
#  {'comName': 'Osprey',
#   'formatted_address': '6WHQ+W9 Lincoln National Park SA, Australia',
#   'howMany': 1,
#   'lat': -34.77021,
#   'lng': 135.93847,
#   'locId': 'L2557479',
#   'locName': 'Lincoln National Park--Stamford Hill',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pandion haliaetus',
#   'speciesCode': 'osprey',
#   'subId': 'S180923490'},
#  {'comName': 'Red-rumped Parrot',
#   'formatted_address': '10 Garden St, Cunnamulla QLD 4490, Australia',
#   'howMany': 3,
#   'lat': -28.070211,
#   'lng': 145.681353,
#   'locId': 'L33210726',
#   'locName': '9 Louise St, Cunnamulla AU-QLD -28.07021, 145.68135',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Psephotus haematonotus',
#   'speciesCode': 'rerpar1',
#   'subId': 'S180931970'},
#  {'comName': 'Collared Sparrowhawk',
#   'formatted_address': '10 Garden St, Cunnamulla QLD 4490, Australia',
#   'howMany': 1,
#   'lat': -28.070211,
#   'lng': 145.681353,
#   'locId': 'L33210726',
#   'locName': '9 Louise St, Cunnamulla AU-QLD -28.07021, 145.68135',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Accipiter cirrocephalus',
#   'speciesCode': 'colspa1',
#   'subId': 'S180931970'},
#  {'comName': 'Mangrove Robin',
#   'formatted_address': 'Charles Darwin Np Access, Charles Darwin NT 0822, '
#                        'Australia',
#   'howMany': 1,
#   'lat': -12.4434808,
#   'lng': 130.877037,
#   'locId': 'L1143268',
#   'locName': 'Charles Darwin National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melanodryas pulverulenta',
#   'speciesCode': 'manrob1',
#   'subId': 'S180925203'},
#  {'comName': 'White-bellied Cuckooshrike',
#   'formatted_address': 'Charles Darwin Np Access, Charles Darwin NT 0822, '
#                        'Australia',
#   'howMany': 2,
#   'lat': -12.4434808,
#   'lng': 130.877037,
#   'locId': 'L1143268',
#   'locName': 'Charles Darwin National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Coracina papuensis',
#   'speciesCode': 'whbcus1',
#   'subId': 'S180925203'},
#  {'comName': 'Sulphur-crested Cockatoo',
#   'formatted_address': 'Charles Darwin Np Access, Charles Darwin NT 0822, '
#                        'Australia',
#   'howMany': 2,
#   'lat': -12.4434808,
#   'lng': 130.877037,
#   'locId': 'L1143268',
#   'locName': 'Charles Darwin National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cacatua galerita',
#   'speciesCode': 'succoc',
#   'subId': 'S180925203'},
#  {'comName': 'White-throated Honeyeater',
#   'formatted_address': 'Charles Darwin Np Access, Charles Darwin NT 0822, '
#                        'Australia',
#   'howMany': 8,
#   'lat': -12.4434808,
#   'lng': 130.877037,
#   'locId': 'L1143268',
#   'locName': 'Charles Darwin National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:20',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Melithreptus albogularis',
#   'speciesCode': 'whthon1',
#   'subId': 'S180925203'},
#  {'comName': 'Rufous Fieldwren',
#   'formatted_address': '4QWRJWCF+28',
#   'howMany': 1,
#   'lat': -31.3799544,
#   'lng': 136.9232799,
#   'locId': 'L33208104',
#   'locName': 'Stuart Highway, Arcoona, South Australia, AU (-31.38, 136.923)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:13',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calamanthus campestris',
#   'speciesCode': 'ruffie2',
#   'subId': 'S180921444'},
#  {'comName': 'Pacific Black Duck',
#   'formatted_address': '1000 High St Rd, Glen Waverley VIC 3150, Australia',
#   'howMany': 7,
#   'lat': -37.8794669,
#   'lng': 145.1897656,
#   'locId': 'L7817345',
#   'locName': 'Napier Park',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:12',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas superciliosa',
#   'speciesCode': 'pabduc1',
#   'subId': 'S180922300'},
#  {'comName': 'Rufous-throated Honeyeater',
#   'formatted_address': 'State Route 24, Beswick Creek NT 0852, Australia',
#   'howMany': 1,
#   'lat': -14.6025,
#   'lng': 132.71172,
#   'locId': 'L2540255',
#   'locName': 'Central Arnhem Rd at -14.60250, 132.71172',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:11',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Conopophila rufogularis',
#   'speciesCode': 'ruthon1',
#   'subId': 'S180927433'},
#  {'comName': 'Pheasant Coucal',
#   'formatted_address': 'State Route 24, Beswick Creek NT 0852, Australia',
#   'howMany': 1,
#   'lat': -14.6025,
#   'lng': 132.71172,
#   'locId': 'L2540255',
#   'locName': 'Central Arnhem Rd at -14.60250, 132.71172',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:11',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Centropus phasianinus',
#   'speciesCode': 'phecou2',
#   'subId': 'S180927433'},
#  {'comName': 'Magpie-lark',
#   'formatted_address': '5R64HMJF+MC',
#   'howMany': 4,
#   'lat': -25.41833,
#   'lng': 142.67361,
#   'locId': 'L2532139',
#   'locName': 'Windorah Nature Trail',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Grallina cyanoleuca',
#   'speciesCode': 'maglar1',
#   'subId': 'S180932748'},
#  {'comName': 'Spotted Harrier',
#   'formatted_address': '14 Magnolia Bvd, Two Wells SA 5501, Australia',
#   'howMany': 1,
#   'lat': -34.5888418,
#   'lng': 138.5268296,
#   'locId': 'L27222309',
#   'locName': 'Seacomb Road',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Circus assimilis',
#   'speciesCode': 'spohar1',
#   'subId': 'S180922048'},
#  {'comName': 'Jacky-winter',
#   'formatted_address': '5R64HMJF+MC',
#   'howMany': 1,
#   'lat': -25.41833,
#   'lng': 142.67361,
#   'locId': 'L2532139',
#   'locName': 'Windorah Nature Trail',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Microeca fascinans',
#   'speciesCode': 'jacwin1',
#   'subId': 'S180932748'},
#  {'comName': 'Pied Butcherbird',
#   'formatted_address': '5R64HMJF+MC',
#   'howMany': 2,
#   'lat': -25.41833,
#   'lng': 142.67361,
#   'locId': 'L2532139',
#   'locName': 'Windorah Nature Trail',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cracticus nigrogularis',
#   'speciesCode': 'piebut1',
#   'subId': 'S180932748'},
#  {'comName': 'Australian Pelican',
#   'formatted_address': '5R64HMJF+MC',
#   'howMany': 1,
#   'lat': -25.41833,
#   'lng': 142.67361,
#   'locId': 'L2532139',
#   'locName': 'Windorah Nature Trail',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:10',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pelecanus conspicillatus',
#   'speciesCode': 'auspel1',
#   'subId': 'S180932748'},
#  {'comName': 'Black Swan',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 12,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cygnus atratus',
#   'speciesCode': 'blkswa',
#   'subId': 'S180929803'},
#  {'comName': 'Eastern Cattle Egret',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 6,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Bubulcus coromandus',
#   'speciesCode': 'categr2',
#   'subId': 'S180929803'},
#  {'comName': 'Muscovy Duck',
#   'exoticCategory': 'X',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cairina moschata',
#   'speciesCode': 'musduc',
#   'subId': 'S180929803'},
#  {'comName': 'Magpie Goose',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 15,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anseranas semipalmata',
#   'speciesCode': 'maggoo1',
#   'subId': 'S180929803'},
#  {'comName': 'Torresian Crow',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Corvus orru',
#   'speciesCode': 'torcro2',
#   'subId': 'S180929803'},
#  {'comName': 'Hardhead',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 1,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Aythya australis',
#   'speciesCode': 'wheduc1',
#   'subId': 'S180929803'},
#  {'comName': 'Little Black Cormorant',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 15,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phalacrocorax sulcirostris',
#   'speciesCode': 'libcor1',
#   'subId': 'S180929803'},
#  {'comName': 'Little Pied Cormorant',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 5,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Microcarbo melanoleucos',
#   'speciesCode': 'lipcor1',
#   'subId': 'S180929803'},
#  {'comName': 'Maned Duck',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Chenonetta jubata',
#   'speciesCode': 'manduc1',
#   'subId': 'S180929803'},
#  {'comName': 'Dusky Moorhen',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 75,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gallinula tenebrosa',
#   'speciesCode': 'dusmoo1',
#   'subId': 'S180929803'},
#  {'comName': 'Mallard',
#   'exoticCategory': 'X',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anas platyrhynchos',
#   'speciesCode': 'mallar3',
#   'subId': 'S180929803'},
#  {'comName': 'Australasian Darter',
#   'formatted_address': '213 Brisbane Rd, Monkland QLD 4570, Australia',
#   'howMany': 2,
#   'lat': -26.2147,
#   'lng': 152.68462,
#   'locId': 'L984423',
#   'locName': 'Lake Alford Park (Gympie)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:09',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Anhinga novaehollandiae',
#   'speciesCode': 'darter4',
#   'subId': 'S180929803'},
#  {'comName': 'Large-billed Gerygone',
#   'formatted_address': '21 Orchard Rd, Coconut Grove NT 0810, Australia',
#   'howMany': 2,
#   'lat': -12.396642,
#   'lng': 130.847231,
#   'locId': 'L1175729',
#   'locName': 'Mangroves near Orchard Rd (Coconut Grove)',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Gerygone magnirostris',
#   'speciesCode': 'labger1',
#   'subId': 'S180925002'},
#  {'comName': 'Laughing Kookaburra',
#   'formatted_address': '27 Macrossan St, Port Douglas QLD 4877, Australia',
#   'howMany': 1,
#   'lat': -16.4827421,
#   'lng': 145.4641479,
#   'locId': 'L1486336',
#   'locName': 'Port Douglas',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dacelo novaeguineae',
#   'speciesCode': 'laukoo1',
#   'subId': 'S180920393'},
#  {'comName': 'Eastern Rosella',
#   'formatted_address': '285 Cedar Ridge Rd, Kurrajong NSW 2758, Australia',
#   'howMany': 2,
#   'lat': -33.481278,
#   'lng': 150.699726,
#   'locId': 'L25178807',
#   'locName': '285 Cedar Ridge Road Kurrajong (Private Property)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-12 17:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Platycercus eximius',
#   'speciesCode': 'easros1',
#   'subId': 'S180919236'},
#  {'comName': 'Rufous Whistler',
#   'formatted_address': '5RH74H48+49',
#   'howMany': 1,
#   'lat': -18.8947259,
#   'lng': 145.5658865,
#   'locId': 'L4976757',
#   'locName': 'Valley of Lagoons',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pachycephala rufiventris',
#   'speciesCode': 'rufwhi1',
#   'subId': 'S180922850'},
#  {'comName': 'Gray Fantail',
#   'formatted_address': '5RH74H48+49',
#   'howMany': 5,
#   'lat': -18.8947259,
#   'lng': 145.5658865,
#   'locId': 'L4976757',
#   'locName': 'Valley of Lagoons',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Rhipidura albiscapa',
#   'speciesCode': 'gryfan1',
#   'subId': 'S180922850'},
#  {'comName': 'Common Bronzewing',
#   'formatted_address': '5RH74H48+49',
#   'howMany': 5,
#   'lat': -18.8947259,
#   'lng': 145.5658865,
#   'locId': 'L4976757',
#   'locName': 'Valley of Lagoons',
#   'locationPrivate': False,
#   'obsDt': '2024-06-12 17:05',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Phaps chalcoptera',
#   'speciesCode': 'combro1',
#   'subId': 'S180922850'},
#  {'comName': 'Black-fronted Dotterel',
# ...
#   'howMany': 1,
#   'lat': -43.0906763,
#   'lng': 148.3212687,
#   'locId': 'L1163813',
#   'locName': 'Eaglehawk Neck Pelagic Trip',
#   'locationPrivate': False,
#   'obsDt': '2024-06-02 07:28',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Thalassarche salvini',
#   'speciesCode': 'salalb1',
#   'subId': 'S179321107'},
#  {'comName': 'Sooty Tern',
#   'formatted_address': '5QV4QX6J+93',
#   'lat': -12.2390223,
#   'lng': 122.9802258,
#   'locId': 'L32572461',
#   'locName': 'Ashmore Reef (-12.239, 122.98)',
#   'locationPrivate': True,
#   'obsDt': '2024-06-01 13:27',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Onychoprion fuscatus',
#   'speciesCode': 'sooter1',
#   'subId': 'S179333397'},
#  {'comName': 'Western Whipbird',
#   'formatted_address': 'Wanna Rd, Lincoln National Park SA 5607, Australia',
#   'howMany': 1,
#   'lat': -34.826937,
#   'lng': 135.847265,
#   'locId': 'L32647962',
#   'locName': '956 Wanna Rd, Lincoln National Park AU-SA -34.82694, 135.84727',
#   'locationPrivate': True,
#   'obsDt': '2024-06-01 09:01',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Psophodes nigrogularis',
#   'speciesCode': 'weswhi1',
#   'subId': 'S178494230'},
#  {'comName': 'Blue-breasted Quail',
#   'formatted_address': '1940 State Route 58, Mount Mee QLD 4521, Australia',
#   'howMany': 1,
#   'lat': -27.1158826,
#   'lng': 152.7533282,
#   'locId': 'L10571892',
#   'locName': "Kye's backyard",
#   'locationPrivate': True,
#   'obsDt': '2024-05-30 23:22',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Synoicus chinensis',
#   'speciesCode': 'blbqua1',
#   'subId': 'S178175225'},
#  {'comName': 'Pacific Koel',
#   'formatted_address': '1 Pago Terrace, Pacific Pines QLD 4211, Australia',
#   'howMany': 1,
#   'lat': -27.93671,
#   'lng': 153.323638,
#   'locId': 'L32561000',
#   'locName': '1 Pago Tce, Pacific Pines AU-QLD -27.93671, 153.32364',
#   'locationPrivate': True,
#   'obsDt': '2024-05-30 12:33',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eudynamys orientalis',
#   'speciesCode': 'asikoe3',
#   'subId': 'S178116301'},
#  {'comName': 'Chestnut-breasted Cuckoo',
#   'formatted_address': '159 Euluma Creek Rd, Julatten QLD 4871, Australia',
#   'howMany': 1,
#   'lat': -16.56237,
#   'lng': 145.38771,
#   'locId': 'L2539396',
#   'locName': 'Euluma Creek Rd, Julatten at -16.56237, 145.38771 (restricted '
#              'access)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-30 08:05',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Cacomantis castaneiventris',
#   'speciesCode': 'chbcuc3',
#   'subId': 'S178112972'},
#  {'comName': 'Black-eared Miner',
#   'formatted_address': '76V7+P3 Gluepot SA, Australia',
#   'howMany': 2,
#   'lat': -33.7056432,
#   'lng': 140.212664,
#   'locId': 'L2557774',
#   'locName': 'Gluepot Reserve--Josies Hideaway (Grasswren Tank)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-30 07:26',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Manorina melanotis',
#   'speciesCode': 'blemin1',
#   'subId': 'S179834231'},
#  {'comName': 'Egyptian Goose',
#   'exoticCategory': 'X',
#   'formatted_address': '272 Fairhill Rd, North Arm QLD 4561, Australia',
#   'howMany': 1,
#   'lat': -26.5250424,
#   'lng': 152.9674081,
#   'locId': 'L5589433',
#   'locName': 'Fairhill Rd Dams at -26.5250, 152.9674 (North Arm)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-29 10:53',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Alopochen aegyptiaca',
#   'speciesCode': 'egygoo',
#   'subId': 'S178087173'},
#  {'comName': 'Northern Shrike-tit',
#   'formatted_address': 'Drysdale River Station, Gibb River-Kalumburu Rd, '
#                        'Drysdale River WA 6740, Australia',
#   'howMany': 3,
#   'lat': -15.7026,
#   'lng': 126.3786,
#   'locId': 'L1120589',
#   'locName': 'Drysdale River Station',
#   'locationPrivate': False,
#   'obsDt': '2024-05-29 06:30',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Falcunculus whitei',
#   'speciesCode': 'cresht3',
#   'subId': 'S178566492'},
#  {'comName': 'Yellow-rumped Munia',
#   'formatted_address': 'Bradshaw Bridge, Bradshaw Training Area, Gregory NT '
#                        '0852, Australia',
#   'howMany': 3,
#   'lat': -15.61389,
#   'lng': 130.4075,
#   'locId': 'L2538504',
#   'locName': 'Bradshaw Bridge at -15.61389, 130.4075',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 17:04',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Lonchura flaviprymna',
#   'speciesCode': 'yermun1',
#   'subId': 'S177926578'},
#  {'comName': 'Flesh-footed Shearwater',
#   'formatted_address': '64 Banksia Dr, Coral Bay WA 6701, Australia',
#   'howMany': 4,
#   'lat': -23.14288,
#   'lng': 113.7751,
#   'locId': 'L2562064',
#   'locName': 'Coral Bay',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 16:56',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Ardenna carneipes',
#   'speciesCode': 'flfshe',
#   'subId': 'S177754811'},
#  {'comName': 'Common Sandpiper',
#   'formatted_address': 'Popes Nose Bridge, Point Samson-Roebourne Rd, Point '
#                        'Samson WA 6720, Australia',
#   'howMany': 1,
#   'lat': -20.6296869,
#   'lng': 117.1775308,
#   'locId': 'L7797010',
#   'locName': 'Johns Creek at Point Samson-Roebourne Rd',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 09:51',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Actitis hypoleucos',
#   'speciesCode': 'comsan',
#   'subId': 'S177721242'},
#  {'comName': 'Western Bristlebird',
#   'formatted_address': '4C78+XG Cheynes WA, Australia',
#   'howMany': 3,
#   'lat': -34.8850112,
#   'lng': 118.4162621,
#   'locId': 'L921845',
#   'locName': 'Arpenteur Nature Reserve (incl. encompassing trails)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 06:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Dasyornis longirostris',
#   'speciesCode': 'wesbri1',
#   'subId': 'S180269365'},
#  {'comName': 'Noisy Scrub-bird',
#   'formatted_address': '4C78+XG Cheynes WA, Australia',
#   'howMany': 3,
#   'lat': -34.8850112,
#   'lng': 118.4162621,
#   'locId': 'L921845',
#   'locName': 'Arpenteur Nature Reserve (incl. encompassing trails)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-28 06:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Atrichornis clamosus',
#   'speciesCode': 'nosbir1',
#   'subId': 'S180269365'},
#  {'comName': 'Blue-faced Parrotfinch',
#   'formatted_address': '30 Jim Weir Rd, Julatten QLD 4871, Australia',
#   'howMany': 1,
#   'lat': -16.6272015,
#   'lng': 145.3199863,
#   'locId': 'L4803810',
#   'locName': 'Julatten, Jim Weir Road.',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 13:13',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Erythrura trichroa',
#   'speciesCode': 'blfpar3',
#   'subId': 'S177476712'},
#  {'comName': 'Wild Turkey',
#   'exoticCategory': 'P',
#   'formatted_address': '43 Hamilton Dr, Emu Bay SA 5223, Australia',
#   'howMany': 3,
#   'lat': -35.5929012,
#   'lng': 137.5062561,
#   'locId': 'L1158734',
#   'locName': 'Emu Bay',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 12:55',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Meleagris gallopavo',
#   'speciesCode': 'wiltur',
#   'subId': 'S177472535'},
#  {'comName': 'Broad-billed Sandpiper',
#   'formatted_address': '5QJ42CFC+58',
#   'howMany': 12,
#   'lat': -17.9771,
#   'lng': 122.42084,
#   'locId': 'L989143',
#   'locName': 'Kidney Bean Claypan and Duck Lake',
#   'locationPrivate': False,
#   'obsDt': '2024-05-27 12:02',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Calidris falcinellus',
#   'speciesCode': 'brbsan',
#   'subId': 'S177517718'},
#  {'comName': 'Common Ostrich',
#   'exoticCategory': 'X',
#   'formatted_address': '4 Spencer St, Kojonup WA 6395, Australia',
#   'howMany': 10,
#   'lat': -33.8371691,
#   'lng': 117.1604712,
#   'locId': 'L3668259',
#   'locName': 'Kojonup',
#   'locationPrivate': False,
#   'obsDt': '2024-05-26 14:22',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Struthio camelus',
#   'speciesCode': 'ostric2',
#   'subId': 'S177178798'},
#  {'comName': 'Dollarbird',
#   'formatted_address': '35 Sunbird Ct, Moorina QLD 4506, Australia',
#   'howMany': 1,
#   'lat': -27.13833,
#   'lng': 152.8825,
#   'locId': 'L2558227',
#   'locName': 'Shanley, Morayfield (restricted access)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-26 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eurystomus orientalis',
#   'speciesCode': 'dollar1',
#   'subId': 'S178131237'},
#  {'comName': 'Black-bellied Plover',
#   'formatted_address': '5P9PP44G+3J',
#   'howMany': 2,
#   'lat': -22.2948125,
#   'lng': 114.1265234,
#   'locId': 'L32280175',
#   'locName': 'Unnamed Road, Exmouth Gulf, Western Australia, AU (-22.295, '
#              '114.127)Bookings Rest',
#   'locationPrivate': True,
#   'obsDt': '2024-05-25 09:30',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pluvialis squatarola',
#   'speciesCode': 'bkbplo',
#   'subId': 'S176902114'},
#  {'comName': 'South Polar Skua',
#   'formatted_address': 'Cheynes Beach Caravan Park, 12 Bald Is Rd, Cheynes WA '
#                        '6328, Australia',
#   'howMany': 1,
#   'lat': -34.8837771,
#   'lng': 118.4046257,
#   'locId': 'L3321508',
#   'locName': 'Cheynes Beach Caravan Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-25 07:00',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Stercorarius maccormicki',
#   'speciesCode': 'sopsku1',
#   'subId': 'S177151736'},
#  {'comName': 'Black Grasswren',
#   'formatted_address': '5QQ75PG4+H3',
#   'howMany': 3,
#   'lat': -14.8236175,
#   'lng': 125.7051798,
#   'locId': 'L2539862',
#   'locName': 'Mitchell River National Park--general',
#   'locationPrivate': False,
#   'obsDt': '2024-05-25 06:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Amytornis housei',
#   'speciesCode': 'blagra1',
#   'subId': 'S178572008'},
#  {'comName': 'Gray Grasswren',
#   'formatted_address': '5Q5X8JW8+CM',
#   'howMany': 2,
#   'lat': -26.65389,
#   'lng': 139.61667,
#   'locId': 'L32349826',
#   'locName': 'Birdsville track',
#   'locationPrivate': True,
#   'obsDt': '2024-05-23 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Amytornis barbatus',
#   'speciesCode': 'grygra1',
#   'subId': 'S177193033'},
#  {'comName': 'White-faced Robin',
#   'formatted_address': 'Portland Rd, Iron Range QLD 4892, Australia',
#   'howMany': 2,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Eopsaltria leucops',
#   'speciesCode': 'whfrob1',
#   'subId': 'S176095004'},
#  {'comName': 'Red-cheeked Parrot',
#   'formatted_address': 'Portland Rd, Iron Range QLD 4892, Australia',
#   'howMany': 3,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Geoffroyus geoffroyi',
#   'speciesCode': 'recpar2',
#   'subId': 'S176095004'},
#  {'comName': 'Tropical Scrubwren',
#   'formatted_address': 'Portland Rd, Iron Range QLD 4892, Australia',
#   'howMany': 2,
#   'lat': -12.7115955,
#   'lng': 143.2899132,
#   'locId': 'L5890284',
#   'locName': 'Kutini Payamu (Iron Range) National Park--Cooks Hut to '
#              'Rainforest Camping area',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 16:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sericornis beccarii',
#   'speciesCode': 'becscr1',
#   'subId': 'S176095004'},
#  {'comName': 'Satin Flycatcher',
#   'formatted_address': '40 Whiteman Creek Rd, The Whiteman NSW 2460, Australia',
#   'howMany': 1,
#   'lat': -29.5858186,
#   'lng': 152.8418933,
#   'locId': 'L9641752',
#   'locName': 'Whiteman Creek (Private Property)',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 13:16',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Myiagra cyanoleuca',
#   'speciesCode': 'satfly1',
#   'subId': 'S175223653'},
#  {'comName': 'Eastern Yellow Wagtail',
#   'formatted_address': '1086 N W Coastal Hwy, Brown Range WA 6701, Australia',
#   'howMany': 1,
#   'lat': -24.8612616,
#   'lng': 113.707006,
#   'locId': 'L31977863',
#   'locName': 'Plantation road verge on highway',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 12:25',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Motacilla tschutschensis',
#   'speciesCode': 'eaywag',
#   'subId': 'S175503341'},
#  {'comName': 'Tahiti Petrel',
#   'formatted_address': '5R4M5W5J+FV',
#   'howMany': 1,
#   'lat': -27.84132,
#   'lng': 153.93214,
#   'locId': 'L28317038',
#   'locName': 'Auto selected -27.84132, 153.93214',
#   'locationPrivate': True,
#   'obsDt': '2024-05-18 11:39',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Pseudobulweria rostrata',
#   'speciesCode': 'tahpet1',
#   'subId': 'S176676068'},
#  {'comName': 'Oriental Pratincole',
#   'formatted_address': '5QJ437G8+Q3',
#   'howMany': 1,
#   'lat': -17.9230256,
#   'lng': 122.2651398,
#   'locId': 'L986014',
#   'locName': 'Dampier Creek saltmarsh (The Common)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:07',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glareola maldivarum',
#   'speciesCode': 'oripra',
#   'subId': 'S175204463'},
#  {'comName': 'Oriental Plover',
#   'formatted_address': '5QJ437G8+Q3',
#   'howMany': 1,
#   'lat': -17.9230256,
#   'lng': 122.2651398,
#   'locId': 'L986014',
#   'locName': 'Dampier Creek saltmarsh (The Common)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:07',
#   'obsReviewed': True,
#   'obsValid': True,
#   'sciName': 'Anarhynchus veredus',
#   'speciesCode': 'oriplo1',
#   'subId': 'S175204463'},
#  {'comName': 'Yellow-billed Kingfisher',
#   'formatted_address': '88RW+9X Iron Range QLD, Australia',
#   'howMany': 3,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Syma torotoro',
#   'speciesCode': 'yebkin1',
#   'subId': 'S176438326'},
#  {'comName': 'Green-backed Honeyeater',
#   'formatted_address': '88RW+9X Iron Range QLD, Australia',
#   'howMany': 5,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Glycichaera fallax',
#   'speciesCode': 'grbhon1',
#   'subId': 'S176438326'},
#  {'comName': 'Northern Scrub-Robin',
#   'formatted_address': '88RW+9X Iron Range QLD, Australia',
#   'howMany': 2,
#   'lat': -12.659014,
#   'lng': 143.3473778,
#   'locId': 'L2038367',
#   'locName': 'Kutini-Payamu (Iron Range) National Park',
#   'locationPrivate': False,
#   'obsDt': '2024-05-18 07:00',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Drymodes superciliaris',
#   'speciesCode': 'nosrob1',
#   'subId': 'S176438326'},
#  {'comName': 'Scarlet-chested Parrot',
#   'formatted_address': '5Q26GFGR+59',
#   'howMany': 2,
#   'lat': -29.474602,
#   'lng': 124.490901,
#   'locId': 'L31875841',
#   'locName': '6431, Plumridge Lakes AU-WA (-29.4746,124.4909)',
#   'locationPrivate': True,
#   'obsDt': '2024-05-17 12:40',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Neophema splendida',
#   'speciesCode': 'sccpar1',
#   'subId': 'S175031406'},
#  {'comName': 'Common Redshank',
#   'formatted_address': '5QJ428CP+7J',
#   'howMany': 1,
#   'lat': -17.979327,
#   'lng': 122.336533,
#   'locId': 'L3442562',
#   'locName': 'Wader Spit (Roebuck Bay)',
#   'locationPrivate': False,
#   'obsDt': '2024-05-15 15:24',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Tringa totanus',
#   'speciesCode': 'comred1',
#   'subId': 'S174619127'},
#  {'comName': 'Naretha Bluebonnet',
#   'formatted_address': '4QWFGVV5+P8',
#   'howMany': 2,
#   'lat': -31.45568,
#   'lng': 129.85827,
#   'locId': 'L2536340',
#   'locName': 'Koonalda Homestead',
#   'locationPrivate': False,
#   'obsDt': '2024-05-15 08:37',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Northiella narethae',
#   'speciesCode': 'bluebo4',
#   'subId': 'S175606155'}]

# %%
# Serialize the data to JSON format
json_data = json.dumps(merged_data, indent=4)  # Indent for better readability

# %%
# Specify the file path to save the JSON data
json_file_path = "Resources/eBird_observations_data.json"

# %%
# Write the JSON data to a file
with open(json_file_path, "w") as json_file:
    json_file.write(json_data)

print(f"Data successfully exported to {json_file_path}")
# Out:
# Data successfully exported to Resources/eBird_observations_data.json

# %%
# Load the JSON data into a DataFrame
df = pd.DataFrame(merged_data)

# %%
# Specify the file path to save the CSV data
csv_file_path = "Resources/eBird_observations_data.csv"

# %%
# Write the DataFrame to a CSV file with headers
df.to_csv(csv_file_path, index=False)

print(f"Data successfully exported to {csv_file_path}")
# Out:
# Data successfully exported to Resources/eBird_observations_data.csv
